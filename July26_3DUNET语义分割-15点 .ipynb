# %%
'''
为了便于修改，每个独立部分放置在一个cell中。
当前未解决的问题有：
1.还原轮廓线
2.多分类情况下分配标签，跟进轮廓线还原
3.数据预处理中删去分界线是否会影响模型性能尚不能确定
'''
# Out:
# '\n为了便于修改，每个独立部分放置在一个cell中。\n当前未解决的问题有：\n'

# %%
'''
TensorFlow和PyTorch会自动检测和使用可用的GPU。
'''

import tensorflow as tf

# 检查是否有GPU可用
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# PyTorch的对应指令是torch.cuda.is_available()
# Out:
# Num GPUs Available:  0

# %%
'''
预训练，其结果决定下一个cell采用的Batch size.
其他参数炒过了：学习率（手动实验0.0001，0.00001等）、训练轮数（设置早停）、网络结构超参数（参照常规）
'''

import numpy as np
import os
import tensorflow as tf
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# 读取点云数据和标签
def load_labeled_point_cloud(file_path):
    data = []
    labels = []
    with open(file_path, 'r', encoding='utf-8') as file:
        for line in file:
            parts = line.strip().split()
            if len(parts) == 4:
                x, y, z, label = map(float, parts)
                data.append([x, y, z])
                labels.append(int(label))
    return np.array(data), np.array(labels)

def create_voxel_grid(data, labels, grid_size, voxel_size):
    if data.size == 0 or labels.size == 0:
        print(f"Warning: Empty data or labels array. data.size={data.size}, labels.size={labels.size}")
        return None, None

    grid = np.zeros((grid_size, grid_size, grid_size))
    label_grid = np.zeros((grid_size, grid_size, grid_size))

    min_coords = np.min(data, axis=0)
    max_coords = np.max(data, axis=0)
    voxel_dim = (max_coords - min_coords) / grid_size

    for i, point in enumerate(data):
        voxel = ((point - min_coords) / voxel_dim).astype(int)
        voxel = np.clip(voxel, 0, grid_size-1)  # Ensure indices are within bounds
        grid[voxel[0], voxel[1], voxel[2]] = 1
        label_grid[voxel[0], voxel[1], voxel[2]] = labels[i] - 1  # Convert labels 1 and 2 to 0 and 1

    return grid, label_grid

def load_data_from_directory(data_dir, grid_size=32):
    x_data = []
    y_data = []
    for file in os.listdir(data_dir):
        if file.endswith("_labeled.txt"):
            file_path = os.path.join(data_dir, file)
            data, labels = load_labeled_point_cloud(file_path)
            if data.size == 0 or labels.size == 0:
                print(f"Skipping empty file: {file_path}")
                continue
            voxel_grid, label_grid = create_voxel_grid(data, labels, grid_size, grid_size)
            if voxel_grid is not None and label_grid is not None:
                # 应用数据增强
                voxel_grid = augment_voxel_grid(voxel_grid)
                x_data.append(voxel_grid)
                y_data.append(label_grid)
    x_data = np.expand_dims(np.array(x_data), axis=-1)
    y_data = np.expand_dims(np.array(y_data), axis=-1)
    return x_data, y_data

# 数据增强
def augment_voxel_grid(voxel_grid):
    """
    对体素网格进行随机旋转和翻转。
    """
    # 随机旋转
    angle = np.random.uniform(0, 360)
    voxel_grid = np.rot90(voxel_grid, k=int(angle // 90), axes=(0, 1))
    
    # 随机翻转
    if np.random.rand() > 0.5:
        voxel_grid = np.flip(voxel_grid, axis=0)
    if np.random.rand() > 0.5:
        voxel_grid = np.flip(voxel_grid, axis=1)
    if np.random.rand() > 0.5:
        voxel_grid = np.flip(voxel_grid, axis=2)
    
    return voxel_grid

# 定义UNET模型
def unet_3d(input_shape):
    inputs = tf.keras.layers.Input(shape=input_shape)

    # Encoder
    conv1 = tf.keras.layers.Conv3D(64, 3, activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(1e-4))(inputs)
    conv1 = tf.keras.layers.Conv3D(64, 3, activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(1e-4))(conv1)
    pool1 = tf.keras.layers.MaxPooling3D(pool_size=(2, 2, 2))(conv1)

    conv2 = tf.keras.layers.Conv3D(128, 3, activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(1e-4))(pool1)
    conv2 = tf.keras.layers.Conv3D(128, 3, activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(1e-4))(conv2)
    pool2 = tf.keras.layers.MaxPooling3D(pool_size=(2, 2, 2))(conv2)

    conv3 = tf.keras.layers.Conv3D(256, 3, activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(1e-4))(pool2)
    conv3 = tf.keras.layers.Conv3D(256, 3, activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(1e-4))(conv3)
    pool3 = tf.keras.layers.MaxPooling3D(pool_size=(2, 2, 2))(conv3)

    # Bottleneck
    conv4 = tf.keras.layers.Conv3D(512, 3, activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(1e-4))(pool3)
    conv4 = tf.keras.layers.Conv3D(512, 3, activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(1e-4))(conv4)

    # Decoder
    up5 = tf.keras.layers.Conv3DTranspose(256, 2, strides=(2, 2, 2), padding='same')(conv4)
    concat5 = tf.keras.layers.concatenate([up5, conv3], axis=-1)
    conv5 = tf.keras.layers.Conv3D(256, 3, activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(1e-4))(concat5)
    conv5 = tf.keras.layers.Conv3D(256, 3, activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(1e-4))(conv5)

    up6 = tf.keras.layers.Conv3DTranspose(128, 2, strides=(2, 2, 2), padding='same')(conv5)
    concat6 = tf.keras.layers.concatenate([up6, conv2], axis=-1)
    conv6 = tf.keras.layers.Conv3D(128, 3, activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(1e-4))(concat6)
    conv6 = tf.keras.layers.Conv3D(128, 3, activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(1e-4))(conv6)

    up7 = tf.keras.layers.Conv3DTranspose(64, 2, strides=(2, 2, 2), padding='same')(conv6)
    concat7 = tf.keras.layers.concatenate([up7, conv1], axis=-1)
    conv7 = tf.keras.layers.Conv3D(64, 3, activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(1e-4))(concat7)
    conv7 = tf.keras.layers.Conv3D(64, 3, activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(1e-4))(conv7)

    outputs = tf.keras.layers.Conv3D(1, 1, activation='sigmoid')(conv7)  # 1 channel output for binary classification

    model = tf.keras.models.Model(inputs=[inputs], outputs=[outputs])
    return model

# 定义学习率调度函数
def scheduler(epoch, lr):
    if epoch < 10:
        return float(lr)
    else:
        return float(lr * tf.math.exp(-0.1).numpy())

# 加载数据
data_dir = 'D:\BaiduSyncdisk\新建文件夹\桌面文件\深度学习程序\A-轮廓线识别\预处理后的数据1124个\预处理后的数据'
x_data, y_data = load_data_from_directory(data_dir, grid_size=16)

# 确保数据归一化
x_data = x_data / np.max(x_data)
y_data = y_data / np.max(y_data)

# 划分数据集
x_train, x_test, y_train, y_test = train_test_split(
    x_data, y_data, test_size=0.2, random_state=42
)

# 定义批次大小的候选值
batch_sizes = [8, 16, 32, 64]

for batch_size in batch_sizes:
    print(f"Testing batch size: {batch_size}")
    
    # 定义模型
    input_shape = (16, 16, 16, 1)
    model = unet_3d(input_shape)

    # 编译模型
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.00001), 
                  loss='binary_crossentropy', 
                  metrics=['accuracy'])

    # 定义学习率调度回调和早停回调
    lr_scheduler = tf.keras.callbacks.LearningRateScheduler(scheduler)
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

    # 训练模型
    history = model.fit(
        x_train, y_train, 
        validation_split=0.1,
        epochs=20, 
        batch_size=batch_size,
        callbacks=[lr_scheduler, early_stopping]
    )

    # 评估模型
    test_loss, test_accuracy = model.evaluate(x_test, y_test)
    print(f"Batch Size: {batch_size}, Test Loss: {test_loss}, Test Accuracy: {test_accuracy}")

    # 绘制训练过程中的损失和精确度
    def plot_training_history(history):
        """
        绘制训练过程中的损失和精确度。
        """
        plt.figure(figsize=(12, 5))

        # 绘制损失
        plt.subplot(1, 2, 1)
        plt.plot(history.history['loss'], label='Training Loss')
        plt.plot(history.history['val_loss'], label='Validation Loss')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.title('Loss Over Epochs')
        plt.legend()

        # 绘制精确度
        plt.subplot(1, 2, 2)
        plt.plot(history.history['accuracy'], label='Training Accuracy')
        plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
        plt.xlabel('Epoch')
        plt.ylabel('Accuracy')
        plt.title('Accuracy Over Epochs')
        plt.legend()

        plt.tight_layout()
        plt.show()

    plot_training_history(history)
# Out:
# <>:134: SyntaxWarning: invalid escape sequence '\B'
# <>:134: SyntaxWarning: invalid escape sequence '\B'
# C:\Users\51625\AppData\Local\Temp\ipykernel_25128\2527643629.py:134: SyntaxWarning: invalid escape sequence '\B'
#   data_dir = 'D:\BaiduSyncdisk\新建文件夹\桌面文件\深度学习程序\A-轮廓线识别\预处理后的数据1124个\预处理后的数据'
# Testing batch size: 8
# Epoch 1/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 55s 520ms/step - accuracy: 0.8702 - loss: 0.7889 - val_accuracy: 0.9003 - val_loss: 0.4557 - learning_rate: 3.0000e-05
# Epoch 2/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 52s 517ms/step - accuracy: 0.9006 - loss: 0.4046 - val_accuracy: 0.9216 - val_loss: 0.3281 - learning_rate: 3.0000e-05
# Epoch 3/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 52s 515ms/step - accuracy: 0.9228 - loss: 0.3214 - val_accuracy: 0.9217 - val_loss: 0.3047 - learning_rate: 3.0000e-05
# Epoch 4/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 52s 514ms/step - accuracy: 0.9213 - loss: 0.3030 - val_accuracy: 0.9215 - val_loss: 0.2885 - learning_rate: 3.0000e-05
# Epoch 5/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 53s 524ms/step - accuracy: 0.9222 - loss: 0.2869 - val_accuracy: 0.9223 - val_loss: 0.2767 - learning_rate: 3.0000e-05
# Epoch 6/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 52s 516ms/step - accuracy: 0.9238 - loss: 0.2735 - val_accuracy: 0.9225 - val_loss: 0.2672 - learning_rate: 3.0000e-05
# Epoch 7/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 52s 519ms/step - accuracy: 0.9224 - loss: 0.2665 - val_accuracy: 0.9192 - val_loss: 0.2709 - learning_rate: 3.0000e-05
# Epoch 8/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 53s 520ms/step - accuracy: 0.9220 - loss: 0.2604 - val_accuracy: 0.9219 - val_loss: 0.2542 - learning_rate: 3.0000e-05
# Epoch 9/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 52s 517ms/step - accuracy: 0.9227 - loss: 0.2536 - val_accuracy: 0.9229 - val_loss: 0.2489 - learning_rate: 3.0000e-05
# Epoch 10/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 53s 524ms/step - accuracy: 0.9226 - loss: 0.2500 - val_accuracy: 0.9231 - val_loss: 0.2456 - learning_rate: 3.0000e-05
# Epoch 11/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 52s 519ms/step - accuracy: 0.9229 - loss: 0.2446 - val_accuracy: 0.9214 - val_loss: 0.2423 - learning_rate: 2.7145e-05
# Epoch 12/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 52s 513ms/step - accuracy: 0.9206 - loss: 0.2431 - val_accuracy: 0.9216 - val_loss: 0.2392 - learning_rate: 2.4562e-05
# Epoch 13/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 52s 518ms/step - accuracy: 0.9238 - loss: 0.2380 - val_accuracy: 0.9222 - val_loss: 0.2366 - learning_rate: 2.2225e-05
# Epoch 14/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 52s 514ms/step - accuracy: 0.9228 - loss: 0.2369 - val_accuracy: 0.9219 - val_loss: 0.2346 - learning_rate: 2.0110e-05
# Epoch 15/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 52s 513ms/step - accuracy: 0.9236 - loss: 0.2338 - val_accuracy: 0.9234 - val_loss: 0.2319 - learning_rate: 1.8196e-05
# Epoch 16/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 52s 515ms/step - accuracy: 0.9238 - loss: 0.2319 - val_accuracy: 0.9233 - val_loss: 0.2303 - learning_rate: 1.6464e-05
# Epoch 17/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 53s 520ms/step - accuracy: 0.9237 - loss: 0.2314 - val_accuracy: 0.9233 - val_loss: 0.2288 - learning_rate: 1.4898e-05
# Epoch 18/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 52s 514ms/step - accuracy: 0.9233 - loss: 0.2294 - val_accuracy: 0.9226 - val_loss: 0.2279 - learning_rate: 1.3480e-05
# Epoch 19/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 53s 524ms/step - accuracy: 0.9245 - loss: 0.2262 - val_accuracy: 0.9232 - val_loss: 0.2265 - learning_rate: 1.2197e-05
# Epoch 20/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 53s 524ms/step - accuracy: 0.9240 - loss: 0.2264 - val_accuracy: 0.9229 - val_loss: 0.2260 - learning_rate: 1.1036e-05
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 339ms/step - accuracy: 0.9259 - loss: 0.2242
# Batch Size: 8, Test Loss: 0.22394932806491852, Test Accuracy: 0.9255295395851135
# Testing batch size: 16
# Epoch 1/20
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 50s 924ms/step - accuracy: 0.7849 - loss: 0.8772 - val_accuracy: 0.9003 - val_loss: 0.5703 - learning_rate: 3.0000e-05
# Epoch 2/20
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 47s 920ms/step - accuracy: 0.8941 - loss: 0.5346 - val_accuracy: 0.9003 - val_loss: 0.4247 - learning_rate: 3.0000e-05
# Epoch 3/20
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 47s 923ms/step - accuracy: 0.9009 - loss: 0.3967 - val_accuracy: 0.9212 - val_loss: 0.3439 - learning_rate: 3.0000e-05
# Epoch 4/20
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 48s 932ms/step - accuracy: 0.9210 - loss: 0.3398 - val_accuracy: 0.9215 - val_loss: 0.3265 - learning_rate: 3.0000e-05
# Epoch 5/20
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 48s 939ms/step - accuracy: 0.9224 - loss: 0.3227 - val_accuracy: 0.9218 - val_loss: 0.3141 - learning_rate: 3.0000e-05
# Epoch 6/20
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 47s 930ms/step - accuracy: 0.9221 - loss: 0.3108 - val_accuracy: 0.9228 - val_loss: 0.3018 - learning_rate: 3.0000e-05
# Epoch 7/20
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 47s 928ms/step - accuracy: 0.9218 - loss: 0.3017 - val_accuracy: 0.9206 - val_loss: 0.2939 - learning_rate: 3.0000e-05
# Epoch 8/20
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 48s 942ms/step - accuracy: 0.9233 - loss: 0.2894 - val_accuracy: 0.9196 - val_loss: 0.2898 - learning_rate: 3.0000e-05
# Epoch 9/20
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 48s 950ms/step - accuracy: 0.9220 - loss: 0.2841 - val_accuracy: 0.9222 - val_loss: 0.2789 - learning_rate: 3.0000e-05
# Epoch 10/20
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 49s 956ms/step - accuracy: 0.9225 - loss: 0.2783 - val_accuracy: 0.9230 - val_loss: 0.2720 - learning_rate: 3.0000e-05
# Epoch 11/20
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 48s 946ms/step - accuracy: 0.9241 - loss: 0.2690 - val_accuracy: 0.9229 - val_loss: 0.2679 - learning_rate: 2.7145e-05
# Epoch 12/20
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 47s 922ms/step - accuracy: 0.9217 - loss: 0.2701 - val_accuracy: 0.9224 - val_loss: 0.2639 - learning_rate: 2.4562e-05
# Epoch 13/20
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 47s 929ms/step - accuracy: 0.9231 - loss: 0.2621 - val_accuracy: 0.9228 - val_loss: 0.2612 - learning_rate: 2.2225e-05
# Epoch 14/20
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 47s 929ms/step - accuracy: 0.9229 - loss: 0.2599 - val_accuracy: 0.9217 - val_loss: 0.2585 - learning_rate: 2.0110e-05
# Epoch 15/20
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 48s 939ms/step - accuracy: 0.9225 - loss: 0.2575 - val_accuracy: 0.9228 - val_loss: 0.2561 - learning_rate: 1.8196e-05
# Epoch 16/20
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 47s 931ms/step - accuracy: 0.9225 - loss: 0.2565 - val_accuracy: 0.9219 - val_loss: 0.2548 - learning_rate: 1.6464e-05
# Epoch 17/20
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 47s 914ms/step - accuracy: 0.9233 - loss: 0.2540 - val_accuracy: 0.9229 - val_loss: 0.2522 - learning_rate: 1.4898e-05
# Epoch 18/20
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 47s 915ms/step - accuracy: 0.9235 - loss: 0.2512 - val_accuracy: 0.9222 - val_loss: 0.2529 - learning_rate: 1.3480e-05
# Epoch 19/20
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 47s 912ms/step - accuracy: 0.9232 - loss: 0.2520 - val_accuracy: 0.9233 - val_loss: 0.2496 - learning_rate: 1.2197e-05
# Epoch 20/20
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 46s 911ms/step - accuracy: 0.9227 - loss: 0.2495 - val_accuracy: 0.9221 - val_loss: 0.2486 - learning_rate: 1.1036e-05
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 339ms/step - accuracy: 0.9253 - loss: 0.2465
# Batch Size: 16, Test Loss: 0.24624010920524597, Test Accuracy: 0.9249164462089539
# Testing batch size: 32
# Epoch 1/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 45s 2s/step - accuracy: 0.6230 - loss: 0.9382 - val_accuracy: 0.9003 - val_loss: 0.7791 - learning_rate: 3.0000e-05
# Epoch 2/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - accuracy: 0.8945 - loss: 0.6960 - val_accuracy: 0.9003 - val_loss: 0.5984 - learning_rate: 3.0000e-05
# Epoch 3/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 44s 2s/step - accuracy: 0.8954 - loss: 0.5693 - val_accuracy: 0.9003 - val_loss: 0.4951 - learning_rate: 3.0000e-05
# Epoch 4/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - accuracy: 0.8935 - loss: 0.4935 - val_accuracy: 0.9003 - val_loss: 0.4407 - learning_rate: 3.0000e-05
# Epoch 5/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - accuracy: 0.8973 - loss: 0.4225 - val_accuracy: 0.9137 - val_loss: 0.3586 - learning_rate: 3.0000e-05
# Epoch 6/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - accuracy: 0.9163 - loss: 0.3568 - val_accuracy: 0.9216 - val_loss: 0.3399 - learning_rate: 3.0000e-05
# Epoch 7/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - accuracy: 0.9213 - loss: 0.3399 - val_accuracy: 0.9226 - val_loss: 0.3285 - learning_rate: 3.0000e-05
# Epoch 8/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 44s 2s/step - accuracy: 0.9231 - loss: 0.3257 - val_accuracy: 0.9219 - val_loss: 0.3207 - learning_rate: 3.0000e-05
# Epoch 9/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 44s 2s/step - accuracy: 0.9228 - loss: 0.3192 - val_accuracy: 0.9213 - val_loss: 0.3149 - learning_rate: 3.0000e-05
# Epoch 10/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 44s 2s/step - accuracy: 0.9207 - loss: 0.3152 - val_accuracy: 0.9208 - val_loss: 0.3083 - learning_rate: 3.0000e-05
# Epoch 11/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 44s 2s/step - accuracy: 0.9213 - loss: 0.3092 - val_accuracy: 0.9209 - val_loss: 0.3035 - learning_rate: 2.7145e-05
# Epoch 12/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 44s 2s/step - accuracy: 0.9227 - loss: 0.3012 - val_accuracy: 0.9216 - val_loss: 0.2974 - learning_rate: 2.4562e-05
# Epoch 13/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 44s 2s/step - accuracy: 0.9227 - loss: 0.2968 - val_accuracy: 0.9216 - val_loss: 0.2936 - learning_rate: 2.2225e-05
# Epoch 14/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 44s 2s/step - accuracy: 0.9227 - loss: 0.2931 - val_accuracy: 0.9206 - val_loss: 0.2910 - learning_rate: 2.0110e-05
# Epoch 15/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 44s 2s/step - accuracy: 0.9225 - loss: 0.2904 - val_accuracy: 0.9226 - val_loss: 0.2866 - learning_rate: 1.8196e-05
# Epoch 16/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 44s 2s/step - accuracy: 0.9220 - loss: 0.2881 - val_accuracy: 0.9227 - val_loss: 0.2844 - learning_rate: 1.6464e-05
# Epoch 17/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 44s 2s/step - accuracy: 0.9228 - loss: 0.2843 - val_accuracy: 0.9227 - val_loss: 0.2820 - learning_rate: 1.4898e-05
# Epoch 18/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 44s 2s/step - accuracy: 0.9236 - loss: 0.2817 - val_accuracy: 0.9228 - val_loss: 0.2800 - learning_rate: 1.3480e-05
# Epoch 19/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - accuracy: 0.9230 - loss: 0.2797 - val_accuracy: 0.9229 - val_loss: 0.2784 - learning_rate: 1.2197e-05
# Epoch 20/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - accuracy: 0.9231 - loss: 0.2786 - val_accuracy: 0.9214 - val_loss: 0.2783 - learning_rate: 1.1036e-05
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 349ms/step - accuracy: 0.9250 - loss: 0.2765
# Batch Size: 32, Test Loss: 0.2760980427265167, Test Accuracy: 0.9245399236679077
# Testing batch size: 64
# Epoch 1/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 46s 3s/step - accuracy: 0.5832 - loss: 0.9495 - val_accuracy: 0.9003 - val_loss: 0.9223 - learning_rate: 3.0000e-05
# Epoch 2/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.8952 - loss: 0.9069 - val_accuracy: 0.9003 - val_loss: 0.8182 - learning_rate: 3.0000e-05
# Epoch 3/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.8953 - loss: 0.7549 - val_accuracy: 0.9003 - val_loss: 0.6494 - learning_rate: 3.0000e-05
# Epoch 4/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 42s 3s/step - accuracy: 0.8968 - loss: 0.6361 - val_accuracy: 0.9003 - val_loss: 0.5983 - learning_rate: 3.0000e-05
# Epoch 5/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.8957 - loss: 0.5873 - val_accuracy: 0.9003 - val_loss: 0.5237 - learning_rate: 3.0000e-05
# Epoch 6/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.8973 - loss: 0.5192 - val_accuracy: 0.9003 - val_loss: 0.4953 - learning_rate: 3.0000e-05
# Epoch 7/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.8944 - loss: 0.4979 - val_accuracy: 0.9003 - val_loss: 0.4719 - learning_rate: 3.0000e-05
# Epoch 8/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.8968 - loss: 0.4695 - val_accuracy: 0.9003 - val_loss: 0.4383 - learning_rate: 3.0000e-05
# Epoch 9/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.8957 - loss: 0.4334 - val_accuracy: 0.9003 - val_loss: 0.3950 - learning_rate: 3.0000e-05
# Epoch 10/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.8957 - loss: 0.3888 - val_accuracy: 0.9102 - val_loss: 0.3635 - learning_rate: 3.0000e-05
# Epoch 11/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.9132 - loss: 0.3593 - val_accuracy: 0.9192 - val_loss: 0.3452 - learning_rate: 2.7145e-05
# Epoch 12/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.9202 - loss: 0.3452 - val_accuracy: 0.9217 - val_loss: 0.3376 - learning_rate: 2.4562e-05
# Epoch 13/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.9231 - loss: 0.3368 - val_accuracy: 0.9225 - val_loss: 0.3331 - learning_rate: 2.2225e-05
# Epoch 14/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 49s 4s/step - accuracy: 0.9218 - loss: 0.3350 - val_accuracy: 0.9225 - val_loss: 0.3303 - learning_rate: 2.0110e-05
# Epoch 15/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.9230 - loss: 0.3292 - val_accuracy: 0.9216 - val_loss: 0.3276 - learning_rate: 1.8196e-05
# Epoch 16/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.9228 - loss: 0.3274 - val_accuracy: 0.9228 - val_loss: 0.3248 - learning_rate: 1.6464e-05
# Epoch 17/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.9224 - loss: 0.3253 - val_accuracy: 0.9223 - val_loss: 0.3225 - learning_rate: 1.4898e-05
# Epoch 18/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.9228 - loss: 0.3233 - val_accuracy: 0.9219 - val_loss: 0.3209 - learning_rate: 1.3480e-05
# Epoch 19/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.9221 - loss: 0.3216 - val_accuracy: 0.9229 - val_loss: 0.3189 - learning_rate: 1.2197e-05
# Epoch 20/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.9232 - loss: 0.3191 - val_accuracy: 0.9228 - val_loss: 0.3173 - learning_rate: 1.1036e-05
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 342ms/step - accuracy: 0.9247 - loss: 0.3197
# Batch Size: 64, Test Loss: 0.3181437849998474, Test Accuracy: 0.9245486259460449

# %%
'''
模型训练
'''

import numpy as np
import os
import tensorflow as tf
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# 读取点云数据和标签
def load_labeled_point_cloud(file_path):
    data = []
    labels = []
    with open(file_path, 'r', encoding='utf-8') as file:
        for line in file:
            parts = line.strip().split()
            if len(parts) == 4:
                x, y, z, label = map(float, parts)
                data.append([x, y, z])
                labels.append(int(label))
    return np.array(data), np.array(labels)

def create_voxel_grid(data, labels, grid_size, voxel_size):
    if data.size == 0 or labels.size == 0:
        print(f"Warning: Empty data or labels array. data.size={data.size}, labels.size={labels.size}")
        return None, None

    grid = np.zeros((grid_size, grid_size, grid_size))
    label_grid = np.zeros((grid_size, grid_size, grid_size))

    min_coords = np.min(data, axis=0)
    max_coords = np.max(data, axis=0)
    voxel_dim = (max_coords - min_coords) / grid_size

    for i, point in enumerate(data):
        voxel = ((point - min_coords) / voxel_dim).astype(int)
        voxel = np.clip(voxel, 0, grid_size-1)  # Ensure indices are within bounds
        grid[voxel[0], voxel[1], voxel[2]] = 1
        label_grid[voxel[0], voxel[1], voxel[2]] = labels[i] - 1  # Convert labels 1 and 2 to 0 and 1

    return grid, label_grid

def load_data_from_directory(data_dir, grid_size=32):
    x_data = []
    y_data = []
    for file in os.listdir(data_dir):
        if file.endswith("_labeled.txt"):
            file_path = os.path.join(data_dir, file)
            data, labels = load_labeled_point_cloud(file_path)
            if data.size == 0 or labels.size == 0:
                print(f"Skipping empty file: {file_path}")
                continue
            voxel_grid, label_grid = create_voxel_grid(data, labels, grid_size, grid_size)
            if voxel_grid is not None and label_grid is not None:
                # 应用数据增强
                voxel_grid = augment_voxel_grid(voxel_grid)
                x_data.append(voxel_grid)
                y_data.append(label_grid)
    x_data = np.expand_dims(np.array(x_data), axis=-1)
    y_data = np.expand_dims(np.array(y_data), axis=-1)
    return x_data, y_data

# 数据增强
def augment_voxel_grid(voxel_grid):
    """
    对体素网格进行随机旋转和翻转。
    """
    # 随机旋转
    angle = np.random.uniform(0, 360)
    voxel_grid = np.rot90(voxel_grid, k=int(angle // 90), axes=(0, 1))
    
    # 随机翻转
    if np.random.rand() > 0.5:
        voxel_grid = np.flip(voxel_grid, axis=0)
    if np.random.rand() > 0.5:
        voxel_grid = np.flip(voxel_grid, axis=1)
    if np.random.rand() > 0.5:
        voxel_grid = np.flip(voxel_grid, axis=2)
    
    return voxel_grid

# 定义UNET模型
def unet_3d(input_shape):
    inputs = tf.keras.layers.Input(shape=input_shape)

    # Encoder
    conv1 = tf.keras.layers.Conv3D(64, 3, activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(1e-4))(inputs)
    conv1 = tf.keras.layers.Conv3D(64, 3, activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(1e-4))(conv1)
    pool1 = tf.keras.layers.MaxPooling3D(pool_size=(2, 2, 2))(conv1)

    conv2 = tf.keras.layers.Conv3D(128, 3, activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(1e-4))(pool1)
    conv2 = tf.keras.layers.Conv3D(128, 3, activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(1e-4))(conv2)
    pool2 = tf.keras.layers.MaxPooling3D(pool_size=(2, 2, 2))(conv2)

    conv3 = tf.keras.layers.Conv3D(256, 3, activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(1e-4))(pool2)
    conv3 = tf.keras.layers.Conv3D(256, 3, activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(1e-4))(conv3)
    pool3 = tf.keras.layers.MaxPooling3D(pool_size=(2, 2, 2))(conv3)

    # Bottleneck
    conv4 = tf.keras.layers.Conv3D(512, 3, activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(1e-4))(pool3)
    conv4 = tf.keras.layers.Conv3D(512, 3, activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(1e-4))(conv4)

    # Decoder
    up5 = tf.keras.layers.Conv3DTranspose(256, 2, strides=(2, 2, 2), padding='same')(conv4)
    concat5 = tf.keras.layers.concatenate([up5, conv3], axis=-1)
    conv5 = tf.keras.layers.Conv3D(256, 3, activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(1e-4))(concat5)
    conv5 = tf.keras.layers.Conv3D(256, 3, activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(1e-4))(conv5)

    up6 = tf.keras.layers.Conv3DTranspose(128, 2, strides=(2, 2, 2), padding='same')(conv5)
    concat6 = tf.keras.layers.concatenate([up6, conv2], axis=-1)
    conv6 = tf.keras.layers.Conv3D(128, 3, activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(1e-4))(concat6)
    conv6 = tf.keras.layers.Conv3D(128, 3, activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(1e-4))(conv6)

    up7 = tf.keras.layers.Conv3DTranspose(64, 2, strides=(2, 2, 2), padding='same')(conv6)
    concat7 = tf.keras.layers.concatenate([up7, conv1], axis=-1)
    conv7 = tf.keras.layers.Conv3D(64, 3, activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(1e-4))(concat7)
    conv7 = tf.keras.layers.Conv3D(64, 3, activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(1e-4))(conv7)

    outputs = tf.keras.layers.Conv3D(1, 1, activation='sigmoid')(conv7)  # 1 channel output for binary classification

    model = tf.keras.models.Model(inputs=[inputs], outputs=[outputs])
    return model

# 定义学习率调度函数
def scheduler(epoch, lr):
    if epoch < 10:
        return float(lr)
    else:
        return float(lr * tf.math.exp(-0.1).numpy())

# 加载数据
data_dir = 'D:\BaiduSyncdisk\新建文件夹\桌面文件\深度学习程序\A-轮廓线识别\预处理后的数据1124个\预处理后的数据'
x_data, y_data = load_data_from_directory(data_dir, grid_size=16)

# 确保数据归一化
x_data = x_data / np.max(x_data)
y_data = y_data / np.max(y_data)

# 划分数据集
x_train, x_test, y_train, y_test = train_test_split(
    x_data, y_data, test_size=0.2, random_state=42
)

# 定义模型
input_shape = (16, 16, 16, 1)
model = unet_3d(input_shape)

# 编译模型
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.00001), 
              loss='binary_crossentropy', 
              metrics=['accuracy'])

# 定义学习率调度回调和早停回调
lr_scheduler = tf.keras.callbacks.LearningRateScheduler(scheduler)
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# 训练模型
history = model.fit(
    x_train, y_train, 
    validation_split=0.1,
    epochs=40, 
    batch_size=10,
    callbacks=[lr_scheduler, early_stopping]
)

# 评估模型
test_loss, test_accuracy = model.evaluate(x_test, y_test)

print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")

# 绘制训练过程中的损失和精确度
def plot_training_history(history):
    """
    绘制训练过程中的损失和精确度。
    """
    # 绘制损失
    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Loss Over Epochs')
    plt.legend()

    # 绘制精确度
    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title('Accuracy Over Epochs')
    plt.legend()

    plt.tight_layout()
    plt.show()

# 炼
plot_training_history(history)
# Out:
# <>:133: SyntaxWarning: invalid escape sequence '\B'
# <>:133: SyntaxWarning: invalid escape sequence '\B'
# C:\Users\51625\AppData\Local\Temp\ipykernel_25128\1713992711.py:133: SyntaxWarning: invalid escape sequence '\B'
#   data_dir = 'D:\BaiduSyncdisk\新建文件夹\桌面文件\深度学习程序\A-轮廓线识别\预处理后的数据1124个\预处理后的数据'
# Epoch 1/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 53s 619ms/step - accuracy: 0.8176 - loss: 0.8210 - val_accuracy: 0.9003 - val_loss: 0.4940 - learning_rate: 3.0000e-05
# Epoch 2/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 51s 627ms/step - accuracy: 0.8977 - loss: 0.4558 - val_accuracy: 0.9184 - val_loss: 0.3463 - learning_rate: 3.0000e-05
# Epoch 3/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 52s 641ms/step - accuracy: 0.9212 - loss: 0.3366 - val_accuracy: 0.9208 - val_loss: 0.3204 - learning_rate: 3.0000e-05
# Epoch 4/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 51s 632ms/step - accuracy: 0.9220 - loss: 0.3148 - val_accuracy: 0.9223 - val_loss: 0.3031 - learning_rate: 3.0000e-05
# Epoch 5/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 51s 628ms/step - accuracy: 0.9231 - loss: 0.2965 - val_accuracy: 0.9227 - val_loss: 0.2889 - learning_rate: 3.0000e-05
# Epoch 6/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 51s 635ms/step - accuracy: 0.9227 - loss: 0.2860 - val_accuracy: 0.9216 - val_loss: 0.2797 - learning_rate: 3.0000e-05
# Epoch 7/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 52s 639ms/step - accuracy: 0.9223 - loss: 0.2784 - val_accuracy: 0.9230 - val_loss: 0.2703 - learning_rate: 3.0000e-05
# Epoch 8/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 51s 634ms/step - accuracy: 0.9225 - loss: 0.2692 - val_accuracy: 0.9230 - val_loss: 0.2641 - learning_rate: 3.0000e-05
# Epoch 9/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 51s 628ms/step - accuracy: 0.9238 - loss: 0.2628 - val_accuracy: 0.9227 - val_loss: 0.2610 - learning_rate: 3.0000e-05
# Epoch 10/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 51s 624ms/step - accuracy: 0.9231 - loss: 0.2583 - val_accuracy: 0.9222 - val_loss: 0.2543 - learning_rate: 3.0000e-05
# Epoch 11/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 51s 628ms/step - accuracy: 0.9227 - loss: 0.2531 - val_accuracy: 0.9232 - val_loss: 0.2497 - learning_rate: 2.7145e-05
# Epoch 12/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 51s 629ms/step - accuracy: 0.9222 - loss: 0.2511 - val_accuracy: 0.9220 - val_loss: 0.2480 - learning_rate: 2.4562e-05
# Epoch 13/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 51s 626ms/step - accuracy: 0.9245 - loss: 0.2446 - val_accuracy: 0.9228 - val_loss: 0.2445 - learning_rate: 2.2225e-05
# Epoch 14/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 51s 627ms/step - accuracy: 0.9233 - loss: 0.2431 - val_accuracy: 0.9227 - val_loss: 0.2442 - learning_rate: 2.0110e-05
# Epoch 15/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 52s 636ms/step - accuracy: 0.9223 - loss: 0.2444 - val_accuracy: 0.9229 - val_loss: 0.2405 - learning_rate: 1.8196e-05
# Epoch 16/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 144s 2s/step - accuracy: 0.9219 - loss: 0.2430 - val_accuracy: 0.9230 - val_loss: 0.2398 - learning_rate: 1.6464e-05
# Epoch 17/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 143s 2s/step - accuracy: 0.9205 - loss: 0.2445 - val_accuracy: 0.9226 - val_loss: 0.2372 - learning_rate: 1.4898e-05
# Epoch 18/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 140s 2s/step - accuracy: 0.9237 - loss: 0.2369 - val_accuracy: 0.9231 - val_loss: 0.2359 - learning_rate: 1.3480e-05
# Epoch 19/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 138s 2s/step - accuracy: 0.9236 - loss: 0.2357 - val_accuracy: 0.9208 - val_loss: 0.2364 - learning_rate: 1.2197e-05
# Epoch 20/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 137s 2s/step - accuracy: 0.9242 - loss: 0.2325 - val_accuracy: 0.9229 - val_loss: 0.2338 - learning_rate: 1.1036e-05
# Epoch 21/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 138s 2s/step - accuracy: 0.9233 - loss: 0.2332 - val_accuracy: 0.9229 - val_loss: 0.2329 - learning_rate: 9.9861e-06
# Epoch 22/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 139s 2s/step - accuracy: 0.9243 - loss: 0.2317 - val_accuracy: 0.9232 - val_loss: 0.2319 - learning_rate: 9.0358e-06
# Epoch 23/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 139s 2s/step - accuracy: 0.9229 - loss: 0.2326 - val_accuracy: 0.9231 - val_loss: 0.2311 - learning_rate: 8.1760e-06
# Epoch 24/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 142s 2s/step - accuracy: 0.9227 - loss: 0.2332 - val_accuracy: 0.9229 - val_loss: 0.2307 - learning_rate: 7.3979e-06
# Epoch 25/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 137s 2s/step - accuracy: 0.9238 - loss: 0.2290 - val_accuracy: 0.9231 - val_loss: 0.2299 - learning_rate: 6.6939e-06
# Epoch 26/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 139s 2s/step - accuracy: 0.9232 - loss: 0.2298 - val_accuracy: 0.9231 - val_loss: 0.2294 - learning_rate: 6.0569e-06
# Epoch 27/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 138s 2s/step - accuracy: 0.9236 - loss: 0.2298 - val_accuracy: 0.9230 - val_loss: 0.2293 - learning_rate: 5.4805e-06
# Epoch 28/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 140s 2s/step - accuracy: 0.9238 - loss: 0.2288 - val_accuracy: 0.9229 - val_loss: 0.2288 - learning_rate: 4.9590e-06
# Epoch 29/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 138s 2s/step - accuracy: 0.9252 - loss: 0.2257 - val_accuracy: 0.9232 - val_loss: 0.2280 - learning_rate: 4.4871e-06
# Epoch 30/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 138s 2s/step - accuracy: 0.9236 - loss: 0.2281 - val_accuracy: 0.9227 - val_loss: 0.2280 - learning_rate: 4.0601e-06
# Epoch 31/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 138s 2s/step - accuracy: 0.9238 - loss: 0.2282 - val_accuracy: 0.9231 - val_loss: 0.2274 - learning_rate: 3.6737e-06
# Epoch 32/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 138s 2s/step - accuracy: 0.9252 - loss: 0.2255 - val_accuracy: 0.9233 - val_loss: 0.2271 - learning_rate: 3.3241e-06
# Epoch 33/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 143s 2s/step - accuracy: 0.9237 - loss: 0.2262 - val_accuracy: 0.9231 - val_loss: 0.2270 - learning_rate: 3.0078e-06
# Epoch 34/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 138s 2s/step - accuracy: 0.9240 - loss: 0.2264 - val_accuracy: 0.9231 - val_loss: 0.2266 - learning_rate: 2.7215e-06
# Epoch 35/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 138s 2s/step - accuracy: 0.9241 - loss: 0.2261 - val_accuracy: 0.9232 - val_loss: 0.2263 - learning_rate: 2.4626e-06
# Epoch 36/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 138s 2s/step - accuracy: 0.9242 - loss: 0.2251 - val_accuracy: 0.9232 - val_loss: 0.2261 - learning_rate: 2.2282e-06
# Epoch 37/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 136s 2s/step - accuracy: 0.9254 - loss: 0.2231 - val_accuracy: 0.9230 - val_loss: 0.2262 - learning_rate: 2.0162e-06
# Epoch 38/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 137s 2s/step - accuracy: 0.9237 - loss: 0.2253 - val_accuracy: 0.9230 - val_loss: 0.2260 - learning_rate: 1.8243e-06
# Epoch 39/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 136s 2s/step - accuracy: 0.9232 - loss: 0.2258 - val_accuracy: 0.9232 - val_loss: 0.2258 - learning_rate: 1.6507e-06
# Epoch 40/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 137s 2s/step - accuracy: 0.9224 - loss: 0.2283 - val_accuracy: 0.9232 - val_loss: 0.2256 - learning_rate: 1.4936e-06
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.9255 - loss: 0.2240
# Test Loss: 0.22361233830451965
# Test Accuracy: 0.9251660108566284

# %%
'''
模型保存和加载
'''

# 保存模型
model_save_path = 'D:/BaiduSyncdisk/新建文件夹/桌面文件/深度学习程序/模型-0725/unet_3d_model_0726.h5'
model.save(model_save_path)
print(f"Model saved to {model_save_path}")

# 加载模型
model_load_path = 'D:/BaiduSyncdisk/新建文件夹/桌面文件/深度学习程序/模型-0725/unet_3d_model_0726.h5'
loaded_model = tf.keras.models.load_model(model_load_path)
print(f"Model loaded from {model_load_path}")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved to D:/BaiduSyncdisk/新建文件夹/桌面文件/深度学习程序/模型-0725/unet_3d_model_0726.h5
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model loaded from D:/BaiduSyncdisk/新建文件夹/桌面文件/深度学习程序/模型-0725/unet_3d_model_0726.h5

# %%
'''
模型用于预测，以及结果可视化
'''

# 开启交互旋转
# %matplotlib notebook

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import tensorflow as tf
from scipy.spatial import KDTree
from collections import defaultdict
from itertools import combinations

# 加载obj文件
def load_obj_file(file_path):
    vertices = []
    faces = []
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            for line in file:
                if line.startswith('v '):
                    parts = line.strip().split()
                    vertex = [float(parts[1]), float(parts[2]), float(parts[3])]
                    vertices.append(vertex)
                elif line.startswith('f '):
                    parts = line.strip().split()
                    face = [int(p.split('/')[0]) - 1 for p in parts[1:]]
                    faces.append(face)
    except FileNotFoundError:
        print(f"File not found: {file_path}")
    except Exception as e:
        print(f"An error occurred: {e}")
    return vertices, faces

# 将顶点平移至包围盒中心
def center_vertices(vertices):
    vertices_array = np.array(vertices)
    min_coords = vertices_array.min(axis=0)
    max_coords = vertices_array.max(axis=0)
    center = (min_coords + max_coords) / 2
    centered_vertices = vertices_array - center
    return centered_vertices.tolist()

# 点云转体素网格
def create_voxel_grid(data, grid_size):
    grid = np.zeros((grid_size, grid_size, grid_size))
    min_coords = np.min(data, axis=0)
    max_coords = np.max(data, axis=0)
    voxel_dim = (max_coords - min_coords) / grid_size

    for i, point in enumerate(data):
        voxel = ((point - min_coords) / voxel_dim).astype(int)
        voxel = np.clip(voxel, 0, grid_size-1)  # Ensure indices are within bounds
        grid[voxel[0], voxel[1], voxel[2]] = 1

    return grid, min_coords, voxel_dim

# 旋转点云
def rotate_points(points, angles):
    x_angle, y_angle, z_angle = angles
    Rx = np.array([
        [1, 0, 0],
        [0, np.cos(x_angle), -np.sin(x_angle)],
        [0, np.sin(x_angle), np.cos(x_angle)]
    ])
    Ry = np.array([
        [np.cos(y_angle), 0, np.sin(y_angle)],
        [0, 1, 0],
        [-np.sin(y_angle), 0, np.cos(y_angle)]
    ])
    Rz = np.array([
        [np.cos(z_angle), -np.sin(z_angle), 0],
        [np.sin(z_angle), np.cos(z_angle), 0],
        [0, 0, 1]
    ])
    R = Rz @ Ry @ Rx
    return points @ R.T

# 从训练好的模型获取标签
def get_labels_from_model(model, voxel_grid):
    voxel_grid = np.expand_dims(voxel_grid, axis=0)  # Add batch dimension
    voxel_grid = np.expand_dims(voxel_grid, axis=-1)  # Add channel dimension
    predictions = model.predict(voxel_grid)
    labels = (predictions > 0.5).astype(int)
    return labels.reshape(voxel_grid.shape[1], voxel_grid.shape[2], voxel_grid.shape[3])

# 应用预测标签到原始点云
def apply_labels_to_point_cloud(data, predicted_labels, min_coords, voxel_dim, grid_size):
    labels = np.zeros(len(data))
    for i, point in enumerate(data):
        voxel = ((point - min_coords) / voxel_dim).astype(int)
        voxel = np.clip(voxel, 0, grid_size-1)  # Ensure indices are within bounds
        labels[i] = predicted_labels[voxel[0], voxel[1], voxel[2]]
    return labels

# 识别并合并分割线段
def find_boundary_edges(vertices, faces, labels):
    edges = defaultdict(list)
    for face in faces:
        for (v1, v2) in combinations(face, 2):
            if labels[v1] != labels[v2]:
                edges[tuple(sorted([v1, v2]))].append(face)
    
    # Create an adjacency list for edges
    adjacency_list = defaultdict(list)
    for (v1, v2), faces in edges.items():
        adjacency_list[v1].append(v2)
        adjacency_list[v2].append(v1)
    
    # Find all connected components of edges
    visited = set()
    boundary_lines = []
    for vertex in adjacency_list:
        if vertex not in visited:
            stack = [vertex]
            boundary_line = []
            while stack:
                current = stack.pop()
                if current not in visited:
                    visited.add(current)
                    boundary_line.append(current)
                    for neighbor in adjacency_list[current]:
                        if neighbor not in visited:
                            stack.append(neighbor)
            boundary_lines.append(boundary_line)
    
    # Calculate the length of each boundary line and sort by length
    boundary_lines = sorted(boundary_lines, key=lambda line: sum(np.linalg.norm(vertices[line[i]] - vertices[line[i + 1]]) for i in range(len(line) - 1)), reverse=True)
    return boundary_lines

# 绘制带有分类标签的点云和分界线
def plot_surface_with_marks(vertices, faces, labels, part1, part2, view_angles=(30, 30), angles=(0, 0, 0)):
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')

    vertices = np.array(vertices)
    faces = np.array(faces)

    # Apply rotation
    vertices = rotate_points(vertices, angles)
    
    x, y, z = vertices.T

    try:
        # 标记分割的点云部分
        part1_faces = [face for face in faces if sum(labels[vertex] == 0 for vertex in face) > 1]
        part2_faces = [face for face in faces if sum(labels[vertex] == 1 for vertex in face) > 1]
        
        part1_faces = np.array(part1_faces)
        part2_faces = np.array(part2_faces)
        
        if len(part1_faces) > 0:
            ax.plot_trisurf(vertices[:, 0], vertices[:, 1], vertices[:, 2], triangles=part1_faces, color='cornflowerblue', alpha=0.6)
        if len(part2_faces) > 0:
            ax.plot_trisurf(vertices[:, 0], vertices[:, 1], vertices[:, 2], triangles=part2_faces, color='honeydew', alpha=0.6)

        # 找到边界线并绘制最长的边界线
        boundary_lines = find_boundary_edges(vertices, faces, labels)
        if boundary_lines:
            longest_boundary_line = boundary_lines[0]
            ax.plot(vertices[longest_boundary_line, 0], vertices[longest_boundary_line, 1], vertices[longest_boundary_line, 2], color='red')
            
    except ValueError as e:
        print(f"ValueError: {e}")
        return

    # 设置标签和标题
    ax.set_xlabel('X axis')
    ax.set_ylabel('Y axis')
    ax.set_zlabel('Z axis')
    ax.set_title('3D Model with Segmentation and Boundary Lines')

    # 确保坐标轴刻度一致
    max_range = np.array([max(x)-min(x), max(y)-min(y), max(z)-min(z)]).max()
    mid_x = (max(x) + min(x)) * 0.5
    mid_y = (max(y) + min(y)) * 0.5
    mid_z = (max(z) + min(z)) * 0.5
    ax.set_xlim(mid_x - max_range/2, mid_x + max_range/2)
    ax.set_ylim(mid_y - max_range/2, mid_y + max_range/2)
    ax.set_zlim(mid_z - max_range/2, mid_z + max_range/2)

    # 设置视角
    elev, azim = view_angles
    ax.view_init(elev=elev, azim=azim)  # Adjust these values as needed

    # 确保坐标轴比例相等
    ax.set_box_aspect([1,1,1])  # Aspect ratio is 1:1:1

    # 启用交互式旋转
    plt.show()

# 加载点云数据
obj_file_path = r'D:/BaiduSyncdisk/新建文件夹/桌面文件/深度学习程序/肩台外侧点_0715/150颗/60.obj'
vertices, faces = load_obj_file(obj_file_path)
centered_vertices = center_vertices(vertices)

# 将点云转换为体素网格
grid_size = 16  # Ensure grid size matches model requirements
voxel_grid, min_coords, voxel_dim = create_voxel_grid(np.array(centered_vertices), grid_size)

# 使用训练好的模型进行预测
predicted_labels = get_labels_from_model(model, voxel_grid)

# 获取原始点云的预测标签
predicted_point_labels = apply_labels_to_point_cloud(np.array(centered_vertices), predicted_labels, min_coords, voxel_dim, grid_size)

# 定义分割的部分（需要根据实际情况定义）
part1 = {i for i, label in enumerate(predicted_point_labels) if label == 0}
part2 = {i for i, label in enumerate(predicted_point_labels) if label == 1}

# 画图
plot_surface_with_marks(centered_vertices, faces, predicted_point_labels, part1, part2, view_angles=(30, 30), angles=(np.radians(90), np.radians(-30), np.radians(30)))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# <div id='5dcdd050-f1aa-4d7e-9461-84f47e37bd20'></div>
