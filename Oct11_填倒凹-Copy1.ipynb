# %%
'''
找就位道、计算倒凹、填倒凹
'''

import os

# 获取当前工作目录
current_dir = os.getcwd()
print("当前工作目录：", current_dir)

# 修改当前工作目录，以后输出文件只需要写文件名
new_dir = "D:/李娅宁/9月下旬项目重开"
os.chdir(new_dir)
print("修改后的工作目录：", os.getcwd())

obj_file_path = "150颗0806新数据/3.obj"
txt_file_path = "多分类预处理0929/预处理结果文档/3.txt"
# Out:
# 当前工作目录： C:\Users\HP
# 修改后的工作目录： D:\李娅宁\9月下旬项目重开

# %%
# 1.准备数据
import chardet
import numpy as np

def detect_encoding(file_path):
    '''检测文件的encoding方式'''
    with open(file_path, 'rb') as file:
        raw_data = file.read()
        result = chardet.detect(raw_data)
        return result['encoding']
        
def load_obj_file(file_path, encoding):
    '''读取obj文件中的点云坐标，输出是list'''
    vertices = []
    faces = []
    try:
        with open(file_path, 'r', encoding=encoding) as file:
            for line in file:
                if line.startswith('v '):
                    parts = line.strip().split()
                    vertex = [float(parts[1]), float(parts[2]), float(parts[3])]
                    vertices.append(vertex)
                elif line.startswith('f '):
                    parts = line.strip().split()
                    face = [int(p.split('/')[0]) - 1 for p in parts[1:]]
                    faces.append(face)
    except FileNotFoundError:
        print(f"文件未找到: {file_path}")
    except Exception as e:
        print(f"发生错误: {e}")
    return vertices, faces

def insert_midpoint_points(vertices, faces, minimum_vertices_number=3000):
    if len(vertices) >= minimum_vertices_number:
        print('原始点云的点数足够多')
        return vertices, faces

    else:
        temp = 0
        while len(vertices) < minimum_vertices_number:
            edge_to_midpoint = {}
            new_points = []
            new_faces = []
            vertex_offset = len(vertices)
    
            for face in faces:
                # Compute midpoints for each edge
                midpoints = []
                for i in range(len(face)):
                    edge = tuple(sorted((face[i], face[(i + 1) % len(face)])))
                    if edge not in edge_to_midpoint:
                        midpoint = np.mean([vertices[edge[0]], vertices[edge[1]]], axis=0)
                        edge_to_midpoint[edge] = vertex_offset + len(new_points)
                        new_points.append(midpoint.tolist())
                    midpoints.append(edge_to_midpoint[edge])
                
                # Original vertices
                v0, v1, v2 = face
                # Midpoints
                m0, m1, m2 = midpoints

                # Create four new faces
                new_faces.append([v0, m0, m2])
                new_faces.append([v1, m1, m0])
                new_faces.append([v2, m2, m1])
                new_faces.append([m0, m1, m2])
    
            vertices.extend(new_points)
            faces = new_faces
            temp += 1

        print(f'使用了 {temp} 轮插值来让点云点数满足要求')
        
    return vertices, faces

def load_labeled_point_cloud(file_path):
    '''读取点云数据和标签'''
    data = []
    labels = []
    with open(file_path, 'r', encoding='utf-8') as file:
        for line in file:
            parts = line.strip().split()
            if len(parts) == 4:
                x, y, z, label = map(float, parts)
                data.append([x, y, z])
                labels.append(int(label))
    return np.array(data), np.array(labels)

# %%
import open3d as o3d
import numpy as np
from tqdm import tqdm
from scipy.spatial import KDTree

# Möller–Trumbore算法检测射线与三角形相交
def ray_triangle_intersection(ray_origin, ray_direction, triangle):
    EPSILON = 1e-6  # 用于避免浮点数误差

    vertex0, vertex1, vertex2 = triangle
    
    # 计算三角形的两个边
    edge1 = vertex1 - vertex0
    edge2 = vertex2 - vertex0

    # 计算叉积
    h = np.cross(ray_direction, edge2)
    a = np.dot(edge1, h)

    if -EPSILON < a < EPSILON:
        return False, None  # 射线与三角形平行

    f = 1.0 / a
    s = ray_origin - vertex0
    u = f * np.dot(s, h)

    if u < 0.0 or u > 1.0:
        return False, None

    q = np.cross(s, edge1)
    v = f * np.dot(ray_direction, q)

    if v < 0.0 or u + v > 1.0:
        return False, None

    # 计算 t 以确定交点位置
    t = f * np.dot(edge2, q)

    if t > EPSILON:
        intersection_point = ray_origin + ray_direction * t
        return True, intersection_point

    return False, None  # 射线在三角形平面上但没有相交


# 使用KD-tree和射线投影检测单个方向上的倒凹区域
def detect_undercut_in_direction_with_kdtree(point_cloud, crown_indices, triangles, ray_direction, kdtree, k_nearest=10):
    undercut_points = []

    # 使用 tqdm 创建进度条，遍历 crown_indices
    for i, point in tqdm(enumerate(point_cloud[crown_indices]), total=len(crown_indices), desc="Processing points"):
        is_undercut = False

        # 使用KD-tree找到距离该点最近的三角形顶点索引
        distances, indices = kdtree.query(point, k=k_nearest)

        # 遍历这些邻近的三角形
        for idx in indices:
            tri_idx = triangles[idx]
            triangle = point_cloud[tri_idx]
            
            # 使用Möller–Trumbore算法判断射线与三角形相交
            intersect, _ = ray_triangle_intersection(point, ray_direction, triangle)
            
            if intersect:
                is_undercut = True
                break  # 一旦有相交就可以停止检测

        # 如果检测到相交，说明当前点是倒凹点
        if is_undercut:
            undercut_points.append(point)

    return np.array(undercut_points)


# 生成多个方向，遍历所有方向找到最优方向
def find_optimal_insertion_direction_with_kdtree(point_cloud, crown_indices, triangles, kdtree, n_directions=500, k_nearest=10):
    min_undercut_points = None
    optimal_direction = None
    min_undercut_count = float('inf')

    # 随机生成多个方向
    directions = np.random.randn(n_directions, 3)
    directions = directions / np.linalg.norm(directions, axis=1)[:, np.newaxis]  # 归一化

    # 使用 tqdm 创建方向遍历进度条
    for direction in tqdm(directions, desc="Processing directions"):
        undercut_points = detect_undercut_in_direction_with_kdtree(point_cloud, crown_indices, triangles, direction, kdtree, k_nearest)

        if len(undercut_points) < min_undercut_count:
            min_undercut_count = len(undercut_points)
            min_undercut_points = undercut_points
            optimal_direction = direction

    return optimal_direction, min_undercut_points, min_undercut_count


# 可视化倒凹点和点云
def visualize_undercut(point_cloud, undercut_points, ray_direction):
    # 创建Open3D点云对象
    pcd = o3d.geometry.PointCloud()
    pcd.points = o3d.utility.Vector3dVector(point_cloud)
    
    # 检查undercut_points是否为空或形状不对
    if undercut_points is None or len(undercut_points) == 0:
        print("No undercut points to visualize.")
        return
    elif len(undercut_points.shape) != 2 or undercut_points.shape[1] != 3:
        raise ValueError("Undercut points must be a (n, 3) shaped array.")
    
    # 创建用于表示倒凹区域的点云
    undercut_pcd = o3d.geometry.PointCloud()
    undercut_pcd.points = o3d.utility.Vector3dVector(undercut_points)
    
    # 将点云颜色设为浅蓝色，倒凹区域设为红色
    pcd.paint_uniform_color([0.6, 0.8, 1.0])
    undercut_pcd.paint_uniform_color([1.0, 0.0, 0.0])
    
    # 可视化就位道方向
    axis = o3d.geometry.TriangleMesh.create_coordinate_frame(size=10, origin=[0, 0, 0])
    
    # 创建用于表示就位道方向的虚线箭头
    ray_origin = np.array([0, 0, 0])
    ray_end = ray_origin + ray_direction * 10  # 延长射线以便可视化
    line_set = o3d.geometry.LineSet(
        points=o3d.utility.Vector3dVector([ray_origin, ray_end]),
        lines=o3d.utility.Vector2iVector([[0, 1]])
    )
    line_set.paint_uniform_color([0, 0, 0])  # 设置为黑色
    
    # 显示点云、倒凹和方向箭头
    o3d.visualization.draw_geometries([pcd, undercut_pcd, line_set, axis])


# 测试代码
if __name__ == "__main__":
    # 1. 加载或生成点云和三角面片数据
    obj_encoding = detect_encoding(obj_file_path)
    obj_vertices, obj_faces = load_obj_file(obj_file_path, obj_encoding)
    checked_vertices, faces = insert_midpoint_points(obj_vertices, obj_faces, 5000)  # 对点数小于5000的点云做插值加密
    vertices, labels = load_labeled_point_cloud(txt_file_path)
    crown_idx = [idx for idx in range(len(labels)) if labels[idx]!=1]

    point_cloud = vertices
    triangles = np.array(faces)
    crown_indices = np.array(crown_idx)
    
    # 2. 构建KD-Tree
    kdtree = KDTree(point_cloud)

    # 3. 遍历多个方向并找到最优的插入方向
    optimal_direction, optimal_undercut_points, undercut_count = find_optimal_insertion_direction_with_kdtree(
        point_cloud, crown_indices, triangles, kdtree, n_directions=5, k_nearest=10
    )

    print(f"Optimal insertion direction: {optimal_direction}")
    print(f"Number of undercut points: {undercut_count}")

    # 4. 可视化倒凹区域和点云
    visualize_undercut(point_cloud, optimal_undercut_points, optimal_direction)
# Out:
# 使用了 1 轮插值来让点云点数满足要求
# Processing directions:   0%|                                                                    | 0/20 [00:00<?, ?it/s]
# Processing points:   0%|                                                                      | 0/5031 [00:00<?, ?it/s]
# Processing points:   1%|▋                                                           | 57/5031 [00:00<00:08, 561.55it/s]
# Processing points:   2%|█▎                                                         | 114/5031 [00:00<00:09, 525.47it/s]
# Processing points:   4%|██                                                         | 181/5031 [00:00<00:08, 587.15it/s]
# Processing points:   5%|██▊                                                        | 241/5031 [00:00<00:08, 552.89it/s]
# Processing points:   6%|███▍                                                       | 297/5031 [00:00<00:08, 546.92it/s]
# Processing points:   7%|████▏                                                      | 353/5031 [00:00<00:08, 549.83it/s]
# Processing points:   8%|████▊                                                      | 411/5031 [00:00<00:08, 558.00it/s]
# Processing points:   9%|█████▍                                                     | 467/5031 [00:00<00:08, 548.38it/s]
# Processing points:  10%|██████▏                                                    | 524/5031 [00:00<00:08, 551.90it/s]
# Processing points:  12%|██████▊                                                    | 580/5031 [00:01<00:08, 531.92it/s]
# Processing points:  13%|███████▍                                                   | 637/5031 [00:01<00:08, 542.33it/s]
# Processing points:  14%|████████▏                                                  | 699/5031 [00:01<00:07, 563.45it/s]
# Processing points:  15%|████████▊                                                  | 756/5031 [00:01<00:07, 549.93it/s]
# Processing points:  16%|█████████▌                                                 | 812/5031 [00:01<00:07, 547.96it/s]
# Processing points:  17%|██████████▏                                                | 872/5031 [00:01<00:07, 560.10it/s]
# Processing points:  19%|██████████▉                                                | 933/5031 [00:01<00:07, 573.59it/s]
# Processing points:  20%|███████████▋                                               | 993/5031 [00:01<00:06, 580.58it/s]
# Processing points:  21%|████████████▏                                             | 1052/5031 [00:01<00:06, 573.30it/s]
# Processing points:  22%|████████████▊                                             | 1111/5031 [00:01<00:06, 578.06it/s]
# Processing points:  23%|█████████████▍                                            | 1169/5031 [00:02<00:06, 570.77it/s]
# Processing points:  24%|██████████████▏                                           | 1227/5031 [00:02<00:06, 554.15it/s]
# Processing points:  26%|██████████████▊                                           | 1283/5031 [00:02<00:06, 545.82it/s]
# Processing points:  27%|███████████████▍                                          | 1343/5031 [00:02<00:06, 561.35it/s]
# Processing points:  28%|████████████████▏                                         | 1400/5031 [00:02<00:06, 547.86it/s]
# Processing points:  29%|████████████████▊                                         | 1459/5031 [00:02<00:06, 556.89it/s]
# Processing points:  30%|█████████████████▌                                        | 1518/5031 [00:02<00:06, 565.60it/s]
# Processing points:  31%|██████████████████▏                                       | 1576/5031 [00:02<00:06, 568.29it/s]
# Processing points:  32%|██████████████████▊                                       | 1633/5031 [00:02<00:06, 562.43it/s]
# Processing points:  34%|███████████████████▍                                      | 1690/5031 [00:03<00:06, 534.54it/s]
# Processing points:  35%|████████████████████▏                                     | 1748/5031 [00:03<00:06, 546.72it/s]
# Processing points:  36%|████████████████████▊                                     | 1803/5031 [00:03<00:05, 547.40it/s]
# Processing points:  37%|█████████████████████▍                                    | 1863/5031 [00:03<00:05, 562.43it/s]
# Processing points:  38%|██████████████████████▏                                   | 1920/5031 [00:03<00:05, 562.21it/s]
# Processing points:  39%|██████████████████████▊                                   | 1977/5031 [00:03<00:05, 550.33it/s]
# Processing points:  40%|███████████████████████▍                                  | 2037/5031 [00:03<00:05, 563.93it/s]
# Processing points:  42%|████████████████████████▏                                 | 2094/5031 [00:03<00:05, 555.92it/s]
# Processing points:  43%|████████████████████████▊                                 | 2153/5031 [00:03<00:05, 565.06it/s]
# Processing points:  44%|█████████████████████████▍                                | 2210/5031 [00:03<00:05, 550.24it/s]
# Processing points:  45%|██████████████████████████▏                               | 2272/5031 [00:04<00:04, 567.32it/s]
# Processing points:  46%|██████████████████████████▊                               | 2331/5031 [00:04<00:04, 572.94it/s]
# Processing points:  48%|███████████████████████████▌                              | 2395/5031 [00:04<00:04, 590.59it/s]
# Processing points:  49%|████████████████████████████▎                             | 2455/5031 [00:04<00:04, 579.23it/s]
# Processing points:  50%|████████████████████████████▉                             | 2514/5031 [00:04<00:04, 566.33it/s]
# Processing points:  51%|█████████████████████████████▋                            | 2571/5031 [00:04<00:04, 539.98it/s]
# Processing points:  52%|██████████████████████████████▎                           | 2629/5031 [00:04<00:04, 550.21it/s]
# Processing points:  53%|███████████████████████████████                           | 2689/5031 [00:04<00:04, 564.43it/s]
# Processing points:  55%|███████████████████████████████▋                          | 2753/5031 [00:04<00:03, 583.89it/s]
# Processing points:  56%|████████████████████████████████▍                         | 2813/5031 [00:05<00:03, 586.12it/s]
# Processing points:  57%|█████████████████████████████████                         | 2872/5031 [00:05<00:03, 582.41it/s]
# Processing points:  58%|█████████████████████████████████▊                        | 2933/5031 [00:05<00:03, 587.73it/s]
# Processing points:  59%|██████████████████████████████████▍                       | 2992/5031 [00:05<00:03, 580.91it/s]
# Processing points:  61%|███████████████████████████████████▏                      | 3051/5031 [00:05<00:03, 578.22it/s]
# Processing points:  62%|███████████████████████████████████▉                      | 3113/5031 [00:05<00:03, 588.79it/s]
# Processing points:  63%|████████████████████████████████████▌                     | 3172/5031 [00:05<00:03, 584.40it/s]
# Processing points:  64%|█████████████████████████████████████▏                    | 3231/5031 [00:05<00:03, 507.89it/s]
# Processing points:  66%|█████████████████████████████████████▉                    | 3296/5031 [00:05<00:03, 543.92it/s]
# Processing points:  67%|██████████████████████████████████████▋                   | 3358/5031 [00:05<00:02, 564.84it/s]
# Processing points:  68%|███████████████████████████████████████▍                  | 3421/5031 [00:06<00:02, 581.69it/s]
# Processing points:  69%|████████████████████████████████████████▏                 | 3481/5031 [00:06<00:02, 547.86it/s]
# Processing points:  70%|████████████████████████████████████████▊                 | 3537/5031 [00:06<00:02, 542.61it/s]
# Processing points:  71%|█████████████████████████████████████████▍                | 3597/5031 [00:06<00:02, 556.30it/s]
# Processing points:  73%|██████████████████████████████████████████▏               | 3654/5031 [00:06<00:02, 550.58it/s]
# Processing points:  74%|██████████████████████████████████████████▊               | 3710/5031 [00:06<00:02, 539.06it/s]
# Processing points:  75%|███████████████████████████████████████████▌              | 3774/5031 [00:06<00:02, 566.86it/s]
# Processing points:  76%|████████████████████████████████████████████▏             | 3832/5031 [00:06<00:02, 556.49it/s]
# Processing points:  77%|████████████████████████████████████████████▉             | 3893/5031 [00:06<00:01, 571.46it/s]
# Processing points:  79%|█████████████████████████████████████████████▌            | 3955/5031 [00:07<00:01, 583.26it/s]
# Processing points:  80%|██████████████████████████████████████████████▎           | 4014/5031 [00:07<00:01, 584.03it/s]
# Processing points:  81%|██████████████████████████████████████████████▉           | 4073/5031 [00:07<00:01, 576.91it/s]
# Processing points:  82%|███████████████████████████████████████████████▌          | 4131/5031 [00:07<00:01, 571.05it/s]
# Processing points:  83%|████████████████████████████████████████████████▎         | 4193/5031 [00:07<00:01, 584.92it/s]
# Processing points:  85%|█████████████████████████████████████████████████         | 4252/5031 [00:07<00:01, 581.47it/s]
# Processing points:  86%|█████████████████████████████████████████████████▋        | 4314/5031 [00:07<00:01, 591.88it/s]
# Processing points:  87%|██████████████████████████████████████████████████▍       | 4374/5031 [00:07<00:01, 590.06it/s]
# Processing points:  88%|███████████████████████████████████████████████████       | 4434/5031 [00:07<00:01, 561.00it/s]
# Processing points:  89%|███████████████████████████████████████████████████▊      | 4491/5031 [00:07<00:00, 552.86it/s]
# Processing points:  90%|████████████████████████████████████████████████████▍     | 4547/5031 [00:08<00:00, 540.44it/s]
# Processing points:  92%|█████████████████████████████████████████████████████     | 4605/5031 [00:08<00:00, 550.62it/s]
# Processing points:  93%|█████████████████████████████████████████████████████▊    | 4667/5031 [00:08<00:00, 567.46it/s]
# Processing points:  94%|██████████████████████████████████████████████████████▌   | 4731/5031 [00:08<00:00, 588.01it/s]
# Processing points:  95%|███████████████████████████████████████████████████████▎  | 4793/5031 [00:08<00:00, 593.27it/s]
# Processing points:  96%|███████████████████████████████████████████████████████▉  | 4853/5031 [00:08<00:00, 580.59it/s]
# Processing points:  98%|████████████████████████████████████████████████████████▋ | 4912/5031 [00:08<00:00, 580.39it/s]
# Processing points:  99%|█████████████████████████████████████████████████████████▎| 4971/5031 [00:08<00:00, 580.98it/s]
# Processing points: 100%|██████████████████████████████████████████████████████████| 5031/5031 [00:08<00:00, 563.67it/s]
# Processing directions:   5%|███                                                         | 1/20 [00:08<02:49,  8.94s/it]
# Processing points:   0%|                                                                      | 0/5031 [00:00<?, ?it/s]
# Processing points:   1%|▋                                                           | 60/5031 [00:00<00:08, 589.26it/s]
# Processing points:   2%|█▍                                                         | 119/5031 [00:00<00:08, 555.99it/s]
# Processing points:   3%|██                                                         | 175/5031 [00:00<00:08, 546.87it/s]
# Processing points:   5%|██▋                                                        | 230/5031 [00:00<00:09, 520.44it/s]
# Processing points:   6%|███▍                                                       | 289/5031 [00:00<00:08, 543.06it/s]
# Processing points:   7%|████                                                       | 346/5031 [00:00<00:08, 548.75it/s]
# Processing points:   8%|████▋                                                      | 403/5031 [00:00<00:08, 554.53it/s]
# Processing points:   9%|█████▍                                                     | 467/5031 [00:00<00:07, 581.15it/s]
# Processing points:  10%|██████▏                                                    | 528/5031 [00:00<00:07, 587.96it/s]
# Processing points:  12%|██████▉                                                    | 587/5031 [00:01<00:07, 586.84it/s]
# Processing points:  13%|███████▌                                                   | 646/5031 [00:01<00:07, 573.17it/s]
# Processing points:  14%|████████▎                                                  | 704/5031 [00:01<00:07, 555.72it/s]
# Processing points:  15%|████████▉                                                  | 767/5031 [00:01<00:07, 577.10it/s]
# Processing points:  16%|█████████▋                                                 | 825/5031 [00:01<00:07, 564.74it/s]
# Processing points:  18%|██████████▎                                                | 882/5031 [00:01<00:07, 560.02it/s]
# Processing points:  19%|███████████                                                | 939/5031 [00:01<00:07, 549.84it/s]
# Processing points:  20%|███████████▋                                               | 995/5031 [00:01<00:07, 528.46it/s]
# Processing points:  21%|████████████▏                                             | 1054/5031 [00:01<00:07, 544.34it/s]
# Processing points:  22%|████████████▊                                             | 1109/5031 [00:02<00:07, 512.80it/s]
# Processing points:  23%|█████████████▍                                            | 1161/5031 [00:02<00:07, 506.45it/s]
# Processing points:  24%|█████████████▉                                            | 1213/5031 [00:02<00:07, 507.80it/s]
# Processing points:  25%|██████████████▋                                           | 1275/5031 [00:02<00:06, 538.46it/s]
# Processing points:  26%|███████████████▎                                          | 1330/5031 [00:02<00:06, 530.72it/s]
# Processing points:  28%|███████████████▉                                          | 1384/5031 [00:02<00:07, 508.17it/s]
# Processing points:  29%|████████████████▌                                         | 1438/5031 [00:02<00:06, 514.95it/s]
# Processing points:  30%|█████████████████▏                                        | 1495/5031 [00:02<00:06, 528.58it/s]
# Processing points:  31%|█████████████████▉                                        | 1552/5031 [00:02<00:06, 537.60it/s]
# Processing points:  32%|██████████████████▌                                       | 1606/5031 [00:02<00:06, 505.53it/s]
# Processing points:  33%|███████████████████▏                                      | 1664/5031 [00:03<00:06, 526.00it/s]
# Processing points:  34%|███████████████████▉                                      | 1732/5031 [00:03<00:05, 568.88it/s]
# Processing points:  36%|████████████████████▋                                     | 1792/5031 [00:03<00:05, 576.06it/s]
# Processing points:  37%|█████████████████████▎                                    | 1854/5031 [00:03<00:05, 587.55it/s]
# Processing points:  38%|██████████████████████                                    | 1914/5031 [00:03<00:05, 585.14it/s]
# Processing points:  39%|██████████████████████▊                                   | 1978/5031 [00:03<00:05, 600.02it/s]
# Processing points:  41%|███████████████████████▌                                  | 2039/5031 [00:03<00:05, 581.43it/s]
# Processing points:  42%|████████████████████████▏                                 | 2098/5031 [00:03<00:05, 558.06it/s]
# Processing points:  43%|████████████████████████▊                                 | 2155/5031 [00:03<00:05, 552.26it/s]
# Processing points:  44%|█████████████████████████▌                                | 2213/5031 [00:04<00:05, 557.14it/s]
# Processing points:  45%|██████████████████████████▏                               | 2269/5031 [00:04<00:04, 554.17it/s]
# Processing points:  46%|██████████████████████████▊                               | 2325/5031 [00:04<00:04, 550.77it/s]
# Processing points:  47%|███████████████████████████▍                              | 2385/5031 [00:04<00:04, 564.69it/s]
# Processing points:  49%|████████████████████████████▏                             | 2442/5031 [00:04<00:04, 556.01it/s]
# Processing points:  50%|████████████████████████████▊                             | 2498/5031 [00:04<00:04, 555.23it/s]
# Processing points:  51%|█████████████████████████████▌                            | 2559/5031 [00:04<00:04, 570.48it/s]
# Processing points:  52%|██████████████████████████████▏                           | 2617/5031 [00:04<00:04, 564.10it/s]
# Processing points:  53%|██████████████████████████████▊                           | 2674/5031 [00:04<00:04, 530.12it/s]
# Processing points:  54%|███████████████████████████████▍                          | 2729/5031 [00:04<00:04, 535.31it/s]
# Processing points:  55%|████████████████████████████████▏                         | 2788/5031 [00:05<00:04, 548.24it/s]
# Processing points:  57%|████████████████████████████████▊                         | 2844/5031 [00:05<00:04, 534.90it/s]
# Processing points:  58%|█████████████████████████████████▌                        | 2907/5031 [00:05<00:03, 560.95it/s]
# Processing points:  59%|██████████████████████████████████▏                       | 2964/5031 [00:05<00:03, 562.06it/s]
# Processing points:  60%|██████████████████████████████████▊                       | 3021/5031 [00:05<00:03, 561.51it/s]
# Processing points:  61%|███████████████████████████████████▍                      | 3078/5031 [00:05<00:03, 556.29it/s]
# Processing points:  62%|████████████████████████████████████▏                     | 3141/5031 [00:05<00:03, 574.79it/s]
# Processing points:  64%|████████████████████████████████████▉                     | 3199/5031 [00:05<00:03, 572.79it/s]
# Processing points:  65%|█████████████████████████████████████▌                    | 3259/5031 [00:05<00:03, 576.91it/s]
# Processing points:  66%|██████████████████████████████████████▏                   | 3317/5031 [00:05<00:02, 572.35it/s]
# Processing points:  67%|██████████████████████████████████████▉                   | 3375/5031 [00:06<00:02, 564.02it/s]
# Processing points:  68%|███████████████████████████████████████▌                  | 3432/5031 [00:06<00:02, 563.90it/s]
# Processing points:  69%|████████████████████████████████████████▏                 | 3489/5031 [00:06<00:02, 556.17it/s]
# Processing points:  70%|████████████████████████████████████████▊                 | 3545/5031 [00:06<00:02, 520.89it/s]
# Processing points:  72%|█████████████████████████████████████████▋                | 3616/5031 [00:06<00:02, 572.78it/s]
# Processing points:  73%|██████████████████████████████████████████▎               | 3674/5031 [00:06<00:02, 562.04it/s]
# Processing points:  74%|███████████████████████████████████████████               | 3731/5031 [00:06<00:02, 559.90it/s]
# Processing points:  75%|███████████████████████████████████████████▋              | 3788/5031 [00:06<00:02, 554.38it/s]
# Processing points:  76%|████████████████████████████████████████████▎             | 3844/5031 [00:06<00:02, 528.14it/s]
# Processing points:  77%|████████████████████████████████████████████▉             | 3898/5031 [00:07<00:02, 517.61it/s]
# Processing points:  79%|█████████████████████████████████████████████▋            | 3959/5031 [00:07<00:01, 540.71it/s]
# Processing points:  80%|██████████████████████████████████████████████▎           | 4017/5031 [00:07<00:01, 549.75it/s]
# Processing points:  81%|███████████████████████████████████████████████           | 4082/5031 [00:07<00:01, 578.46it/s]
# Processing points:  82%|███████████████████████████████████████████████▋          | 4141/5031 [00:07<00:01, 580.49it/s]
# Processing points:  84%|████████████████████████████████████████████████▌         | 4210/5031 [00:07<00:01, 611.24it/s]
# Processing points:  85%|█████████████████████████████████████████████████▎        | 4276/5031 [00:07<00:01, 624.24it/s]
# Processing points:  86%|██████████████████████████████████████████████████        | 4339/5031 [00:07<00:01, 623.50it/s]
# Processing points:  88%|██████████████████████████████████████████████████▊       | 4405/5031 [00:07<00:00, 630.92it/s]
# Processing points:  89%|███████████████████████████████████████████████████▌      | 4469/5031 [00:08<00:00, 591.75it/s]
# Processing points:  90%|████████████████████████████████████████████████████▏     | 4529/5031 [00:08<00:00, 581.57it/s]
# Processing points:  91%|████████████████████████████████████████████████████▉     | 4588/5031 [00:08<00:00, 576.21it/s]
# Processing points:  92%|█████████████████████████████████████████████████████▌    | 4646/5031 [00:08<00:00, 565.73it/s]
# Processing points:  93%|██████████████████████████████████████████████████████▏   | 4703/5031 [00:08<00:00, 560.69it/s]
# Processing points:  95%|██████████████████████████████████████████████████████▉   | 4760/5031 [00:08<00:00, 539.48it/s]
# Processing points:  96%|███████████████████████████████████████████████████████▌  | 4815/5031 [00:08<00:00, 514.67it/s]
# Processing points:  97%|████████████████████████████████████████████████████████  | 4868/5031 [00:08<00:00, 516.18it/s]
# Processing points:  98%|████████████████████████████████████████████████████████▋ | 4921/5031 [00:08<00:00, 517.70it/s]
# Processing points:  99%|█████████████████████████████████████████████████████████▍| 4977/5031 [00:08<00:00, 528.85it/s]
# Processing points: 100%|██████████████████████████████████████████████████████████| 5031/5031 [00:09<00:00, 552.42it/s]
# Processing directions:  10%|██████                                                      | 2/20 [00:18<02:42,  9.05s/it]
# Processing points:   0%|                                                                      | 0/5031 [00:00<?, ?it/s]
# Processing points:   1%|▋                                                           | 54/5031 [00:00<00:09, 536.80it/s]
# Processing points:   2%|█▎                                                         | 108/5031 [00:00<00:09, 527.82it/s]
# Processing points:   3%|█▉                                                         | 166/5031 [00:00<00:08, 546.59it/s]
# Processing points:   4%|██▌                                                        | 221/5031 [00:00<00:09, 531.87it/s]
# Processing points:   6%|███▎                                                       | 281/5031 [00:00<00:08, 554.24it/s]
# Processing points:   7%|███▉                                                       | 337/5031 [00:00<00:08, 543.66it/s]
# Processing points:   8%|████▌                                                      | 394/5031 [00:00<00:08, 551.79it/s]
# Processing points:   9%|█████▎                                                     | 450/5031 [00:00<00:08, 527.44it/s]
# Processing points:  10%|█████▉                                                     | 503/5031 [00:00<00:08, 513.27it/s]
# Processing points:  11%|██████▌                                                    | 557/5031 [00:01<00:08, 519.84it/s]
# Processing points:  12%|███████▏                                                   | 618/5031 [00:01<00:08, 543.93it/s]
# Processing points:  14%|████████                                                   | 685/5031 [00:01<00:07, 580.02it/s]
# Processing points:  15%|████████▋                                                  | 745/5031 [00:01<00:07, 585.19it/s]
# Processing points:  16%|█████████▍                                                 | 804/5031 [00:01<00:07, 564.97it/s]
# Processing points:  17%|██████████                                                 | 862/5031 [00:01<00:07, 568.71it/s]
# Processing points:  18%|██████████▊                                                | 923/5031 [00:01<00:07, 579.89it/s]
# Processing points:  20%|███████████▌                                               | 982/5031 [00:01<00:06, 579.42it/s]
# Processing points:  21%|████████████                                              | 1041/5031 [00:01<00:06, 572.67it/s]
# Processing points:  22%|████████████▋                                             | 1099/5031 [00:01<00:07, 547.01it/s]
# Processing points:  23%|█████████████▎                                            | 1154/5031 [00:02<00:07, 505.70it/s]
# Processing points:  24%|█████████████▉                                            | 1206/5031 [00:02<00:07, 492.43it/s]
# Processing points:  25%|██████████████▌                                           | 1268/5031 [00:02<00:07, 526.87it/s]
# Processing points:  27%|███████████████▍                                          | 1338/5031 [00:02<00:06, 574.51it/s]
# Processing points:  28%|████████████████▏                                         | 1404/5031 [00:02<00:06, 598.82it/s]
# Processing points:  29%|████████████████▉                                         | 1471/5031 [00:02<00:05, 617.45it/s]
# Processing points:  30%|█████████████████▋                                        | 1534/5031 [00:02<00:05, 620.92it/s]
# Processing points:  32%|██████████████████▍                                       | 1603/5031 [00:02<00:05, 638.93it/s]
# Processing points:  33%|███████████████████▏                                      | 1668/5031 [00:02<00:05, 618.40it/s]
# Processing points:  34%|███████████████████▉                                      | 1731/5031 [00:03<00:05, 588.93it/s]
# Processing points:  36%|████████████████████▋                                     | 1791/5031 [00:03<00:06, 486.93it/s]
# Processing points:  37%|█████████████████████▏                                    | 1843/5031 [00:03<00:06, 483.70it/s]
# Processing points:  38%|█████████████████████▊                                    | 1894/5031 [00:03<00:06, 489.43it/s]
# Processing points:  39%|██████████████████████▌                                   | 1962/5031 [00:03<00:05, 539.21it/s]
# Processing points:  40%|███████████████████████▎                                  | 2025/5031 [00:03<00:05, 563.15it/s]
# Processing points:  41%|████████████████████████                                  | 2084/5031 [00:03<00:05, 569.88it/s]
# Processing points:  43%|████████████████████████▋                                 | 2142/5031 [00:03<00:05, 567.61it/s]
# Processing points:  44%|█████████████████████████▍                                | 2203/5031 [00:03<00:04, 574.24it/s]
# Processing points:  45%|██████████████████████████                                | 2261/5031 [00:04<00:04, 557.35it/s]
# Processing points:  46%|██████████████████████████▋                               | 2318/5031 [00:04<00:05, 540.16it/s]
# Processing points:  47%|███████████████████████████▍                              | 2376/5031 [00:04<00:04, 550.31it/s]
# Processing points:  48%|████████████████████████████                              | 2437/5031 [00:04<00:04, 566.18it/s]
# Processing points:  50%|████████████████████████████▊                             | 2496/5031 [00:04<00:04, 570.65it/s]
# Processing points:  51%|█████████████████████████████▍                            | 2554/5031 [00:04<00:04, 536.48it/s]
# Processing points:  52%|██████████████████████████████                            | 2609/5031 [00:04<00:04, 539.59it/s]
# Processing points:  53%|██████████████████████████████▋                           | 2666/5031 [00:04<00:04, 547.80it/s]
# Processing points:  54%|███████████████████████████████▍                          | 2728/5031 [00:04<00:04, 567.45it/s]
# Processing points:  56%|████████████████████████████████▏                         | 2794/5031 [00:05<00:03, 593.66it/s]
# Processing points:  57%|████████████████████████████████▉                         | 2859/5031 [00:05<00:03, 608.85it/s]
# Processing points:  58%|█████████████████████████████████▋                        | 2924/5031 [00:05<00:03, 619.98it/s]
# Processing points:  59%|██████████████████████████████████▍                       | 2991/5031 [00:05<00:03, 634.24it/s]
# Processing points:  61%|███████████████████████████████████▏                      | 3057/5031 [00:05<00:03, 641.61it/s]
# Processing points:  62%|███████████████████████████████████▉                      | 3122/5031 [00:05<00:03, 633.43it/s]
# Processing points:  63%|████████████████████████████████████▋                     | 3186/5031 [00:05<00:03, 601.43it/s]
# Processing points:  65%|█████████████████████████████████████▍                    | 3247/5031 [00:05<00:02, 600.90it/s]
# Processing points:  66%|██████████████████████████████████████▏                   | 3308/5031 [00:05<00:02, 591.63it/s]
# Processing points:  67%|██████████████████████████████████████▊                   | 3368/5031 [00:05<00:02, 584.25it/s]
# Processing points:  68%|███████████████████████████████████████▌                  | 3427/5031 [00:06<00:02, 568.92it/s]
# Processing points:  69%|████████████████████████████████████████▏                 | 3485/5031 [00:06<00:02, 552.82it/s]
# Processing points:  70%|████████████████████████████████████████▊                 | 3541/5031 [00:06<00:02, 551.78it/s]
# Processing points:  72%|█████████████████████████████████████████▌                | 3603/5031 [00:06<00:02, 570.82it/s]
# Processing points:  73%|██████████████████████████████████████████▎               | 3666/5031 [00:06<00:02, 587.82it/s]
# Processing points:  74%|██████████████████████████████████████████▉               | 3725/5031 [00:06<00:02, 588.09it/s]
# Processing points:  75%|███████████████████████████████████████████▌              | 3784/5031 [00:06<00:02, 563.45it/s]
# Processing points:  76%|████████████████████████████████████████████▎             | 3845/5031 [00:06<00:02, 576.80it/s]
# Processing points:  78%|█████████████████████████████████████████████             | 3909/5031 [00:06<00:01, 594.90it/s]
# Processing points:  79%|█████████████████████████████████████████████▊            | 3969/5031 [00:07<00:01, 590.40it/s]
# Processing points:  80%|██████████████████████████████████████████████▍           | 4029/5031 [00:07<00:01, 569.55it/s]
# Processing points:  81%|███████████████████████████████████████████████           | 4087/5031 [00:07<00:01, 561.25it/s]
# Processing points:  83%|███████████████████████████████████████████████▊          | 4152/5031 [00:07<00:01, 585.66it/s]
# Processing points:  84%|████████████████████████████████████████████████▌         | 4216/5031 [00:07<00:01, 600.31it/s]
# Processing points:  85%|█████████████████████████████████████████████████▎        | 4280/5031 [00:07<00:01, 611.83it/s]
# Processing points:  86%|██████████████████████████████████████████████████▏       | 4348/5031 [00:07<00:01, 628.05it/s]
# Processing points:  88%|██████████████████████████████████████████████████▉       | 4415/5031 [00:07<00:00, 639.06it/s]
# Processing points:  89%|███████████████████████████████████████████████████▋      | 4480/5031 [00:07<00:00, 630.17it/s]
# Processing points:  90%|████████████████████████████████████████████████████▍     | 4544/5031 [00:07<00:00, 553.24it/s]
# Processing points:  91%|█████████████████████████████████████████████████████     | 4602/5031 [00:08<00:00, 556.95it/s]
# Processing points:  93%|█████████████████████████████████████████████████████▋    | 4662/5031 [00:08<00:00, 567.55it/s]
# Processing points:  94%|██████████████████████████████████████████████████████▍   | 4727/5031 [00:08<00:00, 590.60it/s]
# Processing points:  95%|███████████████████████████████████████████████████████▎  | 4794/5031 [00:08<00:00, 611.91it/s]
# Processing points:  97%|███████████████████████████████████████████████████████▉  | 4856/5031 [00:08<00:00, 613.86it/s]
# Processing points:  98%|████████████████████████████████████████████████████████▋ | 4918/5031 [00:08<00:00, 598.99it/s]
# Processing points: 100%|██████████████████████████████████████████████████████████| 5031/5031 [00:08<00:00, 571.64it/s]
# Processing directions:  15%|█████████                                                   | 3/20 [00:26<02:32,  8.94s/it]
# Processing points:   0%|                                                                      | 0/5031 [00:00<?, ?it/s]
# Processing points:   1%|▋                                                           | 61/5031 [00:00<00:08, 607.26it/s]
# Processing points:   2%|█▍                                                         | 122/5031 [00:00<00:08, 563.36it/s]
# Processing points:   4%|██                                                         | 179/5031 [00:00<00:08, 554.92it/s]
# Processing points:   5%|██▊                                                        | 235/5031 [00:00<00:08, 545.26it/s]
# Processing points:   6%|███▍                                                       | 290/5031 [00:00<00:08, 545.95it/s]
# Processing points:   7%|████                                                       | 345/5031 [00:00<00:08, 532.43it/s]
# Processing points:   8%|████▊                                                      | 412/5031 [00:00<00:08, 572.48it/s]
# Processing points:   9%|█████▌                                                     | 477/5031 [00:00<00:07, 593.41it/s]
# Processing points:  11%|██████▎                                                    | 541/5031 [00:00<00:07, 604.29it/s]
# Processing points:  12%|███████▏                                                   | 608/5031 [00:01<00:07, 623.79it/s]
# Processing points:  13%|███████▊                                                   | 671/5031 [00:01<00:07, 619.59it/s]
# Processing points:  15%|████████▌                                                  | 734/5031 [00:01<00:07, 610.76it/s]
# Processing points:  16%|█████████▎                                                 | 796/5031 [00:01<00:07, 586.11it/s]
# Processing points:  17%|██████████                                                 | 860/5031 [00:01<00:06, 599.97it/s]
# Processing points:  18%|██████████▊                                                | 921/5031 [00:01<00:06, 593.62it/s]
# Processing points:  19%|███████████▌                                               | 981/5031 [00:01<00:06, 580.48it/s]
# Processing points:  21%|███████████▉                                              | 1040/5031 [00:01<00:07, 567.74it/s]
# Processing points:  22%|████████████▋                                             | 1097/5031 [00:01<00:06, 568.23it/s]
# Processing points:  23%|█████████████▎                                            | 1155/5031 [00:01<00:06, 569.84it/s]
# Processing points:  24%|█████████████▉                                            | 1213/5031 [00:02<00:06, 566.51it/s]
# Processing points:  25%|██████████████▋                                           | 1270/5031 [00:02<00:06, 559.09it/s]
# Processing points:  26%|███████████████▎                                          | 1327/5031 [00:02<00:06, 560.50it/s]
# Processing points:  28%|███████████████▉                                          | 1386/5031 [00:02<00:06, 568.18it/s]
# Processing points:  29%|████████████████▋                                         | 1449/5031 [00:02<00:06, 583.08it/s]
# Processing points:  30%|█████████████████▍                                        | 1508/5031 [00:02<00:06, 583.66it/s]
# Processing points:  31%|██████████████████                                        | 1567/5031 [00:02<00:06, 545.27it/s]
# Processing points:  32%|██████████████████▋                                       | 1624/5031 [00:02<00:06, 550.94it/s]
# Processing points:  33%|███████████████████▎                                      | 1680/5031 [00:02<00:06, 550.19it/s]
# Processing points:  35%|████████████████████                                      | 1736/5031 [00:03<00:06, 505.08it/s]
# Processing points:  36%|████████████████████▋                                     | 1797/5031 [00:03<00:06, 533.68it/s]
# Processing points:  37%|█████████████████████▌                                    | 1865/5031 [00:03<00:05, 574.07it/s]
# Processing points:  38%|██████████████████████▏                                   | 1926/5031 [00:03<00:05, 582.81it/s]
# Processing points:  40%|██████████████████████▉                                   | 1993/5031 [00:03<00:05, 604.58it/s]
# Processing points:  41%|███████████████████████▋                                  | 2056/5031 [00:03<00:04, 610.07it/s]
# Processing points:  42%|████████████████████████▍                                 | 2122/5031 [00:03<00:04, 624.61it/s]
# Processing points:  43%|█████████████████████████▏                                | 2187/5031 [00:03<00:04, 630.92it/s]
# Processing points:  45%|█████████████████████████▉                                | 2251/5031 [00:03<00:04, 627.61it/s]
# Processing points:  46%|██████████████████████████▋                               | 2314/5031 [00:03<00:04, 622.55it/s]
# Processing points:  47%|███████████████████████████▍                              | 2377/5031 [00:04<00:04, 608.89it/s]
# Processing points:  48%|████████████████████████████                              | 2439/5031 [00:04<00:04, 585.73it/s]
# Processing points:  50%|████████████████████████████▊                             | 2498/5031 [00:04<00:04, 559.15it/s]
# Processing points:  51%|█████████████████████████████▍                            | 2555/5031 [00:04<00:04, 555.92it/s]
# Processing points:  52%|██████████████████████████████                            | 2611/5031 [00:04<00:04, 539.68it/s]
# Processing points:  53%|██████████████████████████████▋                           | 2667/5031 [00:04<00:04, 543.34it/s]
# Processing points:  54%|███████████████████████████████▍                          | 2729/5031 [00:04<00:04, 562.36it/s]
# Processing points:  55%|████████████████████████████████▏                         | 2792/5031 [00:04<00:03, 580.53it/s]
# Processing points:  57%|████████████████████████████████▉                         | 2856/5031 [00:04<00:03, 597.16it/s]
# Processing points:  58%|█████████████████████████████████▋                        | 2922/5031 [00:05<00:03, 615.55it/s]
# Processing points:  59%|██████████████████████████████████▍                       | 2991/5031 [00:05<00:03, 637.29it/s]
# Processing points:  61%|███████████████████████████████████▏                      | 3055/5031 [00:05<00:03, 630.08it/s]
# Processing points:  62%|████████████████████████████████████                      | 3124/5031 [00:05<00:02, 646.70it/s]
# Processing points:  63%|████████████████████████████████████▊                     | 3193/5031 [00:05<00:02, 658.38it/s]
# Processing points:  65%|█████████████████████████████████████▌                    | 3259/5031 [00:05<00:02, 641.71it/s]
# Processing points:  66%|██████████████████████████████████████▎                   | 3324/5031 [00:05<00:02, 637.23it/s]
# Processing points:  67%|███████████████████████████████████████                   | 3391/5031 [00:05<00:02, 644.57it/s]
# Processing points:  69%|███████████████████████████████████████▊                  | 3456/5031 [00:05<00:02, 627.96it/s]
# Processing points:  70%|████████████████████████████████████████▌                 | 3519/5031 [00:05<00:02, 627.35it/s]
# Processing points:  71%|█████████████████████████████████████████▎                | 3582/5031 [00:06<00:02, 611.35it/s]
# Processing points:  72%|██████████████████████████████████████████                | 3644/5031 [00:06<00:02, 585.61it/s]
# Processing points:  74%|██████████████████████████████████████████▋               | 3703/5031 [00:06<00:02, 576.32it/s]
# Processing points:  75%|███████████████████████████████████████████▎              | 3761/5031 [00:06<00:02, 554.24it/s]
# Processing points:  76%|████████████████████████████████████████████              | 3817/5031 [00:06<00:02, 520.03it/s]
# Processing points:  77%|████████████████████████████████████████████▋             | 3881/5031 [00:06<00:02, 551.43it/s]
# Processing points:  78%|█████████████████████████████████████████████▌            | 3949/5031 [00:06<00:01, 586.55it/s]
# Processing points:  80%|██████████████████████████████████████████████▏           | 4009/5031 [00:06<00:01, 573.02it/s]
# Processing points:  81%|██████████████████████████████████████████████▉           | 4067/5031 [00:06<00:01, 573.27it/s]
# Processing points:  82%|███████████████████████████████████████████████▌          | 4125/5031 [00:07<00:01, 566.11it/s]
# Processing points:  83%|████████████████████████████████████████████████▏         | 4182/5031 [00:07<00:01, 549.85it/s]
# Processing points:  84%|████████████████████████████████████████████████▊         | 4238/5031 [00:07<00:01, 545.01it/s]
# Processing points:  85%|█████████████████████████████████████████████████▍        | 4293/5031 [00:07<00:01, 541.27it/s]
# Processing points:  86%|██████████████████████████████████████████████████▏       | 4348/5031 [00:07<00:01, 531.70it/s]
# Processing points:  88%|██████████████████████████████████████████████████▊       | 4405/5031 [00:07<00:01, 542.46it/s]
# Processing points:  89%|███████████████████████████████████████████████████▍      | 4463/5031 [00:07<00:01, 553.20it/s]
# Processing points:  90%|████████████████████████████████████████████████████▏     | 4525/5031 [00:07<00:00, 572.70it/s]
# Processing points:  91%|████████████████████████████████████████████████████▉     | 4588/5031 [00:07<00:00, 589.33it/s]
# Processing points:  92%|█████████████████████████████████████████████████████▋    | 4652/5031 [00:07<00:00, 602.87it/s]
# Processing points:  94%|██████████████████████████████████████████████████████▍   | 4718/5031 [00:08<00:00, 618.14it/s]
# Processing points:  95%|███████████████████████████████████████████████████████▏  | 4787/5031 [00:08<00:00, 638.37it/s]
# Processing points:  96%|███████████████████████████████████████████████████████▉  | 4851/5031 [00:08<00:00, 623.91it/s]
# Processing points:  98%|████████████████████████████████████████████████████████▋ | 4914/5031 [00:08<00:00, 606.53it/s]
# Processing points: 100%|██████████████████████████████████████████████████████████| 5031/5031 [00:08<00:00, 582.89it/s]
# Processing directions:  20%|████████████                                                | 4/20 [00:35<02:21,  8.83s/it]
# Processing points:   0%|                                                                      | 0/5031 [00:00<?, ?it/s]
# Processing points:   1%|▊                                                           | 63/5031 [00:00<00:07, 621.84it/s]
# Processing points:   3%|█▌                                                         | 129/5031 [00:00<00:07, 640.39it/s]
# Processing points:   4%|██▎                                                        | 194/5031 [00:00<00:07, 612.78it/s]
# Processing points:   5%|███                                                        | 256/5031 [00:00<00:08, 592.64it/s]
# Processing points:   6%|███▋                                                       | 316/5031 [00:00<00:08, 567.57it/s]
# Processing points:   7%|████▎                                                      | 373/5031 [00:00<00:08, 549.14it/s]
# Processing points:   9%|█████                                                      | 429/5031 [00:00<00:08, 539.78it/s]
# Processing points:  10%|█████▋                                                     | 486/5031 [00:00<00:08, 547.53it/s]
# Processing points:  11%|██████▎                                                    | 541/5031 [00:00<00:08, 505.12it/s]
# Processing points:  12%|███████                                                    | 602/5031 [00:01<00:08, 532.03it/s]
# Processing points:  13%|███████▊                                                   | 670/5031 [00:01<00:07, 571.93it/s]
# Processing points:  14%|████████▌                                                  | 728/5031 [00:01<00:07, 573.52it/s]
# Processing points:  16%|█████████▏                                                 | 786/5031 [00:01<00:07, 559.71it/s]
# Processing points:  17%|█████████▉                                                 | 846/5031 [00:01<00:07, 569.06it/s]
# Processing points:  18%|██████████▋                                                | 911/5031 [00:01<00:06, 589.30it/s]
# Processing points:  19%|███████████▍                                               | 971/5031 [00:01<00:06, 592.07it/s]
# Processing points:  21%|███████████▉                                              | 1036/5031 [00:01<00:06, 609.13it/s]
# Processing points:  22%|████████████▋                                             | 1098/5031 [00:01<00:06, 598.34it/s]
# Processing points:  23%|█████████████▎                                            | 1158/5031 [00:02<00:06, 591.95it/s]
# Processing points:  24%|██████████████                                            | 1219/5031 [00:02<00:06, 596.41it/s]
# Processing points:  25%|██████████████▋                                           | 1279/5031 [00:02<00:06, 557.84it/s]
# Processing points:  27%|███████████████▍                                          | 1336/5031 [00:02<00:06, 556.96it/s]
# Processing points:  28%|████████████████                                          | 1393/5031 [00:02<00:06, 560.42it/s]
# Processing points:  29%|████████████████▋                                         | 1450/5031 [00:02<00:06, 563.09it/s]
# Processing points:  30%|█████████████████▎                                        | 1507/5031 [00:02<00:06, 544.53it/s]
# Processing points:  31%|██████████████████                                        | 1565/5031 [00:02<00:06, 552.71it/s]
# Processing points:  32%|██████████████████▋                                       | 1621/5031 [00:02<00:06, 536.60it/s]
# Processing points:  33%|███████████████████▎                                      | 1675/5031 [00:02<00:06, 520.78it/s]
# Processing points:  34%|███████████████████▉                                      | 1728/5031 [00:03<00:06, 508.18it/s]
# Processing points:  36%|████████████████████▌                                     | 1789/5031 [00:03<00:06, 534.43it/s]
# Processing points:  37%|█████████████████████▏                                    | 1843/5031 [00:03<00:05, 535.50it/s]
# Processing points:  38%|█████████████████████▉                                    | 1898/5031 [00:03<00:05, 538.39it/s]
# Processing points:  39%|██████████████████████▌                                   | 1954/5031 [00:03<00:05, 544.09it/s]
# Processing points:  40%|███████████████████████▏                                  | 2009/5031 [00:03<00:05, 539.13it/s]
# Processing points:  41%|███████████████████████▊                                  | 2063/5031 [00:03<00:05, 501.78it/s]
# Processing points:  42%|████████████████████████▍                                 | 2123/5031 [00:03<00:05, 528.30it/s]
# Processing points:  43%|█████████████████████████▏                                | 2181/5031 [00:03<00:05, 541.88it/s]
# Processing points:  45%|█████████████████████████▊                                | 2244/5031 [00:04<00:04, 566.61it/s]
# Processing points:  46%|██████████████████████████▌                               | 2302/5031 [00:04<00:04, 566.37it/s]
# Processing points:  47%|███████████████████████████▎                              | 2370/5031 [00:04<00:04, 599.38it/s]
# Processing points:  48%|████████████████████████████                              | 2437/5031 [00:04<00:04, 620.19it/s]
# Processing points:  50%|████████████████████████████▊                             | 2500/5031 [00:04<00:04, 608.47it/s]
# Processing points:  51%|█████████████████████████████▌                            | 2565/5031 [00:04<00:03, 617.87it/s]
# Processing points:  52%|██████████████████████████████▎                           | 2627/5031 [00:04<00:03, 607.27it/s]
# Processing points:  53%|██████████████████████████████▉                           | 2688/5031 [00:04<00:03, 587.42it/s]
# Processing points:  55%|███████████████████████████████▋                          | 2748/5031 [00:04<00:03, 590.51it/s]
# Processing points:  56%|████████████████████████████████▎                         | 2808/5031 [00:04<00:03, 580.33it/s]
# Processing points:  57%|█████████████████████████████████                         | 2867/5031 [00:05<00:03, 572.61it/s]
# Processing points:  58%|█████████████████████████████████▋                        | 2925/5031 [00:05<00:03, 556.92it/s]
# Processing points:  59%|██████████████████████████████████▍                       | 2982/5031 [00:05<00:03, 560.60it/s]
# Processing points:  60%|███████████████████████████████████                       | 3039/5031 [00:05<00:03, 561.56it/s]
# Processing points:  62%|███████████████████████████████████▋                      | 3096/5031 [00:05<00:03, 550.50it/s]
# Processing points:  63%|████████████████████████████████████▎                     | 3152/5031 [00:05<00:03, 545.14it/s]
# Processing points:  64%|████████████████████████████████████▉                     | 3207/5031 [00:05<00:03, 531.42it/s]
# Processing points:  65%|█████████████████████████████████████▊                    | 3275/5031 [00:05<00:03, 573.95it/s]
# ...
# Processing points:  43%|████████████████████████▉                                 | 2159/5031 [00:03<00:04, 581.31it/s]
# Processing points:  44%|█████████████████████████▌                                | 2218/5031 [00:03<00:05, 546.29it/s]
# Processing points:  45%|██████████████████████████▏                               | 2274/5031 [00:04<00:05, 520.12it/s]
# Processing points:  46%|██████████████████████████▉                               | 2332/5031 [00:04<00:05, 534.16it/s]
# Processing points:  47%|███████████████████████████▌                              | 2386/5031 [00:04<00:05, 522.27it/s]
# Processing points:  49%|████████████████████████████▎                             | 2456/5031 [00:04<00:04, 569.55it/s]
# Processing points:  50%|█████████████████████████████                             | 2516/5031 [00:04<00:04, 578.19it/s]
# Processing points:  51%|█████████████████████████████▊                            | 2583/5031 [00:04<00:04, 604.66it/s]
# Processing points:  53%|██████████████████████████████▍                           | 2644/5031 [00:04<00:04, 548.78it/s]
# Processing points:  54%|███████████████████████████████▏                          | 2705/5031 [00:04<00:04, 564.77it/s]
# Processing points:  55%|███████████████████████████████▊                          | 2763/5031 [00:04<00:04, 565.59it/s]
# Processing points:  56%|████████████████████████████████▌                         | 2828/5031 [00:04<00:03, 587.84it/s]
# Processing points:  57%|█████████████████████████████████▎                        | 2888/5031 [00:05<00:03, 581.23it/s]
# Processing points:  59%|█████████████████████████████████▉                        | 2947/5031 [00:05<00:03, 556.04it/s]
# Processing points:  60%|██████████████████████████████████▋                       | 3004/5031 [00:05<00:03, 547.24it/s]
# Processing points:  61%|███████████████████████████████████▎                      | 3060/5031 [00:05<00:04, 479.03it/s]
# Processing points:  62%|███████████████████████████████████▉                      | 3120/5031 [00:05<00:03, 506.42it/s]
# Processing points:  63%|████████████████████████████████████▋                     | 3183/5031 [00:05<00:03, 537.84it/s]
# Processing points:  64%|█████████████████████████████████████▎                    | 3239/5031 [00:05<00:03, 543.67it/s]
# Processing points:  66%|██████████████████████████████████████                    | 3303/5031 [00:05<00:03, 569.97it/s]
# Processing points:  67%|██████████████████████████████████████▋                   | 3361/5031 [00:05<00:03, 536.14it/s]
# Processing points:  68%|███████████████████████████████████████▍                  | 3416/5031 [00:06<00:03, 524.91it/s]
# Processing points:  69%|████████████████████████████████████████                  | 3470/5031 [00:06<00:03, 499.40it/s]
# Processing points:  70%|████████████████████████████████████████▊                 | 3538/5031 [00:06<00:02, 547.06it/s]
# Processing points:  71%|█████████████████████████████████████████▍                | 3594/5031 [00:06<00:02, 534.34it/s]
# Processing points:  73%|██████████████████████████████████████████▏               | 3662/5031 [00:06<00:02, 574.31it/s]
# Processing points:  74%|██████████████████████████████████████████▉               | 3725/5031 [00:06<00:02, 588.79it/s]
# Processing points:  75%|███████████████████████████████████████████▋              | 3785/5031 [00:06<00:02, 577.10it/s]
# Processing points:  76%|████████████████████████████████████████████▎             | 3844/5031 [00:06<00:02, 573.08it/s]
# Processing points:  78%|████████████████████████████████████████████▉             | 3902/5031 [00:06<00:02, 533.23it/s]
# Processing points:  79%|█████████████████████████████████████████████▋            | 3964/5031 [00:07<00:01, 556.45it/s]
# Processing points:  80%|██████████████████████████████████████████████▎           | 4021/5031 [00:07<00:01, 538.71it/s]
# Processing points:  81%|███████████████████████████████████████████████▏          | 4093/5031 [00:07<00:01, 589.16it/s]
# Processing points:  83%|███████████████████████████████████████████████▉          | 4153/5031 [00:07<00:01, 555.44it/s]
# Processing points:  84%|████████████████████████████████████████████████▌         | 4210/5031 [00:07<00:01, 547.44it/s]
# Processing points:  85%|█████████████████████████████████████████████████▏        | 4266/5031 [00:07<00:01, 493.52it/s]
# Processing points:  86%|█████████████████████████████████████████████████▊        | 4326/5031 [00:07<00:01, 520.24it/s]
# Processing points:  87%|██████████████████████████████████████████████████▌       | 4385/5031 [00:07<00:01, 538.44it/s]
# Processing points:  88%|███████████████████████████████████████████████████▏      | 4440/5031 [00:07<00:01, 509.14it/s]
# Processing points:  90%|███████████████████████████████████████████████████▉      | 4505/5031 [00:08<00:00, 545.46it/s]
# Processing points:  91%|████████████████████████████████████████████████████▌     | 4561/5031 [00:08<00:00, 539.14it/s]
# Processing points:  92%|█████████████████████████████████████████████████████▍    | 4632/5031 [00:08<00:00, 587.08it/s]
# Processing points:  93%|██████████████████████████████████████████████████████    | 4692/5031 [00:08<00:00, 577.05it/s]
# Processing points:  94%|██████████████████████████████████████████████████████▊   | 4753/5031 [00:08<00:00, 586.32it/s]
# Processing points:  96%|███████████████████████████████████████████████████████▍  | 4813/5031 [00:08<00:00, 518.89it/s]
# Processing points:  97%|████████████████████████████████████████████████████████  | 4867/5031 [00:08<00:00, 524.44it/s]
# Processing points:  98%|████████████████████████████████████████████████████████▊ | 4929/5031 [00:08<00:00, 550.74it/s]
# Processing points: 100%|██████████████████████████████████████████████████████████| 5031/5031 [00:09<00:00, 556.15it/s]
# Processing directions:  95%|████████████████████████████████████████████████████████   | 19/20 [02:50<00:08,  9.00s/it]
# Processing points:   0%|                                                                      | 0/5031 [00:00<?, ?it/s]
# Processing points:   1%|▋                                                           | 59/5031 [00:00<00:08, 583.77it/s]
# Processing points:   2%|█▍                                                         | 123/5031 [00:00<00:08, 612.65it/s]
# Processing points:   4%|██▏                                                        | 186/5031 [00:00<00:07, 614.51it/s]
# Processing points:   5%|██▉                                                        | 248/5031 [00:00<00:07, 602.86it/s]
# Processing points:   6%|███▋                                                       | 318/5031 [00:00<00:07, 636.44it/s]
# Processing points:   8%|████▍                                                      | 382/5031 [00:00<00:07, 595.67it/s]
# Processing points:   9%|█████▎                                                     | 448/5031 [00:00<00:07, 615.12it/s]
# Processing points:  10%|█████▉                                                     | 510/5031 [00:00<00:07, 600.80it/s]
# Processing points:  11%|██████▋                                                    | 573/5031 [00:00<00:07, 607.64it/s]
# Processing points:  13%|███████▍                                                   | 635/5031 [00:01<00:07, 566.99it/s]
# Processing points:  14%|████████▏                                                  | 700/5031 [00:01<00:07, 590.00it/s]
# Processing points:  15%|████████▉                                                  | 760/5031 [00:01<00:07, 568.34it/s]
# Processing points:  16%|█████████▋                                                 | 828/5031 [00:01<00:07, 599.44it/s]
# Processing points:  18%|██████████▍                                                | 889/5031 [00:01<00:06, 596.67it/s]
# Processing points:  19%|███████████▏                                               | 950/5031 [00:01<00:06, 584.82it/s]
# Processing points:  20%|███████████▋                                              | 1009/5031 [00:01<00:06, 579.72it/s]
# Processing points:  21%|████████████▍                                             | 1077/5031 [00:01<00:06, 606.43it/s]
# Processing points:  23%|█████████████                                             | 1138/5031 [00:01<00:06, 593.13it/s]
# Processing points:  24%|█████████████▉                                            | 1205/5031 [00:02<00:06, 615.29it/s]
# Processing points:  25%|██████████████▌                                           | 1267/5031 [00:02<00:06, 580.08it/s]
# Processing points:  26%|███████████████▎                                          | 1326/5031 [00:02<00:06, 581.20it/s]
# Processing points:  28%|████████████████                                          | 1393/5031 [00:02<00:06, 603.86it/s]
# Processing points:  29%|████████████████▊                                         | 1454/5031 [00:02<00:06, 589.65it/s]
# Processing points:  30%|█████████████████▍                                        | 1516/5031 [00:02<00:05, 598.28it/s]
# Processing points:  31%|██████████████████▏                                       | 1577/5031 [00:02<00:05, 586.31it/s]
# Processing points:  33%|██████████████████▉                                       | 1638/5031 [00:02<00:05, 590.32it/s]
# Processing points:  34%|███████████████████▌                                      | 1698/5031 [00:02<00:06, 554.82it/s]
# Processing points:  35%|████████████████████▎                                     | 1762/5031 [00:02<00:05, 577.84it/s]
# Processing points:  36%|████████████████████▉                                     | 1821/5031 [00:03<00:05, 558.95it/s]
# Processing points:  38%|█████████████████████▊                                    | 1891/5031 [00:03<00:05, 598.26it/s]
# Processing points:  39%|██████████████████████▌                                   | 1952/5031 [00:03<00:05, 575.86it/s]
# Processing points:  40%|███████████████████████▏                                  | 2016/5031 [00:03<00:05, 590.64it/s]
# Processing points:  41%|███████████████████████▉                                  | 2076/5031 [00:03<00:05, 565.68it/s]
# Processing points:  43%|████████████████████████▋                                 | 2144/5031 [00:03<00:04, 596.55it/s]
# Processing points:  44%|█████████████████████████▍                                | 2205/5031 [00:03<00:04, 573.75it/s]
# Processing points:  45%|██████████████████████████▏                               | 2275/5031 [00:03<00:04, 609.10it/s]
# Processing points:  46%|██████████████████████████▉                               | 2337/5031 [00:03<00:04, 576.55it/s]
# Processing points:  48%|███████████████████████████▌                              | 2396/5031 [00:04<00:04, 572.46it/s]
# Processing points:  49%|████████████████████████████▎                             | 2460/5031 [00:04<00:04, 591.22it/s]
# Processing points:  50%|█████████████████████████████                             | 2520/5031 [00:04<00:04, 579.51it/s]
# Processing points:  51%|█████████████████████████████▊                            | 2585/5031 [00:04<00:04, 598.21it/s]
# Processing points:  53%|██████████████████████████████▌                           | 2646/5031 [00:04<00:03, 600.60it/s]
# Processing points:  54%|███████████████████████████████▏                          | 2707/5031 [00:04<00:03, 594.45it/s]
# Processing points:  55%|███████████████████████████████▉                          | 2767/5031 [00:04<00:03, 581.80it/s]
# Processing points:  56%|████████████████████████████████▋                         | 2831/5031 [00:04<00:03, 597.69it/s]
# Processing points:  57%|█████████████████████████████████▎                        | 2891/5031 [00:04<00:03, 569.64it/s]
# Processing points:  59%|█████████████████████████████████▉                        | 2949/5031 [00:05<00:03, 535.89it/s]
# Processing points:  60%|██████████████████████████████████▋                       | 3012/5031 [00:05<00:03, 560.04it/s]
# Processing points:  61%|███████████████████████████████████▍                      | 3069/5031 [00:05<00:03, 544.61it/s]
# Processing points:  62%|████████████████████████████████████                      | 3133/5031 [00:05<00:03, 570.24it/s]
# Processing points:  64%|████████████████████████████████████▉                     | 3199/5031 [00:05<00:03, 593.78it/s]
# Processing points:  65%|█████████████████████████████████████▌                    | 3259/5031 [00:05<00:03, 575.77it/s]
# Processing points:  66%|██████████████████████████████████████▎                   | 3327/5031 [00:05<00:02, 605.35it/s]
# Processing points:  67%|███████████████████████████████████████                   | 3388/5031 [00:05<00:02, 568.96it/s]
# Processing points:  69%|███████████████████████████████████████▊                  | 3448/5031 [00:05<00:02, 577.28it/s]
# Processing points:  70%|████████████████████████████████████████▍                 | 3507/5031 [00:06<00:02, 549.71it/s]
# Processing points:  71%|█████████████████████████████████████████▏                | 3574/5031 [00:06<00:02, 582.29it/s]
# Processing points:  72%|█████████████████████████████████████████▉                | 3633/5031 [00:06<00:02, 574.48it/s]
# Processing points:  73%|██████████████████████████████████████████▌               | 3691/5031 [00:06<00:02, 555.86it/s]
# Processing points:  74%|███████████████████████████████████████████▏              | 3747/5031 [00:06<00:02, 553.18it/s]
# Processing points:  76%|███████████████████████████████████████████▊              | 3803/5031 [00:06<00:02, 482.40it/s]
# Processing points:  77%|████████████████████████████████████████████▌             | 3861/5031 [00:06<00:02, 507.42it/s]
# Processing points:  78%|█████████████████████████████████████████████▏            | 3918/5031 [00:06<00:02, 523.70it/s]
# Processing points:  79%|█████████████████████████████████████████████▊            | 3972/5031 [00:06<00:02, 512.93it/s]
# Processing points:  80%|██████████████████████████████████████████████▌           | 4039/5031 [00:06<00:01, 555.70it/s]
# Processing points:  81%|███████████████████████████████████████████████▏          | 4096/5031 [00:07<00:01, 525.77it/s]
# Processing points:  83%|███████████████████████████████████████████████▉          | 4161/5031 [00:07<00:01, 558.06it/s]
# Processing points:  84%|████████████████████████████████████████████████▋         | 4218/5031 [00:07<00:01, 544.23it/s]
# Processing points:  85%|█████████████████████████████████████████████████▎        | 4274/5031 [00:07<00:01, 526.15it/s]
# Processing points:  86%|█████████████████████████████████████████████████▉        | 4328/5031 [00:07<00:01, 484.31it/s]
# Processing points:  87%|██████████████████████████████████████████████████▌       | 4385/5031 [00:07<00:01, 506.77it/s]
# Processing points:  88%|███████████████████████████████████████████████████▎      | 4446/5031 [00:07<00:01, 534.86it/s]
# Processing points:  89%|███████████████████████████████████████████████████▉      | 4501/5031 [00:07<00:01, 507.75it/s]
# Processing points:  91%|████████████████████████████████████████████████████▋     | 4567/5031 [00:08<00:00, 548.62it/s]
# Processing points:  92%|█████████████████████████████████████████████████████▎    | 4623/5031 [00:08<00:00, 545.48it/s]
# Processing points:  93%|██████████████████████████████████████████████████████    | 4693/5031 [00:08<00:00, 588.28it/s]
# Processing points:  94%|██████████████████████████████████████████████████████▊   | 4753/5031 [00:08<00:00, 561.53it/s]
# Processing points:  96%|███████████████████████████████████████████████████████▍  | 4811/5031 [00:08<00:00, 565.26it/s]
# Processing points:  97%|████████████████████████████████████████████████████████▏ | 4869/5031 [00:08<00:00, 525.47it/s]
# Processing points:  98%|████████████████████████████████████████████████████████▊ | 4923/5031 [00:08<00:00, 506.55it/s]
# Processing points: 100%|██████████████████████████████████████████████████████████| 5031/5031 [00:08<00:00, 568.10it/s]
# Processing directions: 100%|███████████████████████████████████████████████████████████| 20/20 [02:59<00:00,  8.95s/it]
# Optimal insertion direction: [-0.08955513  0.59034227  0.80216949]
# Number of undercut points: 0
# No undercut points to visualize.
