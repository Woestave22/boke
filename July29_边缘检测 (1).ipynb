# %%
'''
3D UNET边缘检测。
'''

# %%
'''
统一设置地址
'''

import os

# 获取当前工作目录
current_dir = os.getcwd()
print("当前工作目录：", current_dir)

# 修改当前工作目录，以后输出文件只需要写文件名
new_dir = "D:/李娅宁/肩台外侧点-0715/"
os.chdir(new_dir)
print("修改后的工作目录：", os.getcwd())
# Out:
# 当前工作目录： C:\Users\HP
# 修改后的工作目录： D:\李娅宁\肩台外侧点-0715

# %%
'''
数据预处理
'''

import os
import numpy as np
from scipy.interpolate import splprep, splev
import networkx as nx

def load_obj_file(file_path):
    vertices = []
    faces = []
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            for line in file:
                if line.startswith('v '):
                    parts = line.strip().split()
                    vertex = [float(parts[1]), float(parts[2]), float(parts[3])]
                    vertices.append(vertex)
                elif line.startswith('f '):
                    parts = line.strip().split()
                    face = [int(p.split('/')[0]) - 1 for p in parts[1:]]
                    faces.append(face)
    except FileNotFoundError:
        print(f"File not found: {file_path}")
    except Exception as e:
        print(f"An error occurred: {e}")
    return vertices, faces

def load_mark_file(file_path):
    marks = []
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            for line in file:
                parts = line.strip().split()
                if len(parts) == 3:
                    mark = [float(parts[0]), float(parts[1]), float(parts[2])]
                    marks.append(mark)
    except FileNotFoundError:
        print(f"File not found: {file_path}")
    except Exception as e:
        print(f"An error occurred: {e}")
    return marks

def center_vertices(vertices):
    vertices_array = np.array(vertices)
    min_coords = vertices_array.min(axis=0)
    max_coords = vertices_array.max(axis=0)
    center = (min_coords + max_coords) / 2
    centered_vertices = vertices_array - center
    return centered_vertices.tolist()

def interpolate_marks(marks, num_points=100):
    marks = np.array(marks)
    marks = np.vstack([marks, marks[0]])  # 添加第一个点到最后，使曲线闭合
    tck, u = splprep(marks.T, s=0, per=True)
    u_fine = np.linspace(0, 1, num_points)
    interpolated_marks = splev(u_fine, tck)
    return np.array(interpolated_marks).T

def generate_graph(vertices, faces):
    G = nx.Graph()
    for i, vertex in enumerate(vertices):
        G.add_node(i, pos=vertex)
    for face in faces:
        for i in range(len(face)):
            G.add_edge(face[i], face[(i+1) % len(face)])
    return G

def is_on_curve(vertex, curve_points, tolerance):
    for point in curve_points:
        if np.linalg.norm(vertex - point) < tolerance:
            return True
    return False

def segment_point_cloud(vertices, faces, interpolated_marks):
    tolerance = 0.1
    max_tolerance = 1.0
    tolerance_increment = 0.02

    while tolerance <= max_tolerance:
        G = generate_graph(vertices, faces)
        curve_points = np.array(interpolated_marks)
        
        # 找到封闭曲线上的顶点
        curve_points_indices = set()
        for i, vertex in enumerate(vertices):
            if is_on_curve(np.array(vertex), curve_points, tolerance):
                curve_points_indices.add(i)
        
        # 从图中删除封闭曲线上的点
        G.remove_nodes_from(curve_points_indices)
        
        # 使用图的连通性找到两个区域
        components = list(nx.connected_components(G))
        part1 = set()
        part2 = set()
        
        if len(components) > 1:
            part1 = components[0]
            part2 = components[1]
            # 返回所有点的标签：边缘点为 1，其余点为 0
            labels = [1 if i in curve_points_indices else 0 for i in range(len(vertices))]
            return part1, part2, labels, tolerance, len(curve_points_indices)
        else:
            tolerance += tolerance_increment
    
    return set(), set(), [0] * len(vertices), tolerance, len(curve_points_indices)

def save_points_with_labels_to_txt(vertices, labels, output_file_path):
    with open(output_file_path, 'w') as file:
        for i in range(len(vertices)):
            vertex = vertices[i]
            label = labels[i]
            file.write(f"{vertex[0]} {vertex[1]} {vertex[2]} {label}\n")

def process_files(input_folder, output_folder, threshold=200):
    for root, _, files in os.walk(input_folder):
        for file in files:
            if file.endswith('.obj'):
                obj_file_path = os.path.join(root, file)
                mark_file_path = obj_file_path + '.mark'
                if not os.path.exists(mark_file_path):
                    print(f"未找到mark文件: {mark_file_path}")
                    continue
                
                vertices, faces = load_obj_file(obj_file_path)
                marks = load_mark_file(mark_file_path)
                centered_vertices = center_vertices(vertices)
                interpolated_marks = interpolate_marks(marks)
                part1, part2, labels, tolerance, num_inside_points = segment_point_cloud(centered_vertices, faces, interpolated_marks)
                
                if len(part1) > 0 and len(part2) > 0 and num_inside_points < threshold:
                    print(f"{os.path.splitext(file)[0]} 的 tolerance是：{tolerance:.2f}, inside points 数目是：{num_inside_points}")
                    output_file_name = os.path.splitext(file)[0] + '_point_cloud_with_labels.txt'
                    output_file_path = os.path.join(output_folder, output_file_name)
                    save_points_with_labels_to_txt(centered_vertices, labels, output_file_path)
                else:
                    print(f"{os.path.splitext(file)[0]} 无法被分割为两部分")

# 使用修正后的文件路径
input_folder = r'肩台外侧点-0715'
output_folder = r'边缘检测预处理后数据'

if not os.path.exists(output_folder):
    os.makedirs(output_folder)

process_files(input_folder, output_folder)
# Out:
# 1_1 的 tolerance是：0.18, inside points 数目是：130
# 1_10 的 tolerance是：0.18, inside points 数目是：119
# 1_2 的 tolerance是：0.16, inside points 数目是：105
# 1_3 的 tolerance是：0.20, inside points 数目是：142
# 1_4 的 tolerance是：0.18, inside points 数目是：125
# 1_5 的 tolerance是：0.20, inside points 数目是：133
# 未找到mark文件: 肩台外侧点-0715\1\1_6.obj.mark
# 1_7 的 tolerance是：0.16, inside points 数目是：118
# 1_8 的 tolerance是：0.18, inside points 数目是：117
# 1_9 的 tolerance是：0.16, inside points 数目是：104
# 10_1 的 tolerance是：0.20, inside points 数目是：132
# 10_10 的 tolerance是：0.18, inside points 数目是：113
# 10_2 的 tolerance是：0.20, inside points 数目是：129
# 10_3 的 tolerance是：0.20, inside points 数目是：129
# 10_4 的 tolerance是：0.18, inside points 数目是：123
# 10_5 的 tolerance是：0.18, inside points 数目是：108
# 10_6 的 tolerance是：0.18, inside points 数目是：108
# 10_7 的 tolerance是：0.18, inside points 数目是：120
# 10_8 的 tolerance是：0.20, inside points 数目是：129
# 10_9 的 tolerance是：0.18, inside points 数目是：117
# 101_1 的 tolerance是：0.32, inside points 数目是：197
# 101_10 无法被分割为两部分
# 101_2 的 tolerance是：0.22, inside points 数目是：124
# 101_3 的 tolerance是：0.22, inside points 数目是：130
# 101_4 无法被分割为两部分
# 101_5 的 tolerance是：0.26, inside points 数目是：160
# 101_6 无法被分割为两部分
# 101_7 的 tolerance是：0.20, inside points 数目是：125
# 101_8 的 tolerance是：0.26, inside points 数目是：157
# 101_9 无法被分割为两部分
# 102_1 的 tolerance是：0.24, inside points 数目是：135
# 102_10 的 tolerance是：0.22, inside points 数目是：137
# 102_2 的 tolerance是：0.24, inside points 数目是：154
# 102_3 的 tolerance是：0.28, inside points 数目是：192
# 102_4 无法被分割为两部分
# 102_5 的 tolerance是：0.24, inside points 数目是：173
# 102_6 的 tolerance是：0.26, inside points 数目是：176
# 102_7 无法被分割为两部分
# 102_8 的 tolerance是：0.22, inside points 数目是：137
# 102_9 的 tolerance是：0.20, inside points 数目是：121
# 103_1 的 tolerance是：0.22, inside points 数目是：132
# 103_10 的 tolerance是：0.20, inside points 数目是：119
# 103_2 的 tolerance是：0.24, inside points 数目是：156
# 103_3 的 tolerance是：0.22, inside points 数目是：142
# 103_4 的 tolerance是：0.22, inside points 数目是：140
# 103_5 的 tolerance是：0.26, inside points 数目是：169
# 103_6 的 tolerance是：0.22, inside points 数目是：147
# 103_7 的 tolerance是：0.26, inside points 数目是：175
# 103_8 的 tolerance是：0.22, inside points 数目是：149
# 103_9 的 tolerance是：0.22, inside points 数目是：135
# 105_1 的 tolerance是：0.22, inside points 数目是：131
# 105_10 的 tolerance是：0.26, inside points 数目是：164
# 105_2 无法被分割为两部分
# 105_3 无法被分割为两部分
# 105_4 的 tolerance是：0.28, inside points 数目是：176
# 105_5 无法被分割为两部分
# 105_6 的 tolerance是：0.24, inside points 数目是：136
# 105_7 无法被分割为两部分
# 105_8 的 tolerance是：0.28, inside points 数目是：170
# 105_9 的 tolerance是：0.28, inside points 数目是：172
# 106_1 的 tolerance是：0.22, inside points 数目是：143
# 106_10 的 tolerance是：0.22, inside points 数目是：156
# 106_2 无法被分割为两部分
# 106_3 的 tolerance是：0.24, inside points 数目是：153
# 106_4 的 tolerance是：0.22, inside points 数目是：153
# 106_5 的 tolerance是：0.22, inside points 数目是：151
# 106_6 的 tolerance是：0.22, inside points 数目是：148
# 106_7 的 tolerance是：0.24, inside points 数目是：166
# 106_8 无法被分割为两部分
# 106_9 的 tolerance是：0.24, inside points 数目是：168
# 109_1 的 tolerance是：0.24, inside points 数目是：152
# 109_10 的 tolerance是：0.22, inside points 数目是：142
# 109_2 的 tolerance是：0.22, inside points 数目是：138
# 109_3 的 tolerance是：0.20, inside points 数目是：114
# 109_4 的 tolerance是：0.22, inside points 数目是：143
# 109_5 的 tolerance是：0.18, inside points 数目是：104
# 109_6 的 tolerance是：0.22, inside points 数目是：132
# 109_7 的 tolerance是：0.20, inside points 数目是：123
# 109_8 的 tolerance是：0.22, inside points 数目是：147
# 109_9 的 tolerance是：0.22, inside points 数目是：135
# 11_1 的 tolerance是：0.18, inside points 数目是：109
# 11_10 的 tolerance是：0.18, inside points 数目是：110
# 11_2 的 tolerance是：0.18, inside points 数目是：103
# 11_3 的 tolerance是：0.18, inside points 数目是：105
# 11_4 的 tolerance是：0.18, inside points 数目是：119
# 11_5 的 tolerance是：0.18, inside points 数目是：101
# 11_6 的 tolerance是：0.18, inside points 数目是：113
# 11_7 的 tolerance是：0.20, inside points 数目是：114
# 11_8 的 tolerance是：0.18, inside points 数目是：105
# 11_9 的 tolerance是：0.18, inside points 数目是：108
# 110_1 的 tolerance是：0.28, inside points 数目是：185
# 110_2 的 tolerance是：0.16, inside points 数目是：112
# 110_3 的 tolerance是：0.26, inside points 数目是：173
# 110_4 的 tolerance是：0.22, inside points 数目是：144
# 110_5 的 tolerance是：0.20, inside points 数目是：136
# 110_6 的 tolerance是：0.22, inside points 数目是：142
# 110_7 的 tolerance是：0.22, inside points 数目是：139
# 110_8 的 tolerance是：0.24, inside points 数目是：168
# 110_9 的 tolerance是：0.26, inside points 数目是：177
# 111_1 无法被分割为两部分
# 111_10 无法被分割为两部分
# 111_2 的 tolerance是：0.20, inside points 数目是：124
# 111_3 的 tolerance是：0.20, inside points 数目是：121
# 111_4 的 tolerance是：0.24, inside points 数目是：151
# 111_5 的 tolerance是：0.22, inside points 数目是：127
# 111_6 无法被分割为两部分
# 111_7 的 tolerance是：0.22, inside points 数目是：133
# 111_8 的 tolerance是：0.24, inside points 数目是：157
# 111_9 的 tolerance是：0.26, inside points 数目是：168
# 112_1 的 tolerance是：0.20, inside points 数目是：128
# 112_10 的 tolerance是：0.20, inside points 数目是：132
# 112_2 的 tolerance是：0.20, inside points 数目是：121
# 112_3 的 tolerance是：0.26, inside points 数目是：176
# 112_4 的 tolerance是：0.20, inside points 数目是：129
# 112_5 的 tolerance是：0.28, inside points 数目是：189
# 112_6 的 tolerance是：0.26, inside points 数目是：185
# 112_7 的 tolerance是：0.24, inside points 数目是：148
# 112_8 无法被分割为两部分
# 112_9 的 tolerance是：0.20, inside points 数目是：123
# 115_1 无法被分割为两部分
# 115_10 的 tolerance是：0.28, inside points 数目是：166
# 115_2 的 tolerance是：0.22, inside points 数目是：137
# 115_3 的 tolerance是：0.26, inside points 数目是：162
# 115_4 无法被分割为两部分
# 115_5 的 tolerance是：0.24, inside points 数目是：136
# 115_6 无法被分割为两部分
# 115_7 的 tolerance是：0.20, inside points 数目是：124
# 115_8 的 tolerance是：0.24, inside points 数目是：136
# 115_9 的 tolerance是：0.30, inside points 数目是：190
# 116_1 的 tolerance是：0.24, inside points 数目是：140
# 116_10 的 tolerance是：0.22, inside points 数目是：133
# 116_2 的 tolerance是：0.30, inside points 数目是：180
# 116_3 的 tolerance是：0.30, inside points 数目是：183
# 116_4 的 tolerance是：0.32, inside points 数目是：192
# 116_5 无法被分割为两部分
# 116_6 无法被分割为两部分
# 116_7 的 tolerance是：0.22, inside points 数目是：133
# 116_8 的 tolerance是：0.22, inside points 数目是：130
# 116_9 的 tolerance是：0.26, inside points 数目是：162
# 12_1 的 tolerance是：0.28, inside points 数目是：189
# 12_10 的 tolerance是：0.18, inside points 数目是：124
# 12_2 的 tolerance是：0.18, inside points 数目是：105
# 12_3 的 tolerance是：0.18, inside points 数目是：126
# 12_4 的 tolerance是：0.18, inside points 数目是：120
# 12_5 的 tolerance是：0.18, inside points 数目是：118
# 12_6 的 tolerance是：0.20, inside points 数目是：128
# 12_7 的 tolerance是：0.18, inside points 数目是：114
# 12_8 的 tolerance是：0.18, inside points 数目是：107
# 12_9 的 tolerance是：0.20, inside points 数目是：139
# 120_1 的 tolerance是：0.24, inside points 数目是：165
# 120_10 的 tolerance是：0.24, inside points 数目是：163
# 120_2 的 tolerance是：0.22, inside points 数目是：140
# 120_3 的 tolerance是：0.22, inside points 数目是：134
# 120_4 的 tolerance是：0.20, inside points 数目是：130
# 120_5 无法被分割为两部分
# 120_6 的 tolerance是：0.22, inside points 数目是：124
# 120_7 无法被分割为两部分
# 120_8 的 tolerance是：0.22, inside points 数目是：138
# 120_9 的 tolerance是：0.20, inside points 数目是：121
# 122_1 的 tolerance是：0.20, inside points 数目是：119
# 122_10 的 tolerance是：0.22, inside points 数目是：138
# 122_2 的 tolerance是：0.30, inside points 数目是：186
# 122_3 无法被分割为两部分
# 122_4 的 tolerance是：0.20, inside points 数目是：120
# 122_5 的 tolerance是：0.20, inside points 数目是：120
# 122_6 的 tolerance是：0.24, inside points 数目是：151
# 122_7 的 tolerance是：0.24, inside points 数目是：148
# 122_8 的 tolerance是：0.20, inside points 数目是：115
# 122_9 的 tolerance是：0.28, inside points 数目是：179
# 123_1 的 tolerance是：0.20, inside points 数目是：118
# 123_10 的 tolerance是：0.26, inside points 数目是：153
# 123_2 的 tolerance是：0.24, inside points 数目是：149
# 123_3 的 tolerance是：0.22, inside points 数目是：134
# 123_4 的 tolerance是：0.28, inside points 数目是：169
# 123_5 的 tolerance是：0.22, inside points 数目是：129
# 123_6 无法被分割为两部分
# 123_7 的 tolerance是：0.24, inside points 数目是：160
# 123_8 的 tolerance是：0.30, inside points 数目是：189
# 123_9 的 tolerance是：0.22, inside points 数目是：130
# 125_1 无法被分割为两部分
# 125_10 的 tolerance是：0.24, inside points 数目是：163
# 125_2 的 tolerance是：0.20, inside points 数目是：129
# 125_3 的 tolerance是：0.22, inside points 数目是：140
# 125_4 的 tolerance是：0.22, inside points 数目是：143
# 125_5 的 tolerance是：0.22, inside points 数目是：141
# 125_6 的 tolerance是：0.20, inside points 数目是：126
# 125_7 的 tolerance是：0.18, inside points 数目是：111
# 125_8 的 tolerance是：0.22, inside points 数目是：146
# 125_9 的 tolerance是：0.20, inside points 数目是：122
# 126_1 无法被分割为两部分
# 126_10 的 tolerance是：0.22, inside points 数目是：131
# 126_2 的 tolerance是：0.22, inside points 数目是：145
# 126_3 的 tolerance是：0.20, inside points 数目是：128
# 126_4 的 tolerance是：0.24, inside points 数目是：154
# 126_5 的 tolerance是：0.22, inside points 数目是：144
# 126_6 无法被分割为两部分
# 126_7 无法被分割为两部分
# 126_8 无法被分割为两部分
# 126_9 的 tolerance是：0.24, inside points 数目是：162
# 127_1 的 tolerance是：0.20, inside points 数目是：118
# 127_10 的 tolerance是：0.20, inside points 数目是：126
# 127_2 的 tolerance是：0.22, inside points 数目是：152
# 127_3 的 tolerance是：0.22, inside points 数目是：138
# 127_4 的 tolerance是：0.22, inside points 数目是：151
# 127_5 的 tolerance是：0.22, inside points 数目是：154
# 127_6 的 tolerance是：0.26, inside points 数目是：182
# 127_7 的 tolerance是：0.24, inside points 数目是：170
# 127_8 无法被分割为两部分
# 127_9 的 tolerance是：0.24, inside points 数目是：160
# 128_1 无法被分割为两部分
# 128_10 的 tolerance是：0.30, inside points 数目是：198
# 128_2 无法被分割为两部分
# 128_3 的 tolerance是：0.22, inside points 数目是：133
# 128_4 的 tolerance是：0.20, inside points 数目是：121
# 128_5 无法被分割为两部分
# 128_6 的 tolerance是：0.26, inside points 数目是：163
# 128_7 无法被分割为两部分
# 128_8 的 tolerance是：0.24, inside points 数目是：155
# 128_9 的 tolerance是：0.20, inside points 数目是：117
# 129_1 的 tolerance是：0.14, inside points 数目是：59
# 129_10 的 tolerance是：0.24, inside points 数目是：161
# 129_2 的 tolerance是：0.20, inside points 数目是：107
# 129_3 的 tolerance是：0.22, inside points 数目是：130
# 129_4 的 tolerance是：0.26, inside points 数目是：161
# 129_5 的 tolerance是：0.24, inside points 数目是：141
# 129_6 的 tolerance是：0.20, inside points 数目是：103
# 129_7 的 tolerance是：0.30, inside points 数目是：189
# 129_8 的 tolerance是：0.18, inside points 数目是：95
# 129_9 无法被分割为两部分
# 13_1 的 tolerance是：0.20, inside points 数目是：117
# 13_10 的 tolerance是：0.18, inside points 数目是：123
# 13_2 的 tolerance是：0.26, inside points 数目是：176
# 13_3 的 tolerance是：0.18, inside points 数目是：108
# 13_4 的 tolerance是：0.20, inside points 数目是：123
# 13_5 的 tolerance是：0.20, inside points 数目是：121
# 13_7 的 tolerance是：0.20, inside points 数目是：121
# 13_8 的 tolerance是：0.18, inside points 数目是：106
# 13_9 的 tolerance是：0.18, inside points 数目是：115
# 132_1 的 tolerance是：0.24, inside points 数目是：154
# 132_10 的 tolerance是：0.24, inside points 数目是：153
# 132_2 的 tolerance是：0.20, inside points 数目是：114
# 132_3 的 tolerance是：0.24, inside points 数目是：149
# 132_4 的 tolerance是：0.28, inside points 数目是：186
# 132_5 无法被分割为两部分
# 132_6 的 tolerance是：0.20, inside points 数目是：121
# 132_7 的 tolerance是：0.20, inside points 数目是：117
# 132_8 的 tolerance是：0.22, inside points 数目是：131
# 132_9 的 tolerance是：0.20, inside points 数目是：118
# 134_1 的 tolerance是：0.20, inside points 数目是：113
# 134_10 无法被分割为两部分
# 134_2 的 tolerance是：0.26, inside points 数目是：176
# 134_3 的 tolerance是：0.24, inside points 数目是：159
# 134_4 无法被分割为两部分
# 134_5 的 tolerance是：0.22, inside points 数目是：143
# 134_6 的 tolerance是：0.24, inside points 数目是：151
# 134_7 的 tolerance是：0.26, inside points 数目是：175
# 134_8 的 tolerance是：0.26, inside points 数目是：190
# 134_9 的 tolerance是：0.24, inside points 数目是：155
# 135_1 的 tolerance是：0.22, inside points 数目是：146
# 135_10 的 tolerance是：0.26, inside points 数目是：171
# 135_2 的 tolerance是：0.28, inside points 数目是：192
# 135_3 无法被分割为两部分
# 135_4 无法被分割为两部分
# 135_5 无法被分割为两部分
# 135_6 的 tolerance是：0.22, inside points 数目是：144
# 135_7 的 tolerance是：0.22, inside points 数目是：148
# 135_8 的 tolerance是：0.20, inside points 数目是：128
# 135_9 的 tolerance是：0.22, inside points 数目是：141
# 136_1 的 tolerance是：0.22, inside points 数目是：150
# 136_10 的 tolerance是：0.24, inside points 数目是：172
# 136_2 的 tolerance是：0.22, inside points 数目是：145
# 136_3 的 tolerance是：0.18, inside points 数目是：102
# 136_4 的 tolerance是：0.26, inside points 数目是：180
# 136_5 的 tolerance是：0.24, inside points 数目是：162
# 136_6 的 tolerance是：0.20, inside points 数目是：123
# 136_7 的 tolerance是：0.26, inside points 数目是：177
# 136_8 的 tolerance是：0.24, inside points 数目是：164
# 136_9 的 tolerance是：0.22, inside points 数目是：155
# 138_1 的 tolerance是：0.26, inside points 数目是：170
# 138_10 的 tolerance是：0.26, inside points 数目是：172
# 138_2 的 tolerance是：0.20, inside points 数目是：130
# 138_3 的 tolerance是：0.20, inside points 数目是：124
# 138_4 的 tolerance是：0.20, inside points 数目是：103
# 138_5 的 tolerance是：0.28, inside points 数目是：194
# 138_6 无法被分割为两部分
# 138_7 无法被分割为两部分
# 138_8 的 tolerance是：0.20, inside points 数目是：129
# 138_9 无法被分割为两部分
# 139_1 的 tolerance是：0.22, inside points 数目是：125
# 139_10 的 tolerance是：0.26, inside points 数目是：160
# 139_2 无法被分割为两部分
# 139_3 无法被分割为两部分
# 139_4 的 tolerance是：0.20, inside points 数目是：114
# 139_5 的 tolerance是：0.26, inside points 数目是：159
# 139_6 的 tolerance是：0.24, inside points 数目是：132
# 139_7 的 tolerance是：0.26, inside points 数目是：162
# 139_8 的 tolerance是：0.26, inside points 数目是：166
# 139_9 的 tolerance是：0.24, inside points 数目是：153
# 14_1 的 tolerance是：0.18, inside points 数目是：106
# 14_10 的 tolerance是：0.18, inside points 数目是：126
# 14_2 的 tolerance是：0.18, inside points 数目是：109
# 14_3 的 tolerance是：0.18, inside points 数目是：111
# 14_4 的 tolerance是：0.22, inside points 数目是：141
# 14_5 的 tolerance是：0.20, inside points 数目是：133
# 14_6 的 tolerance是：0.18, inside points 数目是：110
# 14_7 的 tolerance是：0.18, inside points 数目是：111
# 14_8 的 tolerance是：0.18, inside points 数目是：112
# 14_9 的 tolerance是：0.18, inside points 数目是：114
# 140_1 的 tolerance是：0.24, inside points 数目是：152
# 140_10 的 tolerance是：0.22, inside points 数目是：142
# 140_2 的 tolerance是：0.28, inside points 数目是：178
# 140_3 无法被分割为两部分
# 140_4 的 tolerance是：0.20, inside points 数目是：119
# 140_5 的 tolerance是：0.20, inside points 数目是：114
# 140_6 无法被分割为两部分
# 140_7 无法被分割为两部分
# 140_8 无法被分割为两部分
# 140_9 的 tolerance是：0.26, inside points 数目是：163
# 142_1 的 tolerance是：0.24, inside points 数目是：149
# 142_10 的 tolerance是：0.26, inside points 数目是：179
# 142_2 的 tolerance是：0.28, inside points 数目是：185
# 142_3 的 tolerance是：0.24, inside points 数目是：161
# 142_4 的 tolerance是：0.26, inside points 数目是：178
# 142_5 的 tolerance是：0.26, inside points 数目是：170
# 142_6 的 tolerance是：0.24, inside points 数目是：142
# 142_7 的 tolerance是：0.22, inside points 数目是：142
# 142_8 的 tolerance是：0.24, inside points 数目是：151
# 142_9 的 tolerance是：0.22, inside points 数目是：135
# 145_1 的 tolerance是：0.22, inside points 数目是：122
# 145_10 的 tolerance是：0.24, inside points 数目是：156
# 145_2 的 tolerance是：0.22, inside points 数目是：112
# 145_3 的 tolerance是：0.30, inside points 数目是：188
# 145_4 的 tolerance是：0.28, inside points 数目是：188
# 145_5 的 tolerance是：0.20, inside points 数目是：106
# 145_6 的 tolerance是：0.26, inside points 数目是：171
# 145_7 的 tolerance是：0.24, inside points 数目是：156
# 145_8 无法被分割为两部分
# 145_9 的 tolerance是：0.26, inside points 数目是：169
# 146_1 的 tolerance是：0.26, inside points 数目是：150
# 146_10 无法被分割为两部分
# 146_2 的 tolerance是：0.22, inside points 数目是：131
# 146_3 的 tolerance是：0.26, inside points 数目是：165
# 146_4 的 tolerance是：0.30, inside points 数目是：190
# 146_5 的 tolerance是：0.28, inside points 数目是：175
# 146_6 的 tolerance是：0.28, inside points 数目是：170
# 146_7 的 tolerance是：0.26, inside points 数目是：170
# 146_8 的 tolerance是：0.26, inside points 数目是：162
# 146_9 无法被分割为两部分
# 147_1 的 tolerance是：0.26, inside points 数目是：157
# 147_10 的 tolerance是：0.26, inside points 数目是：164
# 147_2 的 tolerance是：0.28, inside points 数目是：177
# 147_3 的 tolerance是：0.26, inside points 数目是：169
# 147_4 的 tolerance是：0.28, inside points 数目是：178
# 147_5 的 tolerance是：0.26, inside points 数目是：155
# 147_6 无法被分割为两部分
# 147_7 的 tolerance是：0.20, inside points 数目是：105
# 147_8 无法被分割为两部分
# 147_9 的 tolerance是：0.26, inside points 数目是：168
# 148_1 的 tolerance是：0.30, inside points 数目是：199
# 148_10 的 tolerance是：0.26, inside points 数目是：160
# 148_2 的 tolerance是：0.26, inside points 数目是：150
# 148_3 的 tolerance是：0.30, inside points 数目是：185
# 148_4 的 tolerance是：0.26, inside points 数目是：160
# 148_5 的 tolerance是：0.26, inside points 数目是：152
# 148_6 的 tolerance是：0.28, inside points 数目是：178
# 148_7 无法被分割为两部分
# 148_8 的 tolerance是：0.22, inside points 数目是：119
# 148_9 无法被分割为两部分
# 149_1 的 tolerance是：0.22, inside points 数目是：143
# 149_10 无法被分割为两部分
# 149_2 无法被分割为两部分
# 149_3 的 tolerance是：0.26, inside points 数目是：182
# 149_4 无法被分割为两部分
# 149_5 的 tolerance是：0.26, inside points 数目是：175
# 149_6 的 tolerance是：0.28, inside points 数目是：189
# 149_7 的 tolerance是：0.24, inside points 数目是：152
# 149_8 的 tolerance是：0.22, inside points 数目是：144
# 149_9 的 tolerance是：0.24, inside points 数目是：159
# 15_1 的 tolerance是：0.20, inside points 数目是：113
# 15_10 的 tolerance是：0.20, inside points 数目是：131
# 15_2 的 tolerance是：0.18, inside points 数目是：115
# 15_3 的 tolerance是：0.20, inside points 数目是：116
# 15_4 的 tolerance是：0.20, inside points 数目是：124
# 15_5 的 tolerance是：0.20, inside points 数目是：106
# 15_6 的 tolerance是：0.18, inside points 数目是：99
# 15_7 的 tolerance是：0.18, inside points 数目是：103
# 15_8 的 tolerance是：0.18, inside points 数目是：103
# 15_9 的 tolerance是：0.18, inside points 数目是：100
# 1 的 tolerance是：0.18, inside points 数目是：148
# 10 的 tolerance是：0.18, inside points 数目是：148
# 100 的 tolerance是：0.16, inside points 数目是：86
# 101 的 tolerance是：0.18, inside points 数目是：123
# 102 的 tolerance是：0.18, inside points 数目是：120
# 103 的 tolerance是：0.20, inside points 数目是：137
# 104 的 tolerance是：0.18, inside points 数目是：121
# 105 的 tolerance是：0.16, inside points 数目是：110
# 106 的 tolerance是：0.22, inside points 数目是：164
# 107 的 tolerance是：0.20, inside points 数目是：125
# 108 的 tolerance是：0.20, inside points 数目是：139
# 109 的 tolerance是：0.24, inside points 数目是：179
# 11 的 tolerance是：0.18, inside points 数目是：150
# 110 的 tolerance是：0.22, inside points 数目是：142
# 111 的 tolerance是：0.66, inside points 数目是：178
# 112 的 tolerance是：0.48, inside points 数目是：173
# 113 的 tolerance是：0.52, inside points 数目是：192
# 114 的 tolerance是：0.70, inside points 数目是：182
# 115 无法被分割为两部分
# 116 无法被分割为两部分
# 117 的 tolerance是：0.60, inside points 数目是：144
# 118 的 tolerance是：0.48, inside points 数目是：139
# 119 无法被分割为两部分
# 12 的 tolerance是：0.18, inside points 数目是：149
# 120 的 tolerance是：0.50, inside points 数目是：195
# 121 的 tolerance是：0.28, inside points 数目是：167
# 122 无法被分割为两部分
# 123 无法被分割为两部分
# 124 的 tolerance是：0.58, inside points 数目是：154
# 125 的 tolerance是：0.48, inside points 数目是：126
# 126 的 tolerance是：0.42, inside points 数目是：173
# 127 的 tolerance是：0.50, inside points 数目是：149
# 128 无法被分割为两部分
# 129 无法被分割为两部分
# 13 的 tolerance是：0.18, inside points 数目是：146
# 130 无法被分割为两部分
# 131 的 tolerance是：0.20, inside points 数目是：133
# 132 的 tolerance是：0.16, inside points 数目是：100
# 133 的 tolerance是：0.18, inside points 数目是：131
# 134 的 tolerance是：0.26, inside points 数目是：172
# 135 的 tolerance是：0.20, inside points 数目是：144
# 136 的 tolerance是：0.24, inside points 数目是：135
# 137 的 tolerance是：0.24, inside points 数目是：152
# 138 的 tolerance是：0.20, inside points 数目是：141
# 139 的 tolerance是：0.18, inside points 数目是：125
# 14 的 tolerance是：0.18, inside points 数目是：140
# 140 的 tolerance是：0.22, inside points 数目是：132
# 141 的 tolerance是：0.22, inside points 数目是：125
# 142 的 tolerance是：0.22, inside points 数目是：156
# 143 的 tolerance是：0.20, inside points 数目是：134
# 144 的 tolerance是：0.20, inside points 数目是：144
# 145 的 tolerance是：0.20, inside points 数目是：122
# 146 的 tolerance是：0.24, inside points 数目是：169
# 147 的 tolerance是：0.20, inside points 数目是：134
# 148 的 tolerance是：0.18, inside points 数目是：110
# 149 的 tolerance是：0.16, inside points 数目是：102
# 15 的 tolerance是：0.24, inside points 数目是：196
# 150 的 tolerance是：0.22, inside points 数目是：149
# 16 的 tolerance是：0.26, inside points 数目是：182
# 17 无法被分割为两部分
# 18 的 tolerance是：0.22, inside points 数目是：166
# 19 的 tolerance是：0.18, inside points 数目是：133
# 2 的 tolerance是：0.20, inside points 数目是：160
# 20 的 tolerance是：0.18, inside points 数目是：151
# 21 的 tolerance是：0.24, inside points 数目是：197
# 22 的 tolerance是：0.20, inside points 数目是：151
# 23 的 tolerance是：0.18, inside points 数目是：163
# 24 的 tolerance是：0.20, inside points 数目是：141
# 25 的 tolerance是：0.20, inside points 数目是：167
# 26 的 tolerance是：0.20, inside points 数目是：183
# 27 的 tolerance是：0.14, inside points 数目是：112
# 28 的 tolerance是：0.18, inside points 数目是：151
# 29 的 tolerance是：0.16, inside points 数目是：138
# 3 的 tolerance是：0.16, inside points 数目是：137
# 30 的 tolerance是：0.22, inside points 数目是：187
# 31 的 tolerance是：0.18, inside points 数目是：157
# 32 的 tolerance是：0.16, inside points 数目是：155
# 33 的 tolerance是：0.20, inside points 数目是：148
# 34 的 tolerance是：0.24, inside points 数目是：187
# 35 的 tolerance是：0.22, inside points 数目是：181
# 36 的 tolerance是：0.20, inside points 数目是：180
# 37 的 tolerance是：0.22, inside points 数目是：169
# 38 无法被分割为两部分
# 39 的 tolerance是：0.18, inside points 数目是：149
# 4 的 tolerance是：0.18, inside points 数目是：144
# 40 的 tolerance是：0.20, inside points 数目是：172
# 41 的 tolerance是：0.18, inside points 数目是：159
# 42 的 tolerance是：0.22, inside points 数目是：188
# 43 的 tolerance是：0.24, inside points 数目是：182
# 44 的 tolerance是：0.20, inside points 数目是：170
# 45 的 tolerance是：0.22, inside points 数目是：164
# 46 无法被分割为两部分
# 47 的 tolerance是：0.18, inside points 数目是：149
# 48 的 tolerance是：0.10, inside points 数目是：42
# 49 的 tolerance是：0.20, inside points 数目是：181
# 5 的 tolerance是：0.16, inside points 数目是：120
# 50 的 tolerance是：0.18, inside points 数目是：127
# 51 的 tolerance是：0.22, inside points 数目是：170
# 52 的 tolerance是：0.16, inside points 数目是：105
# 53 的 tolerance是：0.16, inside points 数目是：111
# 54 的 tolerance是：0.18, inside points 数目是：125
# 55 的 tolerance是：0.16, inside points 数目是：111
# 56 的 tolerance是：0.22, inside points 数目是：170
# 57 的 tolerance是：0.18, inside points 数目是：133
# 58 的 tolerance是：0.10, inside points 数目是：51
# 59 的 tolerance是：0.18, inside points 数目是：124
# 6 的 tolerance是：0.16, inside points 数目是：126
# 60 的 tolerance是：0.18, inside points 数目是：149
# 61 的 tolerance是：0.16, inside points 数目是：110
# 62 的 tolerance是：0.16, inside points 数目是：119
# 63 的 tolerance是：0.16, inside points 数目是：116
# 64 的 tolerance是：0.14, inside points 数目是：102
# 65 的 tolerance是：0.18, inside points 数目是：131
# 66 的 tolerance是：0.18, inside points 数目是：133
# 67 的 tolerance是：0.16, inside points 数目是：87
# 68 的 tolerance是：0.16, inside points 数目是：119
# 69 的 tolerance是：0.16, inside points 数目是：121
# 7 的 tolerance是：0.18, inside points 数目是：153
# 70 的 tolerance是：0.14, inside points 数目是：92
# 71 的 tolerance是：0.18, inside points 数目是：153
# 72 的 tolerance是：0.18, inside points 数目是：165
# 73 的 tolerance是：0.16, inside points 数目是：139
# 74 的 tolerance是：0.18, inside points 数目是：157
# 75 的 tolerance是：0.18, inside points 数目是：149
# 76 的 tolerance是：0.18, inside points 数目是：165
# 77 的 tolerance是：0.18, inside points 数目是：157
# 78 的 tolerance是：0.18, inside points 数目是：154
# 79 的 tolerance是：0.18, inside points 数目是：165
# 8 的 tolerance是：0.18, inside points 数目是：142
# 80 的 tolerance是：0.18, inside points 数目是：171
# 81 的 tolerance是：0.18, inside points 数目是：127
# 82 的 tolerance是：0.16, inside points 数目是：145
# 83 的 tolerance是：0.22, inside points 数目是：199
# 84 的 tolerance是：0.20, inside points 数目是：180
# 85 的 tolerance是：0.18, inside points 数目是：126
# 86 的 tolerance是：0.16, inside points 数目是：114
# 87 的 tolerance是：0.16, inside points 数目是：110
# 88 的 tolerance是：0.16, inside points 数目是：112
# 89 的 tolerance是：0.18, inside points 数目是：123
# 9 的 tolerance是：0.22, inside points 数目是：168
# 90 的 tolerance是：0.16, inside points 数目是：108
# 91 的 tolerance是：0.16, inside points 数目是：93
# 92 的 tolerance是：0.18, inside points 数目是：110
# 93 的 tolerance是：0.16, inside points 数目是：106
# 94 的 tolerance是：0.16, inside points 数目是：93
# 95 的 tolerance是：0.16, inside points 数目是：108
# 96 的 tolerance是：0.18, inside points 数目是：118
# 97 的 tolerance是：0.16, inside points 数目是：117
# 98 的 tolerance是：0.18, inside points 数目是：117
# 99 的 tolerance是：0.20, inside points 数目是：151
# 16_1 的 tolerance是：0.18, inside points 数目是：115
# 16_10 的 tolerance是：0.18, inside points 数目是：110
# 16_2 的 tolerance是：0.18, inside points 数目是：111
# 16_3 的 tolerance是：0.18, inside points 数目是：110
# 16_4 的 tolerance是：0.18, inside points 数目是：115
# 16_5 的 tolerance是：0.18, inside points 数目是：108
# 16_6 的 tolerance是：0.16, inside points 数目是：97
# 16_7 的 tolerance是：0.18, inside points 数目是：109
# 16_8 的 tolerance是：0.20, inside points 数目是：122
# 16_9 的 tolerance是：0.18, inside points 数目是：112
# 17_1 的 tolerance是：0.20, inside points 数目是：112
# 17_10 的 tolerance是：0.20, inside points 数目是：128
# 17_2 的 tolerance是：0.18, inside points 数目是：107
# 17_3 的 tolerance是：0.18, inside points 数目是：106
# 17_4 的 tolerance是：0.18, inside points 数目是：101
# 17_5 的 tolerance是：0.18, inside points 数目是：106
# 17_6 的 tolerance是：0.18, inside points 数目是：97
# 17_7 的 tolerance是：0.20, inside points 数目是：112
# 17_8 的 tolerance是：0.18, inside points 数目是：103
# 17_9 的 tolerance是：0.18, inside points 数目是：111
# 18_1 的 tolerance是：0.20, inside points 数目是：131
# 18_10 的 tolerance是：0.18, inside points 数目是：112
# 18_2 的 tolerance是：0.16, inside points 数目是：99
# 18_3 的 tolerance是：0.18, inside points 数目是：108
# 18_4 的 tolerance是：0.16, inside points 数目是：98
# 18_5 的 tolerance是：0.18, inside points 数目是：115
# 18_6 的 tolerance是：0.18, inside points 数目是：119
# 18_7 的 tolerance是：0.18, inside points 数目是：128
# 18_8 的 tolerance是：0.18, inside points 数目是：112
# 18_9 的 tolerance是：0.16, inside points 数目是：95
# 19_1 的 tolerance是：0.18, inside points 数目是：111
# 19_10 的 tolerance是：0.20, inside points 数目是：131
# 19_2 的 tolerance是：0.18, inside points 数目是：117
# 19_3 的 tolerance是：0.18, inside points 数目是：100
# 19_4 的 tolerance是：0.20, inside points 数目是：128
# 19_5 的 tolerance是：0.18, inside points 数目是：106
# 19_6 的 tolerance是：0.18, inside points 数目是：106
# 19_7 的 tolerance是：0.20, inside points 数目是：119
# 19_8 的 tolerance是：0.20, inside points 数目是：132
# 19_9 的 tolerance是：0.18, inside points 数目是：99
# 2_1 的 tolerance是：0.16, inside points 数目是：114
# 2_10 的 tolerance是：0.16, inside points 数目是：112
# 2_2 的 tolerance是：0.18, inside points 数目是：123
# 2_3 的 tolerance是：0.18, inside points 数目是：131
# 2_4 的 tolerance是：0.16, inside points 数目是：107
# 2_5 的 tolerance是：0.16, inside points 数目是：107
# 2_6 的 tolerance是：0.24, inside points 数目是：171
# 2_7 的 tolerance是：0.20, inside points 数目是：140
# 2_8 无法被分割为两部分
# 未找到mark文件: 肩台外侧点-0715\2\2_9.obj.mark
# 20_1 的 tolerance是：0.20, inside points 数目是：131
# 20_10 的 tolerance是：0.18, inside points 数目是：127
# 20_2 的 tolerance是：0.18, inside points 数目是：114
# 20_3 的 tolerance是：0.20, inside points 数目是：133
# 20_4 的 tolerance是：0.18, inside points 数目是：123
# 20_5 的 tolerance是：0.16, inside points 数目是：101
# 20_6 的 tolerance是：0.18, inside points 数目是：113
# 20_7 的 tolerance是：0.18, inside points 数目是：110
# 20_8 的 tolerance是：0.18, inside points 数目是：119
# 20_9 的 tolerance是：0.16, inside points 数目是：92
# 21_1 的 tolerance是：0.18, inside points 数目是：114
# 21_10 的 tolerance是：0.20, inside points 数目是：125
# 21_2 的 tolerance是：0.20, inside points 数目是：126
# 21_3 的 tolerance是：0.18, inside points 数目是：113
# 21_4 的 tolerance是：0.18, inside points 数目是：112
# 21_5 的 tolerance是：0.16, inside points 数目是：92
# 21_6 的 tolerance是：0.20, inside points 数目是：132
# 21_7 的 tolerance是：0.20, inside points 数目是：126
# 21_8 的 tolerance是：0.18, inside points 数目是：107
# 21_9 的 tolerance是：0.18, inside points 数目是：111
# 22_1 的 tolerance是：0.18, inside points 数目是：122
# 22_10 的 tolerance是：0.18, inside points 数目是：118
# 22_2 的 tolerance是：0.16, inside points 数目是：98
# 22_3 的 tolerance是：0.18, inside points 数目是：113
# 22_4 的 tolerance是：0.22, inside points 数目是：142
# 22_5 的 tolerance是：0.18, inside points 数目是：115
# 22_6 的 tolerance是：0.18, inside points 数目是：118
# 22_7 的 tolerance是：0.20, inside points 数目是：123
# 22_8 的 tolerance是：0.20, inside points 数目是：138
# 22_9 的 tolerance是：0.18, inside points 数目是：114
# 23_1 的 tolerance是：0.18, inside points 数目是：108
# 23_10 的 tolerance是：0.18, inside points 数目是：112
# 23_2 的 tolerance是：0.18, inside points 数目是：112
# 23_3 的 tolerance是：0.18, inside points 数目是：120
# 23_4 的 tolerance是：0.18, inside points 数目是：126
# 23_5 的 tolerance是：0.18, inside points 数目是：110
# 23_6 的 tolerance是：0.18, inside points 数目是：117
# 23_7 的 tolerance是：0.18, inside points 数目是：123
# 23_8 的 tolerance是：0.18, inside points 数目是：119
# 23_9 的 tolerance是：0.20, inside points 数目是：120
# 24_1 的 tolerance是：0.18, inside points 数目是：110
# 24_10 的 tolerance是：0.18, inside points 数目是：123
# 24_2 的 tolerance是：0.18, inside points 数目是：118
# 24_3 无法被分割为两部分
# 24_4 的 tolerance是：0.18, inside points 数目是：123
# 24_5 的 tolerance是：0.18, inside points 数目是：104
# 24_6 的 tolerance是：0.18, inside points 数目是：130
# 24_7 的 tolerance是：0.20, inside points 数目是：128
# 24_8 的 tolerance是：0.18, inside points 数目是：113
# 24_9 的 tolerance是：0.18, inside points 数目是：114
# 25_1 的 tolerance是：0.18, inside points 数目是：106
# 25_10 的 tolerance是：0.20, inside points 数目是：130
# 25_2 的 tolerance是：0.18, inside points 数目是：120
# 25_3 的 tolerance是：0.18, inside points 数目是：109
# 25_4 的 tolerance是：0.24, inside points 数目是：145
# 25_5 的 tolerance是：0.18, inside points 数目是：111
# 25_6 的 tolerance是：0.24, inside points 数目是：152
# 25_7 的 tolerance是：0.18, inside points 数目是：108
# 25_8 的 tolerance是：0.18, inside points 数目是：110
# 25_9 的 tolerance是：0.18, inside points 数目是：108
# 26_1 的 tolerance是：0.18, inside points 数目是：112
# 26_10 的 tolerance是：0.18, inside points 数目是：118
# 26_2 的 tolerance是：0.18, inside points 数目是：122
# 26_3 的 tolerance是：0.18, inside points 数目是：110
# 26_4 的 tolerance是：0.18, inside points 数目是：119
# 26_5 的 tolerance是：0.18, inside points 数目是：116
# 26_6 的 tolerance是：0.18, inside points 数目是：107
# 26_7 的 tolerance是：0.18, inside points 数目是：113
# 26_8 的 tolerance是：0.20, inside points 数目是：125
# 26_9 的 tolerance是：0.18, inside points 数目是：110
# 27_1 的 tolerance是：0.20, inside points 数目是：120
# 27_10 的 tolerance是：0.18, inside points 数目是：119
# 27_2 的 tolerance是：0.18, inside points 数目是：110
# 27_3 的 tolerance是：0.18, inside points 数目是：105
# 27_4 的 tolerance是：0.18, inside points 数目是：116
# 27_5 的 tolerance是：0.20, inside points 数目是：139
# 27_6 的 tolerance是：0.20, inside points 数目是：142
# 27_7 的 tolerance是：0.18, inside points 数目是：108
# 27_8 的 tolerance是：0.18, inside points 数目是：103
# 27_9 的 tolerance是：0.18, inside points 数目是：109
# 28_1 的 tolerance是：0.20, inside points 数目是：130
# 28_10 的 tolerance是：0.18, inside points 数目是：102
# 28_2 的 tolerance是：0.20, inside points 数目是：131
# 28_3 的 tolerance是：0.18, inside points 数目是：104
# 28_4 的 tolerance是：0.20, inside points 数目是：119
# 28_5 的 tolerance是：0.18, inside points 数目是：105
# 28_6 的 tolerance是：0.20, inside points 数目是：122
# 28_7 的 tolerance是：0.18, inside points 数目是：114
# 28_8 的 tolerance是：0.18, inside points 数目是：109
# 28_9 的 tolerance是：0.22, inside points 数目是：135
# 29_1 的 tolerance是：0.20, inside points 数目是：127
# 29_10 的 tolerance是：0.18, inside points 数目是：130
# 29_2 的 tolerance是：0.18, inside points 数目是：111
# 29_3 的 tolerance是：0.18, inside points 数目是：124
# 29_4 的 tolerance是：0.18, inside points 数目是：118
# 29_5 的 tolerance是：0.20, inside points 数目是：125
# 29_6 的 tolerance是：0.18, inside points 数目是：115
# 29_7 的 tolerance是：0.18, inside points 数目是：120
# 29_8 的 tolerance是：0.18, inside points 数目是：108
# 29_9 的 tolerance是：0.18, inside points 数目是：119
# 3_1 的 tolerance是：0.22, inside points 数目是：151
# 3_10 的 tolerance是：0.20, inside points 数目是：121
# 3_2 的 tolerance是：0.18, inside points 数目是：110
# 3_3 的 tolerance是：0.16, inside points 数目是：98
# 3_4 的 tolerance是：0.18, inside points 数目是：116
# 3_5 的 tolerance是：0.18, inside points 数目是：119
# 3_6 的 tolerance是：0.18, inside points 数目是：118
# 3_7 的 tolerance是：0.18, inside points 数目是：105
# 3_8 的 tolerance是：0.18, inside points 数目是：105
# 3_9 的 tolerance是：0.18, inside points 数目是：109
# 30_1 的 tolerance是：0.24, inside points 数目是：171
# 30_10 的 tolerance是：0.18, inside points 数目是：114
# 30_2 的 tolerance是：0.20, inside points 数目是：128
# 30_3 的 tolerance是：0.20, inside points 数目是：129
# 30_4 的 tolerance是：0.18, inside points 数目是：121
# 30_5 的 tolerance是：0.24, inside points 数目是：165
# 30_6 的 tolerance是：0.18, inside points 数目是：108
# 30_7 的 tolerance是：0.18, inside points 数目是：109
# 30_8 的 tolerance是：0.18, inside points 数目是：120
# 30_9 的 tolerance是：0.18, inside points 数目是：117
# 31_1 的 tolerance是：0.18, inside points 数目是：117
# 31_10 的 tolerance是：0.18, inside points 数目是：121
# 31_2 的 tolerance是：0.22, inside points 数目是：148
# 31_3 的 tolerance是：0.18, inside points 数目是：115
# 31_4 的 tolerance是：0.18, inside points 数目是：129
# 31_5 的 tolerance是：0.18, inside points 数目是：118
# 31_6 的 tolerance是：0.18, inside points 数目是：120
# 31_7 的 tolerance是：0.18, inside points 数目是：118
# 31_8 的 tolerance是：0.20, inside points 数目是：131
# 31_9 的 tolerance是：0.16, inside points 数目是：103
# 32_1 的 tolerance是：0.18, inside points 数目是：123
# 32_10 的 tolerance是：0.18, inside points 数目是：110
# 32_2 的 tolerance是：0.18, inside points 数目是：119
# 32_3 的 tolerance是：0.18, inside points 数目是：120
# 32_4 的 tolerance是：0.16, inside points 数目是：99
# 32_5 的 tolerance是：0.18, inside points 数目是：115
# 32_6 的 tolerance是：0.18, inside points 数目是：121
# 32_7 的 tolerance是：0.18, inside points 数目是：117
# 32_8 的 tolerance是：0.18, inside points 数目是：113
# 32_9 的 tolerance是：0.20, inside points 数目是：133
# 33_1 的 tolerance是：0.18, inside points 数目是：114
# 33_10 的 tolerance是：0.20, inside points 数目是：139
# 33_2 的 tolerance是：0.18, inside points 数目是：119
# 33_3 的 tolerance是：0.18, inside points 数目是：121
# 33_4 的 tolerance是：0.18, inside points 数目是：124
# 33_5 的 tolerance是：0.18, inside points 数目是：114
# 33_6 的 tolerance是：0.20, inside points 数目是：130
# 33_7 的 tolerance是：0.18, inside points 数目是：120
# 33_8 的 tolerance是：0.18, inside points 数目是：126
# 33_9 的 tolerance是：0.18, inside points 数目是：115
# 34_1 的 tolerance是：0.16, inside points 数目是：108
# 34_10 的 tolerance是：0.18, inside points 数目是：118
# 34_2 的 tolerance是：0.16, inside points 数目是：98
# 34_3 的 tolerance是：0.18, inside points 数目是：126
# 34_4 的 tolerance是：0.18, inside points 数目是：122
# 34_5 的 tolerance是：0.18, inside points 数目是：124
# 34_6 的 tolerance是：0.16, inside points 数目是：104
# 34_7 的 tolerance是：0.18, inside points 数目是：125
# 34_8 的 tolerance是：0.18, inside points 数目是：117
# 34_9 的 tolerance是：0.18, inside points 数目是：121
# 35_1 的 tolerance是：0.18, inside points 数目是：104
# 35_10 的 tolerance是：0.20, inside points 数目是：123
# 35_2 的 tolerance是：0.22, inside points 数目是：148
# 35_3 的 tolerance是：0.18, inside points 数目是：105
# 35_4 的 tolerance是：0.20, inside points 数目是：115
# 35_5 的 tolerance是：0.18, inside points 数目是：106
# 35_6 的 tolerance是：0.18, inside points 数目是：103
# 35_7 的 tolerance是：0.20, inside points 数目是：117
# 35_8 的 tolerance是：0.18, inside points 数目是：101
# 35_9 的 tolerance是：0.22, inside points 数目是：129
# 36_1 的 tolerance是：0.18, inside points 数目是：119
# 36_10 的 tolerance是：0.18, inside points 数目是：115
# 36_2 的 tolerance是：0.24, inside points 数目是：150
# 36_3 的 tolerance是：0.18, inside points 数目是：121
# 36_4 的 tolerance是：0.18, inside points 数目是：120
# 36_5 的 tolerance是：0.16, inside points 数目是：101
# 36_6 的 tolerance是：0.18, inside points 数目是：121
# 36_7 的 tolerance是：0.18, inside points 数目是：118
# 36_8 的 tolerance是：0.22, inside points 数目是：143
# 36_9 的 tolerance是：0.16, inside points 数目是：104
# 37_1 的 tolerance是：0.22, inside points 数目是：138
# 37_10 的 tolerance是：0.20, inside points 数目是：114
# 37_2 的 tolerance是：0.24, inside points 数目是：141
# 37_3 的 tolerance是：0.22, inside points 数目是：136
# 37_4 的 tolerance是：0.18, inside points 数目是：99
# 37_5 的 tolerance是：0.20, inside points 数目是：124
# 37_6 的 tolerance是：0.18, inside points 数目是：105
# 37_7 的 tolerance是：0.18, inside points 数目是：113
# 37_8 的 tolerance是：0.20, inside points 数目是：115
# 37_9 的 tolerance是：0.18, inside points 数目是：95
# 38_1 的 tolerance是：0.18, inside points 数目是：101
# 38_10 的 tolerance是：0.18, inside points 数目是：104
# 38_2 的 tolerance是：0.20, inside points 数目是：113
# 38_3 的 tolerance是：0.18, inside points 数目是：106
# 38_4 的 tolerance是：0.20, inside points 数目是：118
# 38_5 的 tolerance是：0.20, inside points 数目是：111
# 38_6 的 tolerance是：0.20, inside points 数目是：116
# 38_7 的 tolerance是：0.20, inside points 数目是：119
# 38_8 的 tolerance是：0.18, inside points 数目是：104
# 38_9 的 tolerance是：0.24, inside points 数目是：157
# 39_1 的 tolerance是：0.18, inside points 数目是：107
# 39_10 的 tolerance是：0.18, inside points 数目是：108
# 39_2 的 tolerance是：0.18, inside points 数目是：109
# 39_3 的 tolerance是：0.18, inside points 数目是：106
# 39_4 的 tolerance是：0.18, inside points 数目是：114
# 39_5 的 tolerance是：0.18, inside points 数目是：109
# 39_6 的 tolerance是：0.18, inside points 数目是：114
# 39_7 的 tolerance是：0.18, inside points 数目是：105
# 39_8 的 tolerance是：0.16, inside points 数目是：95
# 39_9 的 tolerance是：0.18, inside points 数目是：105
# 4_1 的 tolerance是：0.20, inside points 数目是：148
# 4_10 的 tolerance是：0.18, inside points 数目是：135
# 4_2 的 tolerance是：0.18, inside points 数目是：119
# 4_3 的 tolerance是：0.16, inside points 数目是：105
# 4_4 的 tolerance是：0.18, inside points 数目是：124
# 4_5 的 tolerance是：0.18, inside points 数目是：124
# 4_6 的 tolerance是：0.16, inside points 数目是：119
# 4_7 的 tolerance是：0.16, inside points 数目是：119
# 4_8 的 tolerance是：0.16, inside points 数目是：109
# 4_9 的 tolerance是：0.18, inside points 数目是：136
# 40_1 的 tolerance是：0.20, inside points 数目是：138
# 40_10 的 tolerance是：0.20, inside points 数目是：122
# 40_2 的 tolerance是：0.18, inside points 数目是：115
# 40_3 的 tolerance是：0.18, inside points 数目是：112
# 40_4 的 tolerance是：0.20, inside points 数目是：134
# 40_5 的 tolerance是：0.18, inside points 数目是：104
# 40_6 的 tolerance是：0.20, inside points 数目是：127
# 40_7 的 tolerance是：0.18, inside points 数目是：114
# 40_8 的 tolerance是：0.18, inside points 数目是：115
# 40_9 的 tolerance是：0.18, inside points 数目是：104
# 41_1 的 tolerance是：0.16, inside points 数目是：99
# 41_10 的 tolerance是：0.18, inside points 数目是：111
# 41_2 的 tolerance是：0.18, inside points 数目是：117
# 41_3 的 tolerance是：0.20, inside points 数目是：127
# 41_4 的 tolerance是：0.20, inside points 数目是：129
# 41_5 的 tolerance是：0.24, inside points 数目是：151
# 41_6 的 tolerance是：0.22, inside points 数目是：150
# 41_7 的 tolerance是：0.18, inside points 数目是：121
# 41_8 的 tolerance是：0.18, inside points 数目是：118
# 41_9 的 tolerance是：0.18, inside points 数目是：115
# 42_1 的 tolerance是：0.24, inside points 数目是：155
# 42_10 的 tolerance是：0.22, inside points 数目是：138
# 42_2 的 tolerance是：0.26, inside points 数目是：163
# 42_3 的 tolerance是：0.18, inside points 数目是：119
# 42_4 的 tolerance是：0.18, inside points 数目是：126
# 42_5 的 tolerance是：0.20, inside points 数目是：143
# 42_6 的 tolerance是：0.18, inside points 数目是：125
# 42_7 的 tolerance是：0.18, inside points 数目是：117
# 42_8 的 tolerance是：0.18, inside points 数目是：114
# 42_9 的 tolerance是：0.20, inside points 数目是：122
# 43_1 的 tolerance是：0.20, inside points 数目是：132
# 43_10 的 tolerance是：0.20, inside points 数目是：129
# 43_2 的 tolerance是：0.20, inside points 数目是：138
# 43_3 的 tolerance是：0.16, inside points 数目是：104
# 43_4 的 tolerance是：0.18, inside points 数目是：106
# 43_5 的 tolerance是：0.18, inside points 数目是：126
# 43_6 的 tolerance是：0.24, inside points 数目是：161
# 43_7 的 tolerance是：0.20, inside points 数目是：127
# 43_8 的 tolerance是：0.20, inside points 数目是：125
# 43_9 的 tolerance是：0.18, inside points 数目是：116
# 44_1 的 tolerance是：0.20, inside points 数目是：120
# 44_10 的 tolerance是：0.18, inside points 数目是：103
# 44_2 的 tolerance是：0.22, inside points 数目是：148
# 44_3 的 tolerance是：0.18, inside points 数目是：114
# 44_4 的 tolerance是：0.20, inside points 数目是：130
# 44_5 的 tolerance是：0.16, inside points 数目是：97
# 44_6 的 tolerance是：0.18, inside points 数目是：106
# 44_7 的 tolerance是：0.18, inside points 数目是：109
# 44_8 的 tolerance是：0.30, inside points 数目是：194
# 44_9 的 tolerance是：0.28, inside points 数目是：180
# 45_1 的 tolerance是：0.30, inside points 数目是：197
# 45_10 的 tolerance是：0.24, inside points 数目是：150
# 45_2 的 tolerance是：0.18, inside points 数目是：104
# 45_3 的 tolerance是：0.18, inside points 数目是：119
# 45_4 的 tolerance是：0.18, inside points 数目是：101
# 45_5 的 tolerance是：0.24, inside points 数目是：148
# 45_6 的 tolerance是：0.18, inside points 数目是：106
# 45_7 的 tolerance是：0.20, inside points 数目是：112
# 45_8 的 tolerance是：0.18, inside points 数目是：100
# 45_9 的 tolerance是：0.22, inside points 数目是：132
# 46_1 的 tolerance是：0.22, inside points 数目是：137
# 46_10 的 tolerance是：0.22, inside points 数目是：126
# 46_2 的 tolerance是：0.26, inside points 数目是：180
# 46_3 的 tolerance是：0.20, inside points 数目是：124
# 46_4 的 tolerance是：0.16, inside points 数目是：96
# 46_5 的 tolerance是：0.22, inside points 数目是：145
# 46_6 无法被分割为两部分
# 46_7 的 tolerance是：0.22, inside points 数目是：127
# 46_8 的 tolerance是：0.20, inside points 数目是：123
# 46_9 的 tolerance是：0.20, inside points 数目是：129
# 47_1 的 tolerance是：0.20, inside points 数目是：126
# 47_10 的 tolerance是：0.24, inside points 数目是：144
# 47_2 的 tolerance是：0.18, inside points 数目是：114
# 47_3 无法被分割为两部分
# 47_4 的 tolerance是：0.28, inside points 数目是：179
# 47_5 的 tolerance是：0.20, inside points 数目是：109
# 47_6 的 tolerance是：0.22, inside points 数目是：137
# 47_7 的 tolerance是：0.26, inside points 数目是：165
# 47_8 的 tolerance是：0.18, inside points 数目是：107
# 47_9 的 tolerance是：0.20, inside points 数目是：123
# 48_1 的 tolerance是：0.18, inside points 数目是：119
# 48_10 的 tolerance是：0.26, inside points 数目是：150
# 48_2 的 tolerance是：0.20, inside points 数目是：128
# 48_3 的 tolerance是：0.28, inside points 数目是：187
# 48_4 的 tolerance是：0.18, inside points 数目是：127
# 48_5 的 tolerance是：0.18, inside points 数目是：114
# 48_6 的 tolerance是：0.18, inside points 数目是：122
# 48_7 的 tolerance是：0.18, inside points 数目是：117
# 48_8 的 tolerance是：0.22, inside points 数目是：137
# 48_9 的 tolerance是：0.18, inside points 数目是：122
# 49_1 的 tolerance是：0.22, inside points 数目是：122
# 49_10 的 tolerance是：0.22, inside points 数目是：116
# 49_2 的 tolerance是：0.22, inside points 数目是：127
# 49_3 的 tolerance是：0.24, inside points 数目是：143
# 49_4 的 tolerance是：0.22, inside points 数目是：122
# 49_5 的 tolerance是：0.24, inside points 数目是：145
# 49_6 的 tolerance是：0.18, inside points 数目是：107
# 49_7 的 tolerance是：0.22, inside points 数目是：126
# 49_8 的 tolerance是：0.28, inside points 数目是：174
# 49_9 的 tolerance是：0.28, inside points 数目是：170
# 5_1 的 tolerance是：0.18, inside points 数目是：132
# 5_10 的 tolerance是：0.18, inside points 数目是：130
# 5_2 的 tolerance是：0.16, inside points 数目是：119
# 5_3 的 tolerance是：0.18, inside points 数目是：100
# 5_4 的 tolerance是：0.16, inside points 数目是：123
# 5_5 的 tolerance是：0.18, inside points 数目是：140
# 5_6 的 tolerance是：0.16, inside points 数目是：110
# 5_7 的 tolerance是：0.16, inside points 数目是：117
# 5_8 的 tolerance是：0.16, inside points 数目是：112
# 5_9 的 tolerance是：0.16, inside points 数目是：118
# 50_1 的 tolerance是：0.22, inside points 数目是：151
# 50_10 的 tolerance是：0.24, inside points 数目是：149
# 50_2 的 tolerance是：0.22, inside points 数目是：113
# 50_3 的 tolerance是：0.24, inside points 数目是：151
# 50_4 的 tolerance是：0.22, inside points 数目是：132
# 50_5 的 tolerance是：0.18, inside points 数目是：107
# 50_6 的 tolerance是：0.30, inside points 数目是：188
# 50_7 的 tolerance是：0.26, inside points 数目是：163
# 50_8 的 tolerance是：0.24, inside points 数目是：157
# 50_9 的 tolerance是：0.22, inside points 数目是：135
# 51_1 的 tolerance是：0.24, inside points 数目是：150
# 51_10 的 tolerance是：0.24, inside points 数目是：156
# 51_2 的 tolerance是：0.22, inside points 数目是：130
# 51_3 的 tolerance是：0.22, inside points 数目是：135
# 51_4 的 tolerance是：0.26, inside points 数目是：166
# 51_5 的 tolerance是：0.20, inside points 数目是：130
# 51_6 的 tolerance是：0.22, inside points 数目是：129
# 51_7 的 tolerance是：0.26, inside points 数目是：167
# 51_8 的 tolerance是：0.22, inside points 数目是：132
# 51_9 的 tolerance是：0.26, inside points 数目是：159
# 56_1 的 tolerance是：0.22, inside points 数目是：145
# 56_10 的 tolerance是：0.20, inside points 数目是：134
# 56_2 的 tolerance是：0.20, inside points 数目是：136
# 56_3 的 tolerance是：0.24, inside points 数目是：172
# 56_4 的 tolerance是：0.22, inside points 数目是：137
# 56_5 的 tolerance是：0.18, inside points 数目是：116
# 56_6 的 tolerance是：0.26, inside points 数目是：186
# 56_7 的 tolerance是：0.22, inside points 数目是：159
# 56_8 的 tolerance是：0.20, inside points 数目是：124
# 56_9 无法被分割为两部分
# 57_1 的 tolerance是：0.20, inside points 数目是：118
# 57_10 的 tolerance是：0.22, inside points 数目是：136
# 57_2 的 tolerance是：0.22, inside points 数目是：140
# 57_3 的 tolerance是：0.20, inside points 数目是：140
# 57_4 的 tolerance是：0.24, inside points 数目是：164
# 57_5 的 tolerance是：0.24, inside points 数目是：159
# 57_6 的 tolerance是：0.24, inside points 数目是：151
# 57_7 的 tolerance是：0.24, inside points 数目是：162
# 57_8 的 tolerance是：0.20, inside points 数目是：117
# 57_9 的 tolerance是：0.20, inside points 数目是：119
# 58_1 的 tolerance是：0.18, inside points 数目是：112
# 58_10 的 tolerance是：0.24, inside points 数目是：137
# 58_2 的 tolerance是：0.22, inside points 数目是：141
# 58_3 的 tolerance是：0.22, inside points 数目是：130
# 58_4 的 tolerance是：0.22, inside points 数目是：130
# 58_5 的 tolerance是：0.26, inside points 数目是：157
# 58_6 的 tolerance是：0.24, inside points 数目是：138
# 58_7 的 tolerance是：0.24, inside points 数目是：138
# 58_8 的 tolerance是：0.20, inside points 数目是：121
# 58_9 的 tolerance是：0.18, inside points 数目是：107
# 6_1 的 tolerance是：0.18, inside points 数目是：122
# 6_10 的 tolerance是：0.16, inside points 数目是：112
# 6_2 的 tolerance是：0.16, inside points 数目是：117
# 6_3 的 tolerance是：0.18, inside points 数目是：130
# 6_4 的 tolerance是：0.16, inside points 数目是：99
# 6_5 的 tolerance是：0.16, inside points 数目是：101
# 6_6 的 tolerance是：0.18, inside points 数目是：127
# 6_7 的 tolerance是：0.16, inside points 数目是：99
# 6_8 的 tolerance是：0.18, inside points 数目是：139
# 6_9 的 tolerance是：0.26, inside points 数目是：174
# 60_1 的 tolerance是：0.22, inside points 数目是：138
# 60_10 的 tolerance是：0.22, inside points 数目是：133
# 60_2 的 tolerance是：0.28, inside points 数目是：195
# 60_3 的 tolerance是：0.18, inside points 数目是：120
# 60_4 的 tolerance是：0.28, inside points 数目是：196
# 60_5 的 tolerance是：0.26, inside points 数目是：188
# 60_6 的 tolerance是：0.22, inside points 数目是：134
# 60_7 的 tolerance是：0.20, inside points 数目是：122
# 60_8 无法被分割为两部分
# 60_9 的 tolerance是：0.20, inside points 数目是：121
# 61_1 的 tolerance是：0.16, inside points 数目是：100
# 61_10 的 tolerance是：0.20, inside points 数目是：122
# 61_2 的 tolerance是：0.18, inside points 数目是：115
# 61_3 的 tolerance是：0.22, inside points 数目是：139
# 61_4 的 tolerance是：0.20, inside points 数目是：128
# 61_5 的 tolerance是：0.22, inside points 数目是：141
# 61_6 的 tolerance是：0.24, inside points 数目是：154
# 61_7 的 tolerance是：0.20, inside points 数目是：130
# 61_8 的 tolerance是：0.20, inside points 数目是：125
# 61_9 无法被分割为两部分
# 7_1 的 tolerance是：0.18, inside points 数目是：115
# 7_10 的 tolerance是：0.18, inside points 数目是：119
# 7_2 的 tolerance是：0.20, inside points 数目是：145
# 7_3 的 tolerance是：0.16, inside points 数目是：96
# 7_4 的 tolerance是：0.18, inside points 数目是：120
# 7_6 的 tolerance是：0.16, inside points 数目是：103
# 7_7 的 tolerance是：0.18, inside points 数目是：126
# 7_8 的 tolerance是：0.18, inside points 数目是：128
# 7_9 的 tolerance是：0.16, inside points 数目是：102
# 71_1 的 tolerance是：0.26, inside points 数目是：165
# 71_10 的 tolerance是：0.18, inside points 数目是：118
# 71_2 的 tolerance是：0.18, inside points 数目是：113
# 71_3 的 tolerance是：0.20, inside points 数目是：126
# 71_4 的 tolerance是：0.16, inside points 数目是：96
# 71_5 的 tolerance是：0.16, inside points 数目是：96
# 71_6 的 tolerance是：0.18, inside points 数目是：104
# 71_7 的 tolerance是：0.16, inside points 数目是：96
# 71_8 的 tolerance是：0.16, inside points 数目是：99
# 71_9 的 tolerance是：0.18, inside points 数目是：112
# 72_1 的 tolerance是：0.18, inside points 数目是：124
# 72_10 的 tolerance是：0.20, inside points 数目是：142
# 72_2 的 tolerance是：0.18, inside points 数目是：122
# 72_3 的 tolerance是：0.20, inside points 数目是：127
# 72_4 的 tolerance是：0.22, inside points 数目是：149
# 72_5 的 tolerance是：0.24, inside points 数目是：156
# 72_6 的 tolerance是：0.16, inside points 数目是：104
# 72_7 的 tolerance是：0.24, inside points 数目是：167
# 72_8 的 tolerance是：0.20, inside points 数目是：135
# 72_9 的 tolerance是：0.18, inside points 数目是：117
# 73_1 的 tolerance是：0.20, inside points 数目是：131
# 73_10 的 tolerance是：0.20, inside points 数目是：115
# 73_2 的 tolerance是：0.30, inside points 数目是：197
# 73_3 的 tolerance是：0.24, inside points 数目是：159
# 73_4 无法被分割为两部分
# 73_5 的 tolerance是：0.20, inside points 数目是：116
# 73_6 的 tolerance是：0.18, inside points 数目是：129
# 73_7 的 tolerance是：0.22, inside points 数目是：146
# 73_8 的 tolerance是：0.20, inside points 数目是：122
# 73_9 的 tolerance是：0.18, inside points 数目是：112
# 75_1 的 tolerance是：0.20, inside points 数目是：127
# 75_10 的 tolerance是：0.28, inside points 数目是：182
# 75_2 的 tolerance是：0.22, inside points 数目是：129
# 75_3 的 tolerance是：0.26, inside points 数目是：165
# 75_4 的 tolerance是：0.22, inside points 数目是：144
# 75_5 的 tolerance是：0.24, inside points 数目是：149
# 75_6 的 tolerance是：0.18, inside points 数目是：116
# 75_7 的 tolerance是：0.22, inside points 数目是：127
# 75_8 的 tolerance是：0.20, inside points 数目是：119
# 75_9 的 tolerance是：0.24, inside points 数目是：149
# 76_1 的 tolerance是：0.22, inside points 数目是：140
# 76_10 的 tolerance是：0.20, inside points 数目是：133
# 76_2 的 tolerance是：0.20, inside points 数目是：130
# 76_3 的 tolerance是：0.22, inside points 数目是：137
# 76_4 的 tolerance是：0.24, inside points 数目是：166
# 76_5 的 tolerance是：0.20, inside points 数目是：129
# 76_6 的 tolerance是：0.26, inside points 数目是：172
# 76_7 的 tolerance是：0.22, inside points 数目是：149
# 76_8 的 tolerance是：0.22, inside points 数目是：145
# 76_9 的 tolerance是：0.20, inside points 数目是：132
# 77_1 的 tolerance是：0.16, inside points 数目是：107
# 77_10 无法被分割为两部分
# 77_2 的 tolerance是：0.18, inside points 数目是：115
# 77_3 的 tolerance是：0.16, inside points 数目是：110
# 77_4 的 tolerance是：0.22, inside points 数目是：136
# 77_5 的 tolerance是：0.22, inside points 数目是：146
# 77_6 的 tolerance是：0.18, inside points 数目是：117
# 77_7 无法被分割为两部分
# 77_8 的 tolerance是：0.24, inside points 数目是：161
# 77_9 的 tolerance是：0.28, inside points 数目是：180
# 78_1 无法被分割为两部分
# 未找到mark文件: 肩台外侧点-0715\78\78_10.obj.mark
# 78_2 的 tolerance是：0.24, inside points 数目是：158
# 78_3 的 tolerance是：0.28, inside points 数目是：194
# 78_4 的 tolerance是：0.24, inside points 数目是：143
# 78_5 的 tolerance是：0.20, inside points 数目是：121
# 78_6 的 tolerance是：0.22, inside points 数目是：143
# 78_7 的 tolerance是：0.24, inside points 数目是：150
# 78_8 的 tolerance是：0.18, inside points 数目是：110
# 78_9 的 tolerance是：0.22, inside points 数目是：150
# 8_1 的 tolerance是：0.18, inside points 数目是：110
# 8_10 的 tolerance是：0.18, inside points 数目是：124
# 8_2 的 tolerance是：0.20, inside points 数目是：138
# 8_3 的 tolerance是：0.20, inside points 数目是：140
# 8_4 的 tolerance是：0.18, inside points 数目是：119
# 8_5 的 tolerance是：0.18, inside points 数目是：105
# 8_6 的 tolerance是：0.18, inside points 数目是：116
# 8_7 的 tolerance是：0.18, inside points 数目是：108
# 8_8 的 tolerance是：0.18, inside points 数目是：120
# 8_9 的 tolerance是：0.18, inside points 数目是：111
# 80_1 的 tolerance是：0.22, inside points 数目是：145
# 未找到mark文件: 肩台外侧点-0715\80\80_10.obj.mark
# 80_2 的 tolerance是：0.20, inside points 数目是：121
# 80_3 的 tolerance是：0.24, inside points 数目是：150
# 80_4 无法被分割为两部分
# 80_5 的 tolerance是：0.28, inside points 数目是：177
# 80_6 的 tolerance是：0.28, inside points 数目是：195
# 80_7 的 tolerance是：0.18, inside points 数目是：107
# 80_8 无法被分割为两部分
# 80_9 无法被分割为两部分
# 84_1 的 tolerance是：0.24, inside points 数目是：163
# 84_10 的 tolerance是：0.32, inside points 数目是：199
# 84_2 的 tolerance是：0.22, inside points 数目是：131
# 84_3 无法被分割为两部分
# 84_4 的 tolerance是：0.28, inside points 数目是：182
# 84_5 无法被分割为两部分
# 84_6 的 tolerance是：0.22, inside points 数目是：145
# 84_7 的 tolerance是：0.26, inside points 数目是：171
# 84_8 无法被分割为两部分
# 84_9 的 tolerance是：0.26, inside points 数目是：161
# 85_1 无法被分割为两部分
# 85_10 无法被分割为两部分
# 85_2 的 tolerance是：0.26, inside points 数目是：177
# 85_3 的 tolerance是：0.26, inside points 数目是：175
# 85_4 的 tolerance是：0.22, inside points 数目是：147
# 85_5 无法被分割为两部分
# 85_6 的 tolerance是：0.24, inside points 数目是：152
# 85_7 的 tolerance是：0.26, inside points 数目是：173
# 85_8 的 tolerance是：0.20, inside points 数目是：129
# 85_9 无法被分割为两部分
# 9_1 的 tolerance是：0.18, inside points 数目是：123
# 9_10 的 tolerance是：0.18, inside points 数目是：115
# 9_2 的 tolerance是：0.18, inside points 数目是：116
# 9_3 的 tolerance是：0.18, inside points 数目是：114
# 9_4 的 tolerance是：0.18, inside points 数目是：121
# 9_5 的 tolerance是：0.18, inside points 数目是：119
# 9_6 的 tolerance是：0.18, inside points 数目是：124
# 9_7 的 tolerance是：0.16, inside points 数目是：103
# 9_8 的 tolerance是：0.18, inside points 数目是：115
# 9_9 的 tolerance是：0.18, inside points 数目是：109

# %%
'''
生成训练数据
'''

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import os

class PointCloudDataset(Dataset):
    def __init__(self, txt_files, voxel_size=100):
        self.data = []
        for txt_file in txt_files:
            points = np.loadtxt(txt_file)
            self.data.append(self.voxelize(points, voxel_size))
    
    def voxelize(self, points, voxel_size):
        # Normalize points to fit in the voxel grid
        min_coords = points[:, :3].min(axis=0)
        max_coords = points[:, :3].max(axis=0)
        normalized_points = (points[:, :3] - min_coords) / (max_coords - min_coords)
        normalized_points *= (voxel_size - 1)
        
        # Create voxel grid
        voxel_grid = np.zeros((voxel_size, voxel_size, voxel_size), dtype=np.float32)
        for point in normalized_points:
            x, y, z = point.astype(int)
            voxel_grid[x, y, z] = 1  # Mark the voxel as occupied

        # Create label grid
        labels = np.zeros((voxel_size, voxel_size, voxel_size), dtype=np.float32)
        for point in points:
            x, y, z, label = point.astype(int)
            labels[x, y, z] = label  # Assign the label to the voxel

        return voxel_grid, labels
    
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, idx):
        voxel_grid, labels = self.data[idx]
        return torch.tensor(voxel_grid).unsqueeze(0), torch.tensor(labels).unsqueeze(0)

def get_data_loaders(data_folder, batch_size=4, voxel_size=100):
    txt_files = [os.path.join(data_folder, f) for f in os.listdir(data_folder) if f.endswith('.txt')]
    dataset = PointCloudDataset(txt_files, voxel_size)
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)
    return dataloader
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 6
#       1 '''
#       2 生成训练数据
#       3 '''
#       5 import numpy as np
# ----> 6 import torch
#       7 import torch.nn as nn
#       8 import torch.optim as optim
#
# File D:\Anaconda\Lib\site-packages\torch\__init__.py:148
#     146                 err = ctypes.WinError(ctypes.get_last_error())
#     147                 err.strerror += f' Error loading "{dll}" or one of its dependencies.'
# --> 148                 raise err
#     150     kernel32.SetErrorMode(prev_error_mode)
#     153 def _preload_cuda_deps(lib_folder, lib_name):
#
# OSError: [WinError 126] 找不到指定的模块。 Error loading "D:\Anaconda\Lib\site-packages\torch\lib\fbgemm.dll" or one of its dependencies.

# %%
'''
3D UNET
'''

class UNet3D(nn.Module):
    def __init__(self, in_channels, out_channels, init_features=32):
        super(UNet3D, self).__init__()

        features = init_features
        self.encoder1 = UNet3D._block(in_channels, features)
        self.pool1 = nn.MaxPool3d(kernel_size=2, stride=2)
        self.encoder2 = UNet3D._block(features, features * 2)
        self.pool2 = nn.MaxPool3d(kernel_size=2, stride=2)
        self.encoder3 = UNet3D._block(features * 2, features * 4)
        self.pool3 = nn.MaxPool3d(kernel_size=2, stride=2)
        self.encoder4 = UNet3D._block(features * 4, features * 8)
        self.pool4 = nn.MaxPool3d(kernel_size=2, stride=2)

        self.bottleneck = UNet3D._block(features * 8, features * 16)

        self.upconv4 = nn.ConvTranspose3d(features * 16, features * 8, kernel_size=2, stride=2)
        self.decoder4 = UNet3D._block(features * 16, features * 8)
        self.upconv3 = nn.ConvTranspose3d(features * 8, features * 4, kernel_size=2, stride=2)
        self.decoder3 = UNet3D._block(features * 8, features * 4)
        self.upconv2 = nn.ConvTranspose3d(features * 4, features * 2, kernel_size=2, stride=2)
        self.decoder2 = UNet3D._block(features * 4, features * 2)
        self.upconv1 = nn.ConvTranspose3d(features * 2, features, kernel_size=2, stride=2)
        self.decoder1 = UNet3D._block(features * 2, features)

        self.conv = nn.Conv3d(in_channels=features, out_channels=out_channels, kernel_size=1)

    def forward(self, x):
        enc1 = self.encoder1(x)
        enc2 = self.encoder2(self.pool1(enc1))
        enc3 = self.encoder3(self.pool2(enc2))
        enc4 = self.encoder4(self.pool3(enc3))

        bottleneck = self.bottleneck(self.pool4(enc4))

        dec4 = self.upconv4(bottleneck)
        dec4 = torch.cat((dec4, enc4), dim=1)
        dec4 = self.decoder4(dec4)
        dec3 = self.upconv3(dec4)
        dec3 = torch.cat((dec3, enc3), dim=1)
        dec3 = self.decoder3(dec3)
        dec2 = self.upconv2(dec3)
        dec2 = torch.cat((dec2, enc2), dim=1)
        dec2 = self.decoder2(dec2)
        dec1 = self.upconv1(dec2)
        dec1 = torch.cat((dec1, enc1), dim=1)
        dec1 = self.decoder1(dec1)

        return torch.sigmoid(self.conv(dec1))

    @staticmethod
    def _block(in_channels, features, name=""):
        return nn.Sequential(
            nn.Conv3d(in_channels=in_channels, out_channels=features, kernel_size=3, padding=1, bias=False),
            nn.BatchNorm3d(features),
            nn.ReLU(inplace=True),
            nn.Conv3d(in_channels=features, out_channels=features, kernel_size=3, padding=1, bias=False),
            nn.BatchNorm3d(features),
            nn.ReLU(inplace=True),
        )

# %%
'''
炼
'''

def dice_loss(pred, target, smooth=1e-6):
    intersection = (pred * target).sum()
    union = pred.sum() + target.sum()
    dice = (2.0 * intersection + smooth) / (union + smooth)
    return 1 - dice

def train(model, dataloader, optimizer, num_epochs=25, device='cuda'):
    model = model.to(device)
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        for inputs, labels in dataloader:
            inputs, labels = inputs.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = dice_loss(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item() * inputs.size(0)

        epoch_loss = running_loss / len(dataloader.dataset)
        print(f'Epoch {epoch+1}/{num_epochs}, Loss: {epoch_loss:.4f}')

def evaluate(model, dataloader, device='cuda'):
    model.eval()
    total = 0
    correct = 0
    with torch.no_grad():
        for inputs, labels in dataloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            predicted = (outputs > 0.5).float()
            total += labels.nelement()
            correct += (predicted == labels).sum().item()

    print(f'Accuracy: {correct / total:.4f}')

# 获取数据加载器
data_folder = r'边缘检测预处理后数据'
batch_size = 4
voxel_size = 100

dataloader = get_data_loaders(data_folder, batch_size, voxel_size)

# 定义模型、损失函数和优化器
model = UNet3D(in_channels=1, out_channels=1)
optimizer = optim.Adam(model.parameters(), lr=1e-4)

# 训练模型
train(model, dataloader, optimizer, num_epochs=2)

# 评估模型
evaluate(model, dataloader)

# %%
# 保存模型
model_save_path = 'July29边缘检测模型/UNET_BEC.h5'
model.save(model_save_path)
print(f"Model saved to {model_save_path}")

# %%
# 开启交互旋转
# %matplotlib notebook

# %%
'''
预测结果可视化
'''

import os
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import tensorflow as tf
from collections import defaultdict
from itertools import combinations

# 加载obj文件
def load_obj_file(file_path):
    vertices = []
    faces = []
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            for line in file:
                if line.startswith('v '):
                    parts = line.strip().split()
                    vertex = [float(parts[1]), float(parts[2]), float(parts[3])]
                    vertices.append(vertex)
                elif line.startswith('f '):
                    parts = line.strip().split()
                    face = [int(p.split('/')[0]) - 1 for p in parts[1:]]
                    faces.append(face)
    except FileNotFoundError:
        print(f"File not found: {file_path}")
    except Exception as e:
        print(f"An error occurred: {e}")
    return vertices, faces

# 将顶点平移至包围盒中心
def center_vertices(vertices):
    vertices_array = np.array(vertices)
    min_coords = vertices_array.min(axis=0)
    max_coords = vertices_array.max(axis=0)
    center = (min_coords + max_coords) / 2
    centered_vertices = vertices_array - center
    return centered_vertices.tolist(), center

# 点云转体素网格
def create_voxel_grid(data, grid_size):
    grid = np.zeros((grid_size, grid_size, grid_size))
    min_coords = np.min(data, axis=0)
    max_coords = np.max(data, axis=0)
    voxel_dim = (max_coords - min_coords) / grid_size

    for i, point in enumerate(data):
        voxel = ((point - min_coords) / voxel_dim).astype(int)
        voxel = np.clip(voxel, 0, grid_size-1)  # Ensure indices are within bounds
        grid[voxel[0], voxel[1], voxel[2]] = 1

    return grid, min_coords, voxel_dim

# 从训练好的模型获取标签
def get_labels_from_model(model, voxel_grid):
    voxel_grid = np.expand_dims(voxel_grid, axis=0)  # Add batch dimension
    voxel_grid = np.expand_dims(voxel_grid, axis=-1)  # Add channel dimension
    predictions = model.predict(voxel_grid)
    labels = (predictions > 0.5).astype(int)
    return labels.reshape(voxel_grid.shape[1], voxel_grid.shape[2], voxel_grid.shape[3])

# 应用预测标签到原始点云
def apply_labels_to_point_cloud(data, predicted_labels, min_coords, voxel_dim, grid_size):
    labels = np.zeros(len(data))
    for i, point in enumerate(data):
        voxel = ((point - min_coords) / voxel_dim).astype(int)
        voxel = np.clip(voxel, 0, grid_size-1)  # Ensure indices are within bounds
        labels[i] = predicted_labels[voxel[0], voxel[1], voxel[2]]
    return labels

# 绘制带有分类标签的点云和分界线
def plot_point_cloud_with_labels(vertices, labels, angles=(0, 0, 0)):
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')

    vertices = np.array(vertices)
    labels = np.array(labels)

    # Apply rotation
    vertices = rotate_points(vertices, angles)
    
    x, y, z = vertices.T

    edge_points = vertices[labels == 1]
    non_edge_points = vertices[labels == 0]

    # 绘制点云
    ax.scatter(non_edge_points[:, 0], non_edge_points[:, 1], non_edge_points[:, 2], c='b', marker='o', s=1, label='Non-edge')
    ax.scatter(edge_points[:, 0], edge_points[:, 1], edge_points[:, 2], c='r', marker='o', s=1, label='Edge')

    # 设置标签和标题
    ax.set_xlabel('X axis')
    ax.set_ylabel('Y axis')
    ax.set_zlabel('Z axis')
    ax.set_title('3D Point Cloud with Edge Detection')

    # 确保坐标轴刻度一致
    max_range = np.array([max(x)-min(x), max(y)-min(y), max(z)-min(z)]).max()
    mid_x = (max(x) + min(x)) * 0.5
    mid_y = (max(y) + min(y)) * 0.5
    mid_z = (max(z) + min(z)) * 0.5
    ax.set_xlim(mid_x - max_range/2, mid_x + max_range/2)
    ax.set_ylim(mid_y - max_range/2, mid_y + max_range/2)
    ax.set_zlim(mid_z - max_range/2, mid_z + max_range/2)

    # 设置视角
    ax.view_init(elev=30, azim=30)  # Adjust these values as needed

    # 确保坐标轴比例相等
    ax.set_box_aspect([1,1,1])  # Aspect ratio is 1:1:1

    # 启用交互式旋转
    plt.legend()
    plt.show()

# 加载模型
model = tf.keras.models.load_model('July29边缘检测模型/UNET_BEC.h5')

# 加载点云数据
obj_file_path = r'肩台外侧点-0715/30/30_1.obj'
vertices, faces = load_obj_file(obj_file_path)
centered_vertices, center = center_vertices(vertices)

# 将点云转换为体素网格
grid_size = 100  # Grid size as specified
voxel_grid, min_coords, voxel_dim = create_voxel_grid(np.array(centered_vertices), grid_size)

# 使用训练好的模型进行预测
predicted_labels = get_labels_from_model(model, voxel_grid)

# 获取原始点云的预测标签
predicted_point_labels = apply_labels_to_point_cloud(np.array(centered_vertices), predicted_labels, min_coords, voxel_dim, grid_size)

# 画图
plot_point_cloud_with_labels(centered_vertices, predicted_point_labels, angles=(0, 0, 0))
